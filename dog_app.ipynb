# %% [markdown]
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
from tensorflow.keras.backend import set_session
set_session(session) # set this TensorFlow session as the default session for Keras

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('data/dog_images/train')
valid_files, valid_targets = load_dataset('data/dog_images/valid')
test_files, test_targets = load_dataset('data/dog_images/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("data/lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13234 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__
#
#
# * 100.0% of humans are detected as humans.
# * 0.11% of dogs are detected as humans.

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
humansDetectedAsHumans = 0
for i in human_files_short:
    success = face_detector(i)
    #print('human face_detector access success:', success)
    if success:
        humansDetectedAsHumans += 1

dogsDetectedAsHumans = 0
for i in dog_files_short:
    success = face_detector(i)
    #print('dog face_detector access success:', success)
    if success:
        dogsDetectedAsHumans += 1     
    
print(humansDetectedAsHumans / human_files_short.shape[0])
print(dogsDetectedAsHumans / dog_files_short.shape[0])
# Out:
# 0.98
# 0.12

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# * It is reasonable to request this, though the definition of "clear" is not so clear. To assist with the times when the image is not a clearly presented face, we can do data augmentation on the training set for translation, rotation, scale, intensity, and noise. Additionally, it may be helpful to work on regularization techniques like L1/L2 regularization and dropout to limit overfitting to "clearly presented faces".
#
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# extract pre-trained face detector lbpcascade
lbp_face_cascade = cv2.CascadeClassifier('lbpcascade/lbpcascade_frontalface_improved.xml')  

# load color (BGR) image
img = cv2.imread(human_files[3])
#img = cv2.imread('Aaron_Eckhart_0001.jpg')
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = lbp_face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()

# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = lbp_face_cascade.detectMultiScale(gray)
    return len(faces) > 0

humansDetectedAsHumans = 0
for i in human_files_short:
    success = face_detector(i)
    #print('human face_detector access success:', success)
    if success:
        humansDetectedAsHumans += 1

dogsDetectedAsHumans = 0
for i in dog_files_short:
    success = face_detector(i)
    #print('dog face_detector access success:', success)
    if success:
        dogsDetectedAsHumans += 1     
    
print(humansDetectedAsHumans / human_files_short.shape[0])
print(dogsDetectedAsHumans / dog_files_short.shape[0])
# Out:
# Number of faces detected: 1
# 0.85
# 0.01

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')
# Out:
# WARNING:tensorflow:From C:\Users\shane\.conda\envs\keras3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__
#
# 0.0% of humans were detected as a dog. 100.0% of dogs were detected as human.
#
# Perfect score.

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

#import tensorflow as tf
#config = tf.ConfigProto()
#config.gpu_options.allow_growth = True
#sess = tf.Session(config=config)

human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
humansDetectedAsHumans = 0
for i in human_files_short:
    success = dog_detector(i)
    print('human face_detector access success:', success)
    if success:
        humansDetectedAsHumans += 1

dogsDetectedAsHumans = 0
for i in dog_files_short:
    success = dog_detector(i)
    print('dog face_detector access success:', success)
    if success:
        dogsDetectedAsHumans += 1     
    
print(humansDetectedAsHumans / human_files_short.shape[0])
print(dogsDetectedAsHumans / dog_files_short.shape[0])
# Out:
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: True
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# human face_detector access success: False
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# dog face_detector access success: True
# 0.01
# 1.0

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [01:05<00:00, 101.99it/s]
# 100%|██████████| 835/835 [00:12<00:00, 69.41it/s]
# 100%|██████████| 836/836 [00:11<00:00, 75.56it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__
#
# I chose an architecture similar to that of the ones used in the cifar10 mini projects, since they performed decently there. Additionally, since we are using larger images, I added an extra filter layer to extact larger features, which seemed to improve the results, as did adding dropout after the CNN laters, improving from 8.3% -> 10.28%

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

### TODO: Define your architecture.
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.1))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.1))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(133, activation='softmax'))

model.summary()

# best Test accuracy: 8.3732% with cifar10_cnn network, 5 epochs
# best with additional cov layer is Test accuracy: > 10.0%, 10 epochs
# Out:
# WARNING:tensorflow:From C:\Users\shane\.conda\envs\keras3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 128)       32896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               12544500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 12,654,573
# Trainable params: 12,654,573
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 10

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\shane\.conda\envs\keras3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6680 samples, validate on 835 samples
# Epoch 1/10
# 6680/6680 [==============================] - ETA: 8:29 - loss: 4.8581 - acc: 0.050 - ETA: 2:57 - loss: 7.9551 - acc: 0.033 - ETA: 1:51 - loss: 6.8144 - acc: 0.030 - ETA: 1:22 - loss: 6.2817 - acc: 0.021 - ETA: 1:06 - loss: 5.9749 - acc: 0.016 - ETA: 56s - loss: 5.7798 - acc: 0.013 - ETA: 49s - loss: 5.6423 - acc: 0.01 - ETA: 44s - loss: 5.5429 - acc: 0.01 - ETA: 40s - loss: 5.4675 - acc: 0.00 - ETA: 37s - loss: 5.4075 - acc: 0.00 - ETA: 34s - loss: 5.3603 - acc: 0.00 - ETA: 32s - loss: 5.3191 - acc: 0.00 - ETA: 30s - loss: 5.2840 - acc: 0.00 - ETA: 28s - loss: 5.2558 - acc: 0.00 - ETA: 27s - loss: 5.2303 - acc: 0.00 - ETA: 26s - loss: 5.2085 - acc: 0.00 - ETA: 25s - loss: 5.1896 - acc: 0.00 - ETA: 24s - loss: 5.1723 - acc: 0.00 - ETA: 23s - loss: 5.1562 - acc: 0.00 - ETA: 22s - loss: 5.1451 - acc: 0.00 - ETA: 22s - loss: 5.1330 - acc: 0.00 - ETA: 21s - loss: 5.1219 - acc: 0.00 - ETA: 20s - loss: 5.1113 - acc: 0.00 - ETA: 20s - loss: 5.1017 - acc: 0.00 - ETA: 19s - loss: 5.0930 - acc: 0.00 - ETA: 19s - loss: 5.0849 - acc: 0.00 - ETA: 18s - loss: 5.0770 - acc: 0.00 - ETA: 18s - loss: 5.0731 - acc: 0.00 - ETA: 18s - loss: 5.0665 - acc: 0.00 - ETA: 17s - loss: 5.0602 - acc: 0.00 - ETA: 17s - loss: 5.0546 - acc: 0.00 - ETA: 16s - loss: 5.0490 - acc: 0.00 - ETA: 16s - loss: 5.0442 - acc: 0.00 - ETA: 16s - loss: 5.0402 - acc: 0.00 - ETA: 16s - loss: 5.0360 - acc: 0.00 - ETA: 15s - loss: 5.0319 - acc: 0.00 - ETA: 15s - loss: 5.0280 - acc: 0.00 - ETA: 15s - loss: 5.0242 - acc: 0.00 - ETA: 14s - loss: 5.0206 - acc: 0.00 - ETA: 14s - loss: 5.0174 - acc: 0.00 - ETA: 14s - loss: 5.0149 - acc: 0.00 - ETA: 14s - loss: 5.0119 - acc: 0.00 - ETA: 14s - loss: 5.0088 - acc: 0.00 - ETA: 13s - loss: 5.0079 - acc: 0.00 - ETA: 13s - loss: 5.0054 - acc: 0.00 - ETA: 13s - loss: 5.0026 - acc: 0.00 - ETA: 13s - loss: 4.9996 - acc: 0.00 - ETA: 13s - loss: 4.9979 - acc: 0.00 - ETA: 12s - loss: 4.9959 - acc: 0.00 - ETA: 12s - loss: 4.9936 - acc: 0.00 - ETA: 12s - loss: 4.9911 - acc: 0.00 - ETA: 12s - loss: 4.9889 - acc: 0.00 - ETA: 12s - loss: 4.9867 - acc: 0.00 - ETA: 11s - loss: 4.9847 - acc: 0.00 - ETA: 11s - loss: 4.9830 - acc: 0.00 - ETA: 11s - loss: 4.9813 - acc: 0.00 - ETA: 11s - loss: 4.9790 - acc: 0.00 - ETA: 11s - loss: 4.9777 - acc: 0.01 - ETA: 11s - loss: 4.9762 - acc: 0.01 - ETA: 11s - loss: 4.9748 - acc: 0.01 - ETA: 10s - loss: 4.9736 - acc: 0.01 - ETA: 10s - loss: 4.9722 - acc: 0.01 - ETA: 10s - loss: 4.9709 - acc: 0.01 - ETA: 10s - loss: 4.9694 - acc: 0.00 - ETA: 10s - loss: 4.9677 - acc: 0.00 - ETA: 10s - loss: 4.9668 - acc: 0.00 - ETA: 10s - loss: 4.9650 - acc: 0.00 - ETA: 9s - loss: 4.9634 - acc: 0.0096 - ETA: 9s - loss: 4.9632 - acc: 0.009 - ETA: 9s - loss: 4.9620 - acc: 0.009 - ETA: 9s - loss: 4.9610 - acc: 0.009 - ETA: 9s - loss: 4.9597 - acc: 0.009 - ETA: 9s - loss: 4.9588 - acc: 0.009 - ETA: 9s - loss: 4.9573 - acc: 0.010 - ETA: 9s - loss: 4.9576 - acc: 0.010 - ETA: 8s - loss: 4.9564 - acc: 0.010 - ETA: 8s - loss: 4.9556 - acc: 0.010 - ETA: 8s - loss: 4.9549 - acc: 0.010 - ETA: 8s - loss: 4.9538 - acc: 0.010 - ETA: 8s - loss: 4.9522 - acc: 0.010 - ETA: 8s - loss: 4.9507 - acc: 0.010 - ETA: 8s - loss: 4.9505 - acc: 0.010 - ETA: 8s - loss: 4.9494 - acc: 0.010 - ETA: 7s - loss: 4.9483 - acc: 0.009 - ETA: 7s - loss: 4.9478 - acc: 0.010 - ETA: 7s - loss: 4.9466 - acc: 0.009 - ETA: 7s - loss: 4.9459 - acc: 0.010 - ETA: 7s - loss: 4.9454 - acc: 0.010 - ETA: 7s - loss: 4.9443 - acc: 0.010 - ETA: 7s - loss: 4.9437 - acc: 0.010 - ETA: 7s - loss: 4.9431 - acc: 0.010 - ETA: 7s - loss: 4.9428 - acc: 0.010 - ETA: 6s - loss: 4.9416 - acc: 0.010 - ETA: 6s - loss: 4.9408 - acc: 0.010 - ETA: 6s - loss: 4.9405 - acc: 0.010 - ETA: 6s - loss: 4.9399 - acc: 0.010 - ETA: 6s - loss: 4.9392 - acc: 0.010 - ETA: 6s - loss: 4.9382 - acc: 0.011 - ETA: 6s - loss: 4.9379 - acc: 0.011 - ETA: 6s - loss: 4.9371 - acc: 0.011 - ETA: 6s - loss: 4.9370 - acc: 0.011 - ETA: 6s - loss: 4.9365 - acc: 0.011 - ETA: 5s - loss: 4.9356 - acc: 0.011 - ETA: 5s - loss: 4.9352 - acc: ...
#
# Epoch 00001: val_loss improved from inf to 4.63748, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/10
# 6680/6680 [==============================] - ETA: 14s - loss: 4.7155 - acc: 0.0000e+ - ETA: 13s - loss: 4.5346 - acc: 0.0167   - ETA: 13s - loss: 4.5637 - acc: 0.02 - ETA: 13s - loss: 4.5642 - acc: 0.04 - ETA: 12s - loss: 4.5419 - acc: 0.05 - ETA: 12s - loss: 4.5793 - acc: 0.04 - ETA: 12s - loss: 4.5878 - acc: 0.04 - ETA: 12s - loss: 4.5940 - acc: 0.04 - ETA: 12s - loss: 4.5970 - acc: 0.03 - ETA: 12s - loss: 4.5825 - acc: 0.03 - ETA: 12s - loss: 4.5854 - acc: 0.04 - ETA: 12s - loss: 4.5770 - acc: 0.04 - ETA: 12s - loss: 4.5880 - acc: 0.03 - ETA: 12s - loss: 4.5863 - acc: 0.03 - ETA: 11s - loss: 4.5904 - acc: 0.03 - ETA: 11s - loss: 4.5903 - acc: 0.04 - ETA: 11s - loss: 4.5928 - acc: 0.03 - ETA: 11s - loss: 4.5852 - acc: 0.04 - ETA: 11s - loss: 4.5965 - acc: 0.04 - ETA: 11s - loss: 4.5946 - acc: 0.04 - ETA: 11s - loss: 4.5918 - acc: 0.04 - ETA: 11s - loss: 4.5788 - acc: 0.04 - ETA: 11s - loss: 4.5749 - acc: 0.04 - ETA: 11s - loss: 4.5798 - acc: 0.04 - ETA: 11s - loss: 4.5715 - acc: 0.04 - ETA: 10s - loss: 4.5708 - acc: 0.04 - ETA: 10s - loss: 4.5666 - acc: 0.04 - ETA: 10s - loss: 4.5619 - acc: 0.04 - ETA: 10s - loss: 4.5681 - acc: 0.04 - ETA: 10s - loss: 4.5651 - acc: 0.04 - ETA: 10s - loss: 4.5542 - acc: 0.04 - ETA: 10s - loss: 4.5494 - acc: 0.04 - ETA: 10s - loss: 4.5490 - acc: 0.04 - ETA: 10s - loss: 4.5510 - acc: 0.04 - ETA: 10s - loss: 4.5494 - acc: 0.04 - ETA: 10s - loss: 4.5529 - acc: 0.04 - ETA: 10s - loss: 4.5539 - acc: 0.04 - ETA: 10s - loss: 4.5469 - acc: 0.04 - ETA: 9s - loss: 4.5453 - acc: 0.0442 - ETA: 9s - loss: 4.5468 - acc: 0.043 - ETA: 9s - loss: 4.5498 - acc: 0.042 - ETA: 9s - loss: 4.5502 - acc: 0.042 - ETA: 9s - loss: 4.5442 - acc: 0.043 - ETA: 9s - loss: 4.5450 - acc: 0.043 - ETA: 9s - loss: 4.5476 - acc: 0.042 - ETA: 9s - loss: 4.5463 - acc: 0.042 - ETA: 9s - loss: 4.5398 - acc: 0.045 - ETA: 9s - loss: 4.5392 - acc: 0.044 - ETA: 9s - loss: 4.5361 - acc: 0.044 - ETA: 9s - loss: 4.5342 - acc: 0.044 - ETA: 9s - loss: 4.5336 - acc: 0.043 - ETA: 8s - loss: 4.5343 - acc: 0.042 - ETA: 8s - loss: 4.5278 - acc: 0.042 - ETA: 8s - loss: 4.5229 - acc: 0.042 - ETA: 8s - loss: 4.5254 - acc: 0.042 - ETA: 8s - loss: 4.5239 - acc: 0.042 - ETA: 8s - loss: 4.5205 - acc: 0.043 - ETA: 8s - loss: 4.5175 - acc: 0.043 - ETA: 8s - loss: 4.5187 - acc: 0.043 - ETA: 8s - loss: 4.5192 - acc: 0.043 - ETA: 8s - loss: 4.5175 - acc: 0.043 - ETA: 8s - loss: 4.5158 - acc: 0.043 - ETA: 8s - loss: 4.5130 - acc: 0.043 - ETA: 7s - loss: 4.5080 - acc: 0.044 - ETA: 7s - loss: 4.5082 - acc: 0.043 - ETA: 7s - loss: 4.5059 - acc: 0.043 - ETA: 7s - loss: 4.5092 - acc: 0.043 - ETA: 7s - loss: 4.5097 - acc: 0.044 - ETA: 7s - loss: 4.5065 - acc: 0.044 - ETA: 7s - loss: 4.5047 - acc: 0.044 - ETA: 7s - loss: 4.5033 - acc: 0.044 - ETA: 7s - loss: 4.5015 - acc: 0.044 - ETA: 7s - loss: 4.5021 - acc: 0.044 - ETA: 7s - loss: 4.5007 - acc: 0.044 - ETA: 7s - loss: 4.5005 - acc: 0.043 - ETA: 7s - loss: 4.4991 - acc: 0.043 - ETA: 7s - loss: 4.5016 - acc: 0.043 - ETA: 6s - loss: 4.5022 - acc: 0.043 - ETA: 6s - loss: 4.5024 - acc: 0.042 - ETA: 6s - loss: 4.5015 - acc: 0.043 - ETA: 6s - loss: 4.5023 - acc: 0.043 - ETA: 6s - loss: 4.4989 - acc: 0.044 - ETA: 6s - loss: 4.4981 - acc: 0.045 - ETA: 6s - loss: 4.5013 - acc: 0.044 - ETA: 6s - loss: 4.5003 - acc: 0.044 - ETA: 6s - loss: 4.5001 - acc: 0.045 - ETA: 6s - loss: 4.4981 - acc: 0.045 - ETA: 6s - loss: 4.4973 - acc: 0.044 - ETA: 6s - loss: 4.4963 - acc: 0.045 - ETA: 6s - loss: 4.4946 - acc: 0.045 - ETA: 5s - loss: 4.4945 - acc: 0.045 - ETA: 5s - loss: 4.4960 - acc: 0.045 - ETA: 5s - loss: 4.4937 - acc: 0.046 - ETA: 5s - loss: 4.4956 - acc: 0.046 - ETA: 5s - loss: 4.4960 - acc: 0.046 - ETA: 5s - loss: 4.4963 - acc: 0.046 - ETA: 5s - loss: 4.4954 - acc: 0.046 - ETA: 5s - loss: 4.4924 - acc: 0.047 - ETA: 5s - loss: 4.4928 - acc: 0.046 - ETA: 5s - loss: 4.4934 - acc: 0.047 - ETA: 5s - loss: 4.4953 - acc: 0.046 - ETA: 5s - loss: 4.4924 - acc: 0.046 - ETA: 5s - loss: 4.4927 - acc: 0.046 - ETA: 4s - loss: 4.4956 - acc: 0. ...
#
# Epoch 00002: val_loss improved from 4.63748 to 4.30997, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 3/10
# 6680/6680 [==============================] - ETA: 14s - loss: 4.3360 - acc: 0.0000e+ - ETA: 13s - loss: 4.5412 - acc: 0.0167   - ETA: 12s - loss: 4.4775 - acc: 0.02 - ETA: 12s - loss: 4.3874 - acc: 0.04 - ETA: 12s - loss: 4.3607 - acc: 0.04 - ETA: 12s - loss: 4.3466 - acc: 0.05 - ETA: 12s - loss: 4.2949 - acc: 0.06 - ETA: 12s - loss: 4.2625 - acc: 0.06 - ETA: 12s - loss: 4.2643 - acc: 0.06 - ETA: 12s - loss: 4.2420 - acc: 0.06 - ETA: 12s - loss: 4.2345 - acc: 0.06 - ETA: 11s - loss: 4.2339 - acc: 0.05 - ETA: 11s - loss: 4.2315 - acc: 0.06 - ETA: 11s - loss: 4.2474 - acc: 0.06 - ETA: 11s - loss: 4.2363 - acc: 0.06 - ETA: 11s - loss: 4.2364 - acc: 0.06 - ETA: 11s - loss: 4.2171 - acc: 0.06 - ETA: 11s - loss: 4.2273 - acc: 0.06 - ETA: 11s - loss: 4.2174 - acc: 0.06 - ETA: 11s - loss: 4.2121 - acc: 0.06 - ETA: 11s - loss: 4.2213 - acc: 0.06 - ETA: 11s - loss: 4.2179 - acc: 0.06 - ETA: 11s - loss: 4.2256 - acc: 0.06 - ETA: 11s - loss: 4.2221 - acc: 0.06 - ETA: 11s - loss: 4.2114 - acc: 0.06 - ETA: 10s - loss: 4.2109 - acc: 0.06 - ETA: 10s - loss: 4.2103 - acc: 0.06 - ETA: 10s - loss: 4.2080 - acc: 0.06 - ETA: 10s - loss: 4.2013 - acc: 0.06 - ETA: 10s - loss: 4.1989 - acc: 0.06 - ETA: 10s - loss: 4.1925 - acc: 0.06 - ETA: 10s - loss: 4.1940 - acc: 0.06 - ETA: 10s - loss: 4.1893 - acc: 0.06 - ETA: 10s - loss: 4.1843 - acc: 0.06 - ETA: 10s - loss: 4.1784 - acc: 0.06 - ETA: 10s - loss: 4.1775 - acc: 0.06 - ETA: 10s - loss: 4.1783 - acc: 0.06 - ETA: 9s - loss: 4.1736 - acc: 0.0676 - ETA: 9s - loss: 4.1705 - acc: 0.069 - ETA: 9s - loss: 4.1653 - acc: 0.071 - ETA: 9s - loss: 4.1633 - acc: 0.069 - ETA: 9s - loss: 4.1618 - acc: 0.068 - ETA: 9s - loss: 4.1599 - acc: 0.070 - ETA: 9s - loss: 4.1593 - acc: 0.070 - ETA: 9s - loss: 4.1524 - acc: 0.070 - ETA: 9s - loss: 4.1539 - acc: 0.069 - ETA: 9s - loss: 4.1523 - acc: 0.068 - ETA: 9s - loss: 4.1560 - acc: 0.068 - ETA: 9s - loss: 4.1547 - acc: 0.068 - ETA: 9s - loss: 4.1563 - acc: 0.068 - ETA: 8s - loss: 4.1485 - acc: 0.070 - ETA: 8s - loss: 4.1512 - acc: 0.070 - ETA: 8s - loss: 4.1541 - acc: 0.069 - ETA: 8s - loss: 4.1562 - acc: 0.068 - ETA: 8s - loss: 4.1511 - acc: 0.069 - ETA: 8s - loss: 4.1509 - acc: 0.068 - ETA: 8s - loss: 4.1498 - acc: 0.068 - ETA: 8s - loss: 4.1498 - acc: 0.068 - ETA: 8s - loss: 4.1515 - acc: 0.070 - ETA: 8s - loss: 4.1519 - acc: 0.070 - ETA: 8s - loss: 4.1567 - acc: 0.070 - ETA: 8s - loss: 4.1568 - acc: 0.070 - ETA: 8s - loss: 4.1581 - acc: 0.069 - ETA: 7s - loss: 4.1574 - acc: 0.069 - ETA: 7s - loss: 4.1571 - acc: 0.069 - ETA: 7s - loss: 4.1595 - acc: 0.068 - ETA: 7s - loss: 4.1607 - acc: 0.068 - ETA: 7s - loss: 4.1579 - acc: 0.067 - ETA: 7s - loss: 4.1584 - acc: 0.067 - ETA: 7s - loss: 4.1604 - acc: 0.067 - ETA: 7s - loss: 4.1597 - acc: 0.068 - ETA: 7s - loss: 4.1622 - acc: 0.068 - ETA: 7s - loss: 4.1631 - acc: 0.068 - ETA: 7s - loss: 4.1644 - acc: 0.067 - ETA: 7s - loss: 4.1629 - acc: 0.067 - ETA: 7s - loss: 4.1622 - acc: 0.068 - ETA: 6s - loss: 4.1647 - acc: 0.068 - ETA: 6s - loss: 4.1645 - acc: 0.067 - ETA: 6s - loss: 4.1648 - acc: 0.068 - ETA: 6s - loss: 4.1643 - acc: 0.068 - ETA: 6s - loss: 4.1623 - acc: 0.068 - ETA: 6s - loss: 4.1627 - acc: 0.068 - ETA: 6s - loss: 4.1661 - acc: 0.067 - ETA: 6s - loss: 4.1666 - acc: 0.067 - ETA: 6s - loss: 4.1650 - acc: 0.067 - ETA: 6s - loss: 4.1636 - acc: 0.067 - ETA: 6s - loss: 4.1636 - acc: 0.067 - ETA: 6s - loss: 4.1643 - acc: 0.067 - ETA: 6s - loss: 4.1656 - acc: 0.067 - ETA: 6s - loss: 4.1666 - acc: 0.067 - ETA: 5s - loss: 4.1673 - acc: 0.067 - ETA: 5s - loss: 4.1670 - acc: 0.069 - ETA: 5s - loss: 4.1638 - acc: 0.068 - ETA: 5s - loss: 4.1639 - acc: 0.068 - ETA: 5s - loss: 4.1650 - acc: 0.069 - ETA: 5s - loss: 4.1654 - acc: 0.068 - ETA: 5s - loss: 4.1663 - acc: 0.068 - ETA: 5s - loss: 4.1673 - acc: 0.068 - ETA: 5s - loss: 4.1648 - acc: 0.068 - ETA: 5s - loss: 4.1655 - acc: 0.069 - ETA: 5s - loss: 4.1675 - acc: 0.068 - ETA: 5s - loss: 4.1634 - acc: 0.069 - ETA: 5s - loss: 4.1641 - acc: 0.068 - ETA: 4s - loss: 4.1626 - acc: 0. ...
#
# Epoch 00003: val_loss improved from 4.30997 to 4.09582, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 4/10
# 6680/6680 [==============================] - ETA: 13s - loss: 3.7637 - acc: 0.05 - ETA: 12s - loss: 3.6689 - acc: 0.08 - ETA: 12s - loss: 3.5517 - acc: 0.13 - ETA: 12s - loss: 3.5413 - acc: 0.12 - ETA: 12s - loss: 3.6056 - acc: 0.11 - ETA: 12s - loss: 3.6699 - acc: 0.11 - ETA: 12s - loss: 3.7264 - acc: 0.12 - ETA: 12s - loss: 3.7174 - acc: 0.12 - ETA: 11s - loss: 3.7022 - acc: 0.12 - ETA: 11s - loss: 3.7107 - acc: 0.12 - ETA: 11s - loss: 3.7019 - acc: 0.12 - ETA: 11s - loss: 3.7134 - acc: 0.12 - ETA: 11s - loss: 3.7222 - acc: 0.12 - ETA: 11s - loss: 3.7359 - acc: 0.12 - ETA: 11s - loss: 3.7429 - acc: 0.12 - ETA: 11s - loss: 3.7441 - acc: 0.11 - ETA: 11s - loss: 3.7232 - acc: 0.12 - ETA: 11s - loss: 3.7184 - acc: 0.12 - ETA: 11s - loss: 3.7328 - acc: 0.12 - ETA: 11s - loss: 3.7495 - acc: 0.11 - ETA: 11s - loss: 3.7518 - acc: 0.11 - ETA: 10s - loss: 3.7581 - acc: 0.11 - ETA: 10s - loss: 3.7677 - acc: 0.11 - ETA: 10s - loss: 3.7816 - acc: 0.10 - ETA: 10s - loss: 3.7735 - acc: 0.11 - ETA: 10s - loss: 3.7641 - acc: 0.11 - ETA: 10s - loss: 3.7674 - acc: 0.11 - ETA: 10s - loss: 3.7813 - acc: 0.11 - ETA: 10s - loss: 3.7857 - acc: 0.11 - ETA: 10s - loss: 3.7836 - acc: 0.11 - ETA: 10s - loss: 3.7876 - acc: 0.11 - ETA: 10s - loss: 3.7840 - acc: 0.11 - ETA: 10s - loss: 3.7855 - acc: 0.11 - ETA: 10s - loss: 3.7932 - acc: 0.11 - ETA: 10s - loss: 3.7936 - acc: 0.11 - ETA: 10s - loss: 3.7918 - acc: 0.11 - ETA: 9s - loss: 3.7938 - acc: 0.1167 - ETA: 9s - loss: 3.8016 - acc: 0.116 - ETA: 9s - loss: 3.8060 - acc: 0.114 - ETA: 9s - loss: 3.8050 - acc: 0.113 - ETA: 9s - loss: 3.8023 - acc: 0.113 - ETA: 9s - loss: 3.7917 - acc: 0.114 - ETA: 9s - loss: 3.7897 - acc: 0.114 - ETA: 9s - loss: 3.7879 - acc: 0.115 - ETA: 9s - loss: 3.7964 - acc: 0.114 - ETA: 9s - loss: 3.7912 - acc: 0.113 - ETA: 9s - loss: 3.8026 - acc: 0.113 - ETA: 9s - loss: 3.8070 - acc: 0.114 - ETA: 8s - loss: 3.8113 - acc: 0.113 - ETA: 8s - loss: 3.8097 - acc: 0.113 - ETA: 8s - loss: 3.8054 - acc: 0.114 - ETA: 8s - loss: 3.8045 - acc: 0.114 - ETA: 8s - loss: 3.8039 - acc: 0.116 - ETA: 8s - loss: 3.8021 - acc: 0.115 - ETA: 8s - loss: 3.8041 - acc: 0.115 - ETA: 8s - loss: 3.8086 - acc: 0.115 - ETA: 8s - loss: 3.8060 - acc: 0.115 - ETA: 8s - loss: 3.8054 - acc: 0.115 - ETA: 8s - loss: 3.8052 - acc: 0.117 - ETA: 8s - loss: 3.8127 - acc: 0.117 - ETA: 8s - loss: 3.8097 - acc: 0.118 - ETA: 7s - loss: 3.8083 - acc: 0.118 - ETA: 7s - loss: 3.8079 - acc: 0.117 - ETA: 7s - loss: 3.8110 - acc: 0.116 - ETA: 7s - loss: 3.8100 - acc: 0.116 - ETA: 7s - loss: 3.8130 - acc: 0.115 - ETA: 7s - loss: 3.8107 - acc: 0.114 - ETA: 7s - loss: 3.8073 - acc: 0.116 - ETA: 7s - loss: 3.8058 - acc: 0.115 - ETA: 7s - loss: 3.8109 - acc: 0.115 - ETA: 7s - loss: 3.8135 - acc: 0.116 - ETA: 7s - loss: 3.8128 - acc: 0.116 - ETA: 7s - loss: 3.8178 - acc: 0.116 - ETA: 7s - loss: 3.8132 - acc: 0.117 - ETA: 7s - loss: 3.8183 - acc: 0.117 - ETA: 6s - loss: 3.8206 - acc: 0.117 - ETA: 6s - loss: 3.8188 - acc: 0.116 - ETA: 6s - loss: 3.8165 - acc: 0.117 - ETA: 6s - loss: 3.8137 - acc: 0.116 - ETA: 6s - loss: 3.8116 - acc: 0.117 - ETA: 6s - loss: 3.8138 - acc: 0.116 - ETA: 6s - loss: 3.8208 - acc: 0.116 - ETA: 6s - loss: 3.8219 - acc: 0.114 - ETA: 6s - loss: 3.8243 - acc: 0.113 - ETA: 6s - loss: 3.8257 - acc: 0.112 - ETA: 6s - loss: 3.8258 - acc: 0.112 - ETA: 6s - loss: 3.8225 - acc: 0.113 - ETA: 6s - loss: 3.8238 - acc: 0.113 - ETA: 5s - loss: 3.8199 - acc: 0.114 - ETA: 5s - loss: 3.8203 - acc: 0.114 - ETA: 5s - loss: 3.8213 - acc: 0.114 - ETA: 5s - loss: 3.8206 - acc: 0.114 - ETA: 5s - loss: 3.8236 - acc: 0.114 - ETA: 5s - loss: 3.8228 - acc: 0.114 - ETA: 5s - loss: 3.8264 - acc: 0.114 - ETA: 5s - loss: 3.8248 - acc: 0.114 - ETA: 5s - loss: 3.8269 - acc: 0.115 - ETA: 5s - loss: 3.8232 - acc: 0.115 - ETA: 5s - loss: 3.8263 - acc: 0.115 - ETA: 5s - loss: 3.8261 - acc: 0.116 - ETA: 5s - loss: 3.8270 - acc: 0.116 - ETA: 5s - loss: 3.8296 - acc: 0.116 - ETA: 4s - loss: 3.8318 - acc: 0.116 - ETA: 4s - loss: 3.8304 - acc: 0.117 - ET ...
#
# Epoch 00004: val_loss improved from 4.09582 to 4.08860, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 5/10
# 6680/6680 [==============================] - ETA: 18s - loss: 3.5704 - acc: 0.10 - ETA: 13s - loss: 3.2788 - acc: 0.18 - ETA: 13s - loss: 3.3932 - acc: 0.16 - ETA: 12s - loss: 3.3967 - acc: 0.16 - ETA: 12s - loss: 3.3938 - acc: 0.17 - ETA: 12s - loss: 3.5062 - acc: 0.16 - ETA: 12s - loss: 3.5366 - acc: 0.15 - ETA: 12s - loss: 3.4964 - acc: 0.17 - ETA: 12s - loss: 3.4841 - acc: 0.17 - ETA: 11s - loss: 3.4702 - acc: 0.17 - ETA: 11s - loss: 3.5019 - acc: 0.16 - ETA: 11s - loss: 3.5158 - acc: 0.16 - ETA: 11s - loss: 3.5104 - acc: 0.16 - ETA: 11s - loss: 3.4923 - acc: 0.16 - ETA: 11s - loss: 3.4715 - acc: 0.16 - ETA: 11s - loss: 3.4732 - acc: 0.16 - ETA: 11s - loss: 3.4500 - acc: 0.15 - ETA: 11s - loss: 3.4595 - acc: 0.15 - ETA: 11s - loss: 3.4639 - acc: 0.15 - ETA: 11s - loss: 3.4740 - acc: 0.15 - ETA: 11s - loss: 3.4518 - acc: 0.16 - ETA: 11s - loss: 3.4422 - acc: 0.15 - ETA: 11s - loss: 3.4236 - acc: 0.16 - ETA: 11s - loss: 3.4331 - acc: 0.16 - ETA: 11s - loss: 3.4365 - acc: 0.16 - ETA: 10s - loss: 3.4285 - acc: 0.16 - ETA: 10s - loss: 3.4342 - acc: 0.16 - ETA: 10s - loss: 3.4405 - acc: 0.16 - ETA: 10s - loss: 3.4592 - acc: 0.16 - ETA: 10s - loss: 3.4570 - acc: 0.16 - ETA: 10s - loss: 3.4569 - acc: 0.16 - ETA: 10s - loss: 3.4528 - acc: 0.16 - ETA: 10s - loss: 3.4561 - acc: 0.16 - ETA: 10s - loss: 3.4638 - acc: 0.16 - ETA: 10s - loss: 3.4694 - acc: 0.16 - ETA: 10s - loss: 3.4669 - acc: 0.16 - ETA: 9s - loss: 3.4550 - acc: 0.1674 - ETA: 9s - loss: 3.4508 - acc: 0.167 - ETA: 9s - loss: 3.4528 - acc: 0.169 - ETA: 9s - loss: 3.4524 - acc: 0.170 - ETA: 9s - loss: 3.4549 - acc: 0.171 - ETA: 9s - loss: 3.4563 - acc: 0.170 - ETA: 9s - loss: 3.4527 - acc: 0.171 - ETA: 9s - loss: 3.4511 - acc: 0.171 - ETA: 9s - loss: 3.4413 - acc: 0.172 - ETA: 9s - loss: 3.4404 - acc: 0.172 - ETA: 9s - loss: 3.4326 - acc: 0.172 - ETA: 9s - loss: 3.4392 - acc: 0.173 - ETA: 9s - loss: 3.4365 - acc: 0.175 - ETA: 8s - loss: 3.4415 - acc: 0.175 - ETA: 8s - loss: 3.4371 - acc: 0.175 - ETA: 8s - loss: 3.4374 - acc: 0.177 - ETA: 8s - loss: 3.4412 - acc: 0.177 - ETA: 8s - loss: 3.4437 - acc: 0.178 - ETA: 8s - loss: 3.4447 - acc: 0.175 - ETA: 8s - loss: 3.4441 - acc: 0.177 - ETA: 8s - loss: 3.4420 - acc: 0.178 - ETA: 8s - loss: 3.4409 - acc: 0.178 - ETA: 8s - loss: 3.4426 - acc: 0.177 - ETA: 8s - loss: 3.4451 - acc: 0.176 - ETA: 8s - loss: 3.4502 - acc: 0.176 - ETA: 8s - loss: 3.4516 - acc: 0.175 - ETA: 7s - loss: 3.4594 - acc: 0.174 - ETA: 7s - loss: 3.4637 - acc: 0.175 - ETA: 7s - loss: 3.4652 - acc: 0.176 - ETA: 7s - loss: 3.4662 - acc: 0.174 - ETA: 7s - loss: 3.4634 - acc: 0.175 - ETA: 7s - loss: 3.4629 - acc: 0.175 - ETA: 7s - loss: 3.4642 - acc: 0.174 - ETA: 7s - loss: 3.4660 - acc: 0.174 - ETA: 7s - loss: 3.4653 - acc: 0.174 - ETA: 7s - loss: 3.4698 - acc: 0.173 - ETA: 7s - loss: 3.4686 - acc: 0.173 - ETA: 7s - loss: 3.4631 - acc: 0.174 - ETA: 7s - loss: 3.4644 - acc: 0.173 - ETA: 6s - loss: 3.4676 - acc: 0.174 - ETA: 6s - loss: 3.4671 - acc: 0.174 - ETA: 6s - loss: 3.4707 - acc: 0.174 - ETA: 6s - loss: 3.4725 - acc: 0.173 - ETA: 6s - loss: 3.4717 - acc: 0.174 - ETA: 6s - loss: 3.4731 - acc: 0.173 - ETA: 6s - loss: 3.4727 - acc: 0.174 - ETA: 6s - loss: 3.4730 - acc: 0.174 - ETA: 6s - loss: 3.4709 - acc: 0.175 - ETA: 6s - loss: 3.4678 - acc: 0.175 - ETA: 6s - loss: 3.4721 - acc: 0.175 - ETA: 6s - loss: 3.4742 - acc: 0.175 - ETA: 6s - loss: 3.4753 - acc: 0.175 - ETA: 6s - loss: 3.4763 - acc: 0.174 - ETA: 5s - loss: 3.4726 - acc: 0.174 - ETA: 5s - loss: 3.4744 - acc: 0.176 - ETA: 5s - loss: 3.4766 - acc: 0.175 - ETA: 5s - loss: 3.4737 - acc: 0.176 - ETA: 5s - loss: 3.4724 - acc: 0.175 - ETA: 5s - loss: 3.4686 - acc: 0.176 - ETA: 5s - loss: 3.4669 - acc: 0.176 - ETA: 5s - loss: 3.4719 - acc: 0.175 - ETA: 5s - loss: 3.4698 - acc: 0.175 - ETA: 5s - loss: 3.4671 - acc: 0.175 - ETA: 5s - loss: 3.4733 - acc: 0.174 - ETA: 5s - loss: 3.4698 - acc: 0.175 - ETA: 5s - loss: 3.4651 - acc: 0.178 - ETA: 4s - loss: 3.4666 - acc: 0.177 - ETA: 4s - loss: 3.4658 - acc: 0.177 - ET ...
#
# Epoch 00005: val_loss improved from 4.08860 to 3.99111, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 6/10
# 6680/6680 [==============================] - ETA: 13s - loss: 2.9614 - acc: 0.30 - ETA: 12s - loss: 2.9678 - acc: 0.31 - ETA: 12s - loss: 3.0152 - acc: 0.31 - ETA: 12s - loss: 2.9571 - acc: 0.30 - ETA: 12s - loss: 3.0126 - acc: 0.29 - ETA: 12s - loss: 3.0531 - acc: 0.27 - ETA: 12s - loss: 3.0226 - acc: 0.26 - ETA: 12s - loss: 2.9867 - acc: 0.28 - ETA: 12s - loss: 3.0250 - acc: 0.25 - ETA: 12s - loss: 3.0047 - acc: 0.25 - ETA: 12s - loss: 2.9805 - acc: 0.26 - ETA: 11s - loss: 2.9821 - acc: 0.27 - ETA: 11s - loss: 2.9892 - acc: 0.27 - ETA: 11s - loss: 2.9972 - acc: 0.27 - ETA: 11s - loss: 2.9858 - acc: 0.27 - ETA: 11s - loss: 2.9994 - acc: 0.27 - ETA: 11s - loss: 2.9999 - acc: 0.26 - ETA: 11s - loss: 3.0124 - acc: 0.26 - ETA: 11s - loss: 3.0278 - acc: 0.26 - ETA: 11s - loss: 3.0068 - acc: 0.26 - ETA: 11s - loss: 2.9966 - acc: 0.27 - ETA: 10s - loss: 2.9713 - acc: 0.27 - ETA: 10s - loss: 2.9532 - acc: 0.28 - ETA: 10s - loss: 2.9465 - acc: 0.27 - ETA: 10s - loss: 2.9371 - acc: 0.28 - ETA: 10s - loss: 2.9475 - acc: 0.28 - ETA: 10s - loss: 2.9419 - acc: 0.28 - ETA: 10s - loss: 2.9460 - acc: 0.28 - ETA: 10s - loss: 2.9613 - acc: 0.28 - ETA: 10s - loss: 2.9615 - acc: 0.28 - ETA: 10s - loss: 2.9517 - acc: 0.28 - ETA: 10s - loss: 2.9474 - acc: 0.28 - ETA: 10s - loss: 2.9477 - acc: 0.28 - ETA: 9s - loss: 2.9611 - acc: 0.2806 - ETA: 9s - loss: 2.9795 - acc: 0.276 - ETA: 9s - loss: 2.9847 - acc: 0.276 - ETA: 9s - loss: 2.9866 - acc: 0.276 - ETA: 9s - loss: 2.9747 - acc: 0.281 - ETA: 9s - loss: 2.9737 - acc: 0.282 - ETA: 9s - loss: 2.9726 - acc: 0.281 - ETA: 9s - loss: 2.9778 - acc: 0.279 - ETA: 9s - loss: 2.9742 - acc: 0.278 - ETA: 9s - loss: 2.9858 - acc: 0.275 - ETA: 9s - loss: 2.9935 - acc: 0.273 - ETA: 9s - loss: 2.9904 - acc: 0.274 - ETA: 9s - loss: 2.9881 - acc: 0.275 - ETA: 8s - loss: 2.9939 - acc: 0.275 - ETA: 8s - loss: 2.9917 - acc: 0.275 - ETA: 8s - loss: 3.0045 - acc: 0.273 - ETA: 8s - loss: 3.0120 - acc: 0.271 - ETA: 8s - loss: 3.0139 - acc: 0.270 - ETA: 8s - loss: 3.0190 - acc: 0.270 - ETA: 8s - loss: 3.0227 - acc: 0.269 - ETA: 8s - loss: 3.0207 - acc: 0.269 - ETA: 8s - loss: 3.0183 - acc: 0.268 - ETA: 8s - loss: 3.0164 - acc: 0.268 - ETA: 8s - loss: 3.0084 - acc: 0.269 - ETA: 8s - loss: 3.0144 - acc: 0.268 - ETA: 8s - loss: 3.0174 - acc: 0.267 - ETA: 7s - loss: 3.0084 - acc: 0.270 - ETA: 7s - loss: 3.0099 - acc: 0.270 - ETA: 7s - loss: 3.0053 - acc: 0.270 - ETA: 7s - loss: 3.0070 - acc: 0.269 - ETA: 7s - loss: 3.0101 - acc: 0.268 - ETA: 7s - loss: 3.0089 - acc: 0.268 - ETA: 7s - loss: 3.0087 - acc: 0.267 - ETA: 7s - loss: 3.0139 - acc: 0.266 - ETA: 7s - loss: 3.0156 - acc: 0.267 - ETA: 7s - loss: 3.0113 - acc: 0.267 - ETA: 7s - loss: 3.0112 - acc: 0.268 - ETA: 7s - loss: 3.0104 - acc: 0.267 - ETA: 7s - loss: 3.0067 - acc: 0.268 - ETA: 7s - loss: 3.0055 - acc: 0.269 - ETA: 6s - loss: 2.9998 - acc: 0.271 - ETA: 6s - loss: 3.0056 - acc: 0.270 - ETA: 6s - loss: 3.0075 - acc: 0.270 - ETA: 6s - loss: 3.0041 - acc: 0.270 - ETA: 6s - loss: 2.9955 - acc: 0.274 - ETA: 6s - loss: 2.9928 - acc: 0.274 - ETA: 6s - loss: 2.9930 - acc: 0.275 - ETA: 6s - loss: 2.9975 - acc: 0.274 - ETA: 6s - loss: 2.9992 - acc: 0.274 - ETA: 6s - loss: 2.9986 - acc: 0.273 - ETA: 6s - loss: 3.0009 - acc: 0.273 - ETA: 6s - loss: 2.9999 - acc: 0.273 - ETA: 6s - loss: 2.9960 - acc: 0.275 - ETA: 5s - loss: 2.9918 - acc: 0.276 - ETA: 5s - loss: 2.9871 - acc: 0.277 - ETA: 5s - loss: 2.9891 - acc: 0.277 - ETA: 5s - loss: 2.9869 - acc: 0.277 - ETA: 5s - loss: 2.9921 - acc: 0.277 - ETA: 5s - loss: 2.9904 - acc: 0.277 - ETA: 5s - loss: 2.9978 - acc: 0.275 - ETA: 5s - loss: 2.9982 - acc: 0.275 - ETA: 5s - loss: 2.9981 - acc: 0.275 - ETA: 5s - loss: 2.9976 - acc: 0.275 - ETA: 5s - loss: 3.0005 - acc: 0.275 - ETA: 5s - loss: 3.0041 - acc: 0.274 - ETA: 5s - loss: 3.0049 - acc: 0.274 - ETA: 4s - loss: 3.0034 - acc: 0.274 - ETA: 4s - loss: 3.0060 - acc: 0.273 - ETA: 4s - loss: 3.0068 - acc: 0.274 - ETA: 4s - loss: 3.0042 - acc: 0.274 - ETA: 4s - loss: 3.0034 - acc: 0.275 - ET ...
#
# Epoch 00006: val_loss improved from 3.99111 to 3.94497, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 7/10
# 6680/6680 [==============================] - ETA: 11s - loss: 2.3931 - acc: 0.40 - ETA: 11s - loss: 2.4840 - acc: 0.35 - ETA: 11s - loss: 2.4581 - acc: 0.39 - ETA: 11s - loss: 2.4968 - acc: 0.36 - ETA: 11s - loss: 2.4547 - acc: 0.37 - ETA: 11s - loss: 2.4371 - acc: 0.37 - ETA: 11s - loss: 2.4047 - acc: 0.40 - ETA: 11s - loss: 2.4677 - acc: 0.37 - ETA: 11s - loss: 2.4355 - acc: 0.38 - ETA: 11s - loss: 2.4392 - acc: 0.37 - ETA: 11s - loss: 2.4357 - acc: 0.36 - ETA: 11s - loss: 2.4403 - acc: 0.37 - ETA: 11s - loss: 2.4718 - acc: 0.36 - ETA: 11s - loss: 2.4806 - acc: 0.37 - ETA: 11s - loss: 2.4889 - acc: 0.37 - ETA: 11s - loss: 2.4602 - acc: 0.37 - ETA: 11s - loss: 2.4627 - acc: 0.37 - ETA: 10s - loss: 2.4554 - acc: 0.37 - ETA: 10s - loss: 2.4608 - acc: 0.38 - ETA: 10s - loss: 2.4553 - acc: 0.38 - ETA: 10s - loss: 2.4727 - acc: 0.37 - ETA: 10s - loss: 2.4891 - acc: 0.37 - ETA: 10s - loss: 2.4917 - acc: 0.37 - ETA: 10s - loss: 2.4841 - acc: 0.37 - ETA: 10s - loss: 2.4731 - acc: 0.37 - ETA: 10s - loss: 2.4630 - acc: 0.37 - ETA: 10s - loss: 2.4587 - acc: 0.37 - ETA: 10s - loss: 2.4664 - acc: 0.37 - ETA: 10s - loss: 2.4578 - acc: 0.37 - ETA: 10s - loss: 2.4672 - acc: 0.37 - ETA: 9s - loss: 2.4666 - acc: 0.3713 - ETA: 9s - loss: 2.4606 - acc: 0.369 - ETA: 9s - loss: 2.4600 - acc: 0.370 - ETA: 9s - loss: 2.4597 - acc: 0.370 - ETA: 9s - loss: 2.4596 - acc: 0.370 - ETA: 9s - loss: 2.4663 - acc: 0.369 - ETA: 9s - loss: 2.4711 - acc: 0.369 - ETA: 9s - loss: 2.4842 - acc: 0.368 - ETA: 9s - loss: 2.4917 - acc: 0.366 - ETA: 9s - loss: 2.4909 - acc: 0.367 - ETA: 9s - loss: 2.4873 - acc: 0.367 - ETA: 9s - loss: 2.4978 - acc: 0.366 - ETA: 9s - loss: 2.4906 - acc: 0.370 - ETA: 8s - loss: 2.4852 - acc: 0.371 - ETA: 8s - loss: 2.4878 - acc: 0.371 - ETA: 8s - loss: 2.4944 - acc: 0.370 - ETA: 8s - loss: 2.4891 - acc: 0.372 - ETA: 8s - loss: 2.4883 - acc: 0.371 - ETA: 8s - loss: 2.4917 - acc: 0.370 - ETA: 8s - loss: 2.5022 - acc: 0.368 - ETA: 8s - loss: 2.5097 - acc: 0.367 - ETA: 8s - loss: 2.5165 - acc: 0.365 - ETA: 8s - loss: 2.5160 - acc: 0.364 - ETA: 8s - loss: 2.5151 - acc: 0.364 - ETA: 8s - loss: 2.5208 - acc: 0.363 - ETA: 8s - loss: 2.5227 - acc: 0.363 - ETA: 8s - loss: 2.5292 - acc: 0.362 - ETA: 7s - loss: 2.5273 - acc: 0.362 - ETA: 7s - loss: 2.5322 - acc: 0.363 - ETA: 7s - loss: 2.5275 - acc: 0.365 - ETA: 7s - loss: 2.5270 - acc: 0.366 - ETA: 7s - loss: 2.5282 - acc: 0.366 - ETA: 7s - loss: 2.5341 - acc: 0.365 - ETA: 7s - loss: 2.5401 - acc: 0.363 - ETA: 7s - loss: 2.5407 - acc: 0.364 - ETA: 7s - loss: 2.5380 - acc: 0.364 - ETA: 7s - loss: 2.5397 - acc: 0.365 - ETA: 7s - loss: 2.5375 - acc: 0.366 - ETA: 7s - loss: 2.5419 - acc: 0.364 - ETA: 7s - loss: 2.5416 - acc: 0.364 - ETA: 6s - loss: 2.5333 - acc: 0.366 - ETA: 6s - loss: 2.5353 - acc: 0.366 - ETA: 6s - loss: 2.5297 - acc: 0.368 - ETA: 6s - loss: 2.5276 - acc: 0.368 - ETA: 6s - loss: 2.5247 - acc: 0.368 - ETA: 6s - loss: 2.5235 - acc: 0.368 - ETA: 6s - loss: 2.5246 - acc: 0.368 - ETA: 6s - loss: 2.5255 - acc: 0.368 - ETA: 6s - loss: 2.5245 - acc: 0.369 - ETA: 6s - loss: 2.5288 - acc: 0.369 - ETA: 6s - loss: 2.5237 - acc: 0.370 - ETA: 6s - loss: 2.5244 - acc: 0.371 - ETA: 6s - loss: 2.5264 - acc: 0.371 - ETA: 6s - loss: 2.5233 - acc: 0.372 - ETA: 6s - loss: 2.5240 - acc: 0.373 - ETA: 5s - loss: 2.5272 - acc: 0.373 - ETA: 5s - loss: 2.5293 - acc: 0.373 - ETA: 5s - loss: 2.5339 - acc: 0.372 - ETA: 5s - loss: 2.5312 - acc: 0.373 - ETA: 5s - loss: 2.5271 - acc: 0.375 - ETA: 5s - loss: 2.5292 - acc: 0.375 - ETA: 5s - loss: 2.5322 - acc: 0.374 - ETA: 5s - loss: 2.5371 - acc: 0.372 - ETA: 5s - loss: 2.5410 - acc: 0.371 - ETA: 5s - loss: 2.5418 - acc: 0.371 - ETA: 5s - loss: 2.5417 - acc: 0.371 - ETA: 5s - loss: 2.5363 - acc: 0.372 - ETA: 5s - loss: 2.5387 - acc: 0.371 - ETA: 5s - loss: 2.5367 - acc: 0.372 - ETA: 4s - loss: 2.5346 - acc: 0.372 - ETA: 4s - loss: 2.5353 - acc: 0.372 - ETA: 4s - loss: 2.5348 - acc: 0.371 - ETA: 4s - loss: 2.5367 - acc: 0.371 - ETA: 4s - loss: 2.5328 - acc: 0.372 - ET ...
#
# Epoch 00007: val_loss did not improve from 3.94497
# Epoch 8/10
# 6680/6680 [==============================] - ETA: 13s - loss: 2.3526 - acc: 0.40 - ETA: 12s - loss: 2.4186 - acc: 0.38 - ETA: 12s - loss: 2.2840 - acc: 0.43 - ETA: 11s - loss: 2.3427 - acc: 0.40 - ETA: 12s - loss: 2.2382 - acc: 0.42 - ETA: 11s - loss: 2.2087 - acc: 0.45 - ETA: 11s - loss: 2.1557 - acc: 0.45 - ETA: 11s - loss: 2.1628 - acc: 0.46 - ETA: 11s - loss: 2.1723 - acc: 0.46 - ETA: 11s - loss: 2.1115 - acc: 0.47 - ETA: 11s - loss: 2.0660 - acc: 0.49 - ETA: 11s - loss: 2.0576 - acc: 0.48 - ETA: 11s - loss: 2.0535 - acc: 0.48 - ETA: 11s - loss: 2.0419 - acc: 0.48 - ETA: 11s - loss: 2.0141 - acc: 0.49 - ETA: 11s - loss: 2.0270 - acc: 0.49 - ETA: 11s - loss: 2.0217 - acc: 0.48 - ETA: 11s - loss: 2.0247 - acc: 0.48 - ETA: 10s - loss: 2.0469 - acc: 0.47 - ETA: 10s - loss: 2.0510 - acc: 0.47 - ETA: 10s - loss: 2.0419 - acc: 0.48 - ETA: 10s - loss: 2.0554 - acc: 0.47 - ETA: 10s - loss: 2.0607 - acc: 0.47 - ETA: 10s - loss: 2.0544 - acc: 0.47 - ETA: 10s - loss: 2.0454 - acc: 0.47 - ETA: 10s - loss: 2.0366 - acc: 0.48 - ETA: 10s - loss: 2.0239 - acc: 0.48 - ETA: 10s - loss: 2.0142 - acc: 0.48 - ETA: 10s - loss: 2.0155 - acc: 0.48 - ETA: 10s - loss: 2.0100 - acc: 0.48 - ETA: 10s - loss: 2.0143 - acc: 0.48 - ETA: 10s - loss: 2.0183 - acc: 0.48 - ETA: 9s - loss: 2.0049 - acc: 0.4885 - ETA: 9s - loss: 1.9977 - acc: 0.488 - ETA: 9s - loss: 2.0099 - acc: 0.485 - ETA: 9s - loss: 2.0073 - acc: 0.483 - ETA: 9s - loss: 2.0106 - acc: 0.484 - ETA: 9s - loss: 2.0045 - acc: 0.485 - ETA: 9s - loss: 2.0002 - acc: 0.486 - ETA: 9s - loss: 2.0070 - acc: 0.486 - ETA: 9s - loss: 2.0062 - acc: 0.485 - ETA: 9s - loss: 2.0016 - acc: 0.486 - ETA: 9s - loss: 2.0020 - acc: 0.487 - ETA: 9s - loss: 2.0058 - acc: 0.487 - ETA: 9s - loss: 1.9869 - acc: 0.492 - ETA: 8s - loss: 1.9927 - acc: 0.491 - ETA: 8s - loss: 1.9912 - acc: 0.489 - ETA: 8s - loss: 1.9925 - acc: 0.488 - ETA: 8s - loss: 1.9925 - acc: 0.488 - ETA: 8s - loss: 1.9913 - acc: 0.488 - ETA: 8s - loss: 1.9897 - acc: 0.490 - ETA: 8s - loss: 1.9919 - acc: 0.488 - ETA: 8s - loss: 1.9945 - acc: 0.487 - ETA: 8s - loss: 1.9902 - acc: 0.487 - ETA: 8s - loss: 1.9857 - acc: 0.488 - ETA: 8s - loss: 1.9880 - acc: 0.489 - ETA: 8s - loss: 2.0005 - acc: 0.487 - ETA: 8s - loss: 2.0025 - acc: 0.487 - ETA: 8s - loss: 2.0065 - acc: 0.487 - ETA: 7s - loss: 2.0038 - acc: 0.486 - ETA: 7s - loss: 2.0036 - acc: 0.485 - ETA: 7s - loss: 1.9956 - acc: 0.487 - ETA: 7s - loss: 1.9965 - acc: 0.487 - ETA: 7s - loss: 1.9996 - acc: 0.487 - ETA: 7s - loss: 2.0053 - acc: 0.486 - ETA: 7s - loss: 2.0026 - acc: 0.487 - ETA: 7s - loss: 1.9980 - acc: 0.488 - ETA: 7s - loss: 2.0027 - acc: 0.487 - ETA: 7s - loss: 2.0054 - acc: 0.486 - ETA: 7s - loss: 2.0025 - acc: 0.487 - ETA: 7s - loss: 2.0055 - acc: 0.486 - ETA: 7s - loss: 2.0053 - acc: 0.486 - ETA: 6s - loss: 2.0074 - acc: 0.486 - ETA: 6s - loss: 2.0087 - acc: 0.485 - ETA: 6s - loss: 2.0010 - acc: 0.485 - ETA: 6s - loss: 2.0031 - acc: 0.485 - ETA: 6s - loss: 2.0062 - acc: 0.484 - ETA: 6s - loss: 2.0027 - acc: 0.485 - ETA: 6s - loss: 2.0088 - acc: 0.484 - ETA: 6s - loss: 2.0035 - acc: 0.486 - ETA: 6s - loss: 2.0083 - acc: 0.485 - ETA: 6s - loss: 2.0040 - acc: 0.485 - ETA: 6s - loss: 2.0029 - acc: 0.484 - ETA: 6s - loss: 2.0071 - acc: 0.483 - ETA: 6s - loss: 2.0100 - acc: 0.483 - ETA: 6s - loss: 2.0106 - acc: 0.482 - ETA: 5s - loss: 2.0104 - acc: 0.482 - ETA: 5s - loss: 2.0105 - acc: 0.481 - ETA: 5s - loss: 2.0094 - acc: 0.481 - ETA: 5s - loss: 2.0132 - acc: 0.479 - ETA: 5s - loss: 2.0173 - acc: 0.478 - ETA: 5s - loss: 2.0168 - acc: 0.478 - ETA: 5s - loss: 2.0219 - acc: 0.477 - ETA: 5s - loss: 2.0231 - acc: 0.477 - ETA: 5s - loss: 2.0290 - acc: 0.475 - ETA: 5s - loss: 2.0305 - acc: 0.475 - ETA: 5s - loss: 2.0333 - acc: 0.474 - ETA: 5s - loss: 2.0345 - acc: 0.474 - ETA: 5s - loss: 2.0325 - acc: 0.474 - ETA: 5s - loss: 2.0366 - acc: 0.473 - ETA: 4s - loss: 2.0366 - acc: 0.472 - ETA: 4s - loss: 2.0345 - acc: 0.472 - ETA: 4s - loss: 2.0332 - acc: 0.472 - ETA: 4s - loss: 2.0384 - acc: 0.472 - ET ...
#
# Epoch 00008: val_loss did not improve from 3.94497
# Epoch 9/10
# 6680/6680 [==============================] - ETA: 13s - loss: 1.7685 - acc: 0.55 - ETA: 12s - loss: 1.5076 - acc: 0.56 - ETA: 12s - loss: 1.4250 - acc: 0.60 - ETA: 12s - loss: 1.3971 - acc: 0.62 - ETA: 11s - loss: 1.4115 - acc: 0.63 - ETA: 11s - loss: 1.3886 - acc: 0.64 - ETA: 11s - loss: 1.3497 - acc: 0.65 - ETA: 11s - loss: 1.3642 - acc: 0.64 - ETA: 11s - loss: 1.3785 - acc: 0.64 - ETA: 11s - loss: 1.3785 - acc: 0.64 - ETA: 11s - loss: 1.4435 - acc: 0.63 - ETA: 11s - loss: 1.4223 - acc: 0.63 - ETA: 11s - loss: 1.4047 - acc: 0.63 - ETA: 11s - loss: 1.4278 - acc: 0.62 - ETA: 11s - loss: 1.4227 - acc: 0.62 - ETA: 11s - loss: 1.4523 - acc: 0.61 - ETA: 10s - loss: 1.4599 - acc: 0.61 - ETA: 10s - loss: 1.4592 - acc: 0.62 - ETA: 10s - loss: 1.4450 - acc: 0.62 - ETA: 10s - loss: 1.4399 - acc: 0.62 - ETA: 10s - loss: 1.4337 - acc: 0.62 - ETA: 10s - loss: 1.4358 - acc: 0.62 - ETA: 10s - loss: 1.4464 - acc: 0.62 - ETA: 10s - loss: 1.4460 - acc: 0.62 - ETA: 10s - loss: 1.4465 - acc: 0.62 - ETA: 10s - loss: 1.4555 - acc: 0.62 - ETA: 10s - loss: 1.4818 - acc: 0.62 - ETA: 10s - loss: 1.4839 - acc: 0.61 - ETA: 10s - loss: 1.4750 - acc: 0.61 - ETA: 10s - loss: 1.4817 - acc: 0.61 - ETA: 10s - loss: 1.4836 - acc: 0.60 - ETA: 9s - loss: 1.4838 - acc: 0.6111 - ETA: 9s - loss: 1.4982 - acc: 0.606 - ETA: 9s - loss: 1.4889 - acc: 0.609 - ETA: 9s - loss: 1.4846 - acc: 0.609 - ETA: 9s - loss: 1.4804 - acc: 0.610 - ETA: 9s - loss: 1.4873 - acc: 0.609 - ETA: 9s - loss: 1.4858 - acc: 0.609 - ETA: 9s - loss: 1.4729 - acc: 0.611 - ETA: 9s - loss: 1.4636 - acc: 0.613 - ETA: 9s - loss: 1.4716 - acc: 0.609 - ETA: 9s - loss: 1.4666 - acc: 0.610 - ETA: 9s - loss: 1.4669 - acc: 0.609 - ETA: 8s - loss: 1.4806 - acc: 0.606 - ETA: 8s - loss: 1.4775 - acc: 0.607 - ETA: 8s - loss: 1.4782 - acc: 0.608 - ETA: 8s - loss: 1.4791 - acc: 0.610 - ETA: 8s - loss: 1.4812 - acc: 0.608 - ETA: 8s - loss: 1.4848 - acc: 0.609 - ETA: 8s - loss: 1.4957 - acc: 0.608 - ETA: 8s - loss: 1.4953 - acc: 0.608 - ETA: 8s - loss: 1.4959 - acc: 0.610 - ETA: 8s - loss: 1.4890 - acc: 0.612 - ETA: 8s - loss: 1.4869 - acc: 0.613 - ETA: 8s - loss: 1.4905 - acc: 0.611 - ETA: 8s - loss: 1.4919 - acc: 0.611 - ETA: 8s - loss: 1.4989 - acc: 0.609 - ETA: 7s - loss: 1.5010 - acc: 0.608 - ETA: 7s - loss: 1.5019 - acc: 0.608 - ETA: 7s - loss: 1.5092 - acc: 0.605 - ETA: 7s - loss: 1.5157 - acc: 0.603 - ETA: 7s - loss: 1.5212 - acc: 0.602 - ETA: 7s - loss: 1.5204 - acc: 0.601 - ETA: 7s - loss: 1.5255 - acc: 0.598 - ETA: 7s - loss: 1.5225 - acc: 0.598 - ETA: 7s - loss: 1.5197 - acc: 0.598 - ETA: 7s - loss: 1.5202 - acc: 0.597 - ETA: 7s - loss: 1.5260 - acc: 0.596 - ETA: 7s - loss: 1.5262 - acc: 0.595 - ETA: 7s - loss: 1.5316 - acc: 0.595 - ETA: 7s - loss: 1.5273 - acc: 0.597 - ETA: 6s - loss: 1.5270 - acc: 0.597 - ETA: 6s - loss: 1.5297 - acc: 0.596 - ETA: 6s - loss: 1.5296 - acc: 0.595 - ETA: 6s - loss: 1.5263 - acc: 0.595 - ETA: 6s - loss: 1.5267 - acc: 0.595 - ETA: 6s - loss: 1.5316 - acc: 0.594 - ETA: 6s - loss: 1.5336 - acc: 0.594 - ETA: 6s - loss: 1.5373 - acc: 0.592 - ETA: 6s - loss: 1.5346 - acc: 0.593 - ETA: 6s - loss: 1.5440 - acc: 0.592 - ETA: 6s - loss: 1.5453 - acc: 0.592 - ETA: 6s - loss: 1.5524 - acc: 0.590 - ETA: 6s - loss: 1.5573 - acc: 0.590 - ETA: 5s - loss: 1.5536 - acc: 0.591 - ETA: 5s - loss: 1.5582 - acc: 0.591 - ETA: 5s - loss: 1.5590 - acc: 0.592 - ETA: 5s - loss: 1.5599 - acc: 0.591 - ETA: 5s - loss: 1.5597 - acc: 0.590 - ETA: 5s - loss: 1.5567 - acc: 0.591 - ETA: 5s - loss: 1.5568 - acc: 0.590 - ETA: 5s - loss: 1.5555 - acc: 0.591 - ETA: 5s - loss: 1.5592 - acc: 0.590 - ETA: 5s - loss: 1.5612 - acc: 0.589 - ETA: 5s - loss: 1.5650 - acc: 0.588 - ETA: 5s - loss: 1.5673 - acc: 0.588 - ETA: 5s - loss: 1.5668 - acc: 0.588 - ETA: 5s - loss: 1.5726 - acc: 0.588 - ETA: 4s - loss: 1.5724 - acc: 0.587 - ETA: 4s - loss: 1.5697 - acc: 0.586 - ETA: 4s - loss: 1.5675 - acc: 0.587 - ETA: 4s - loss: 1.5650 - acc: 0.587 - ETA: 4s - loss: 1.5641 - acc: 0.587 - ETA: 4s - loss: 1.5616 - acc: 0.588 - ET ...
#
# Epoch 00009: val_loss did not improve from 3.94497
# Epoch 10/10
# 6680/6680 [==============================] - ETA: 13s - loss: 1.4571 - acc: 0.70 - ETA: 12s - loss: 1.3558 - acc: 0.63 - ETA: 12s - loss: 1.3234 - acc: 0.66 - ETA: 12s - loss: 1.3773 - acc: 0.62 - ETA: 11s - loss: 1.3726 - acc: 0.62 - ETA: 11s - loss: 1.3579 - acc: 0.64 - ETA: 11s - loss: 1.2770 - acc: 0.66 - ETA: 12s - loss: 1.2720 - acc: 0.66 - ETA: 12s - loss: 1.2495 - acc: 0.67 - ETA: 12s - loss: 1.2592 - acc: 0.67 - ETA: 12s - loss: 1.2062 - acc: 0.68 - ETA: 12s - loss: 1.1763 - acc: 0.68 - ETA: 12s - loss: 1.1730 - acc: 0.67 - ETA: 12s - loss: 1.1852 - acc: 0.67 - ETA: 11s - loss: 1.1823 - acc: 0.68 - ETA: 11s - loss: 1.1853 - acc: 0.67 - ETA: 11s - loss: 1.1750 - acc: 0.68 - ETA: 11s - loss: 1.2003 - acc: 0.67 - ETA: 11s - loss: 1.1749 - acc: 0.68 - ETA: 11s - loss: 1.1788 - acc: 0.67 - ETA: 11s - loss: 1.1647 - acc: 0.68 - ETA: 11s - loss: 1.1728 - acc: 0.67 - ETA: 11s - loss: 1.1956 - acc: 0.67 - ETA: 11s - loss: 1.1953 - acc: 0.67 - ETA: 11s - loss: 1.1943 - acc: 0.67 - ETA: 10s - loss: 1.1945 - acc: 0.68 - ETA: 10s - loss: 1.1885 - acc: 0.68 - ETA: 10s - loss: 1.1840 - acc: 0.68 - ETA: 10s - loss: 1.1698 - acc: 0.68 - ETA: 10s - loss: 1.1648 - acc: 0.68 - ETA: 10s - loss: 1.1655 - acc: 0.68 - ETA: 10s - loss: 1.1684 - acc: 0.67 - ETA: 10s - loss: 1.1709 - acc: 0.67 - ETA: 10s - loss: 1.1681 - acc: 0.68 - ETA: 10s - loss: 1.1623 - acc: 0.68 - ETA: 10s - loss: 1.1612 - acc: 0.68 - ETA: 10s - loss: 1.1694 - acc: 0.68 - ETA: 9s - loss: 1.1616 - acc: 0.6851 - ETA: 9s - loss: 1.1673 - acc: 0.686 - ETA: 9s - loss: 1.1699 - acc: 0.684 - ETA: 9s - loss: 1.1703 - acc: 0.685 - ETA: 9s - loss: 1.1745 - acc: 0.684 - ETA: 9s - loss: 1.1693 - acc: 0.685 - ETA: 9s - loss: 1.1785 - acc: 0.683 - ETA: 9s - loss: 1.1764 - acc: 0.683 - ETA: 9s - loss: 1.1762 - acc: 0.685 - ETA: 9s - loss: 1.1793 - acc: 0.683 - ETA: 9s - loss: 1.1810 - acc: 0.683 - ETA: 9s - loss: 1.1804 - acc: 0.685 - ETA: 9s - loss: 1.1835 - acc: 0.685 - ETA: 8s - loss: 1.1870 - acc: 0.684 - ETA: 8s - loss: 1.1966 - acc: 0.681 - ETA: 8s - loss: 1.1988 - acc: 0.680 - ETA: 8s - loss: 1.1964 - acc: 0.680 - ETA: 8s - loss: 1.2052 - acc: 0.679 - ETA: 8s - loss: 1.2046 - acc: 0.678 - ETA: 8s - loss: 1.1960 - acc: 0.679 - ETA: 8s - loss: 1.2030 - acc: 0.676 - ETA: 8s - loss: 1.1996 - acc: 0.677 - ETA: 8s - loss: 1.1967 - acc: 0.677 - ETA: 8s - loss: 1.2036 - acc: 0.675 - ETA: 8s - loss: 1.2030 - acc: 0.675 - ETA: 8s - loss: 1.2021 - acc: 0.675 - ETA: 7s - loss: 1.2010 - acc: 0.675 - ETA: 7s - loss: 1.2009 - acc: 0.675 - ETA: 7s - loss: 1.1991 - acc: 0.675 - ETA: 7s - loss: 1.1982 - acc: 0.675 - ETA: 7s - loss: 1.1955 - acc: 0.676 - ETA: 7s - loss: 1.1970 - acc: 0.675 - ETA: 7s - loss: 1.1964 - acc: 0.676 - ETA: 7s - loss: 1.2007 - acc: 0.673 - ETA: 7s - loss: 1.2073 - acc: 0.673 - ETA: 7s - loss: 1.2084 - acc: 0.672 - ETA: 7s - loss: 1.2050 - acc: 0.673 - ETA: 7s - loss: 1.2067 - acc: 0.672 - ETA: 6s - loss: 1.2126 - acc: 0.670 - ETA: 6s - loss: 1.2092 - acc: 0.671 - ETA: 6s - loss: 1.2087 - acc: 0.671 - ETA: 6s - loss: 1.2103 - acc: 0.671 - ETA: 6s - loss: 1.2095 - acc: 0.670 - ETA: 6s - loss: 1.2102 - acc: 0.671 - ETA: 6s - loss: 1.2109 - acc: 0.671 - ETA: 6s - loss: 1.2120 - acc: 0.670 - ETA: 6s - loss: 1.2105 - acc: 0.670 - ETA: 6s - loss: 1.2095 - acc: 0.670 - ETA: 6s - loss: 1.2136 - acc: 0.669 - ETA: 6s - loss: 1.2128 - acc: 0.670 - ETA: 6s - loss: 1.2142 - acc: 0.669 - ETA: 5s - loss: 1.2166 - acc: 0.669 - ETA: 5s - loss: 1.2187 - acc: 0.668 - ETA: 5s - loss: 1.2179 - acc: 0.668 - ETA: 5s - loss: 1.2210 - acc: 0.667 - ETA: 5s - loss: 1.2200 - acc: 0.667 - ETA: 5s - loss: 1.2179 - acc: 0.668 - ETA: 5s - loss: 1.2213 - acc: 0.668 - ETA: 5s - loss: 1.2274 - acc: 0.667 - ETA: 5s - loss: 1.2238 - acc: 0.667 - ETA: 5s - loss: 1.2267 - acc: 0.666 - ETA: 5s - loss: 1.2338 - acc: 0.665 - ETA: 5s - loss: 1.2328 - acc: 0.665 - ETA: 5s - loss: 1.2318 - acc: 0.665 - ETA: 4s - loss: 1.2340 - acc: 0.664 - ETA: 4s - loss: 1.2381 - acc: 0.664 - ETA: 4s - loss: 1.2370 - acc: 0.664 - ET ...
#
# Epoch 00010: val_loss did not improve from 3.94497

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 10.4067%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('data/bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6680/6680 [==============================] - ETA: 4:12 - loss: 14.3149 - acc: 0.0000e+ - ETA: 29s - loss: 14.8919 - acc: 0.0111     - ETA: 15s - loss: 14.8683 - acc: 0.011 - ETA: 10s - loss: 14.5950 - acc: 0.017 - ETA: 8s - loss: 14.4050 - acc: 0.022 - ETA: 7s - loss: 14.2948 - acc: 0.02 - ETA: 6s - loss: 14.1254 - acc: 0.03 - ETA: 5s - loss: 13.9744 - acc: 0.03 - ETA: 4s - loss: 13.8087 - acc: 0.03 - ETA: 4s - loss: 13.6909 - acc: 0.04 - ETA: 3s - loss: 13.4850 - acc: 0.04 - ETA: 3s - loss: 13.3900 - acc: 0.05 - ETA: 3s - loss: 13.3322 - acc: 0.05 - ETA: 3s - loss: 13.2042 - acc: 0.06 - ETA: 2s - loss: 13.1722 - acc: 0.06 - ETA: 2s - loss: 13.0688 - acc: 0.06 - ETA: 2s - loss: 13.0087 - acc: 0.06 - ETA: 2s - loss: 12.9358 - acc: 0.07 - ETA: 2s - loss: 12.8886 - acc: 0.07 - ETA: 2s - loss: 12.8197 - acc: 0.07 - ETA: 1s - loss: 12.7452 - acc: 0.08 - ETA: 1s - loss: 12.6615 - acc: 0.08 - ETA: 1s - loss: 12.5391 - acc: 0.09 - ETA: 1s - loss: 12.4461 - acc: 0.09 - ETA: 1s - loss: 12.4107 - acc: 0.09 - ETA: 1s - loss: 12.3433 - acc: 0.10 - ETA: 1s - loss: 12.2650 - acc: 0.10 - ETA: 1s - loss: 12.1633 - acc: 0.10 - ETA: 1s - loss: 12.1198 - acc: 0.10 - ETA: 0s - loss: 12.0471 - acc: 0.11 - ETA: 0s - loss: 11.9945 - acc: 0.11 - ETA: 0s - loss: 11.9390 - acc: 0.11 - ETA: 0s - loss: 11.8778 - acc: 0.12 - ETA: 0s - loss: 11.7835 - acc: 0.12 - ETA: 0s - loss: 11.7192 - acc: 0.12 - ETA: 0s - loss: 11.6454 - acc: 0.13 - ETA: 0s - loss: 11.6214 - acc: 0.13 - ETA: 0s - loss: 11.5684 - acc: 0.13 - ETA: 0s - loss: 11.5050 - acc: 0.14 - ETA: 0s - loss: 11.4513 - acc: 0.14 - ETA: 0s - loss: 11.3934 - acc: 0.14 - ETA: 0s - loss: 11.3641 - acc: 0.14 - 3s 504us/step - loss: 11.3349 - acc: 0.1497 - val_loss: 9.4646 - val_acc: 0.2515
#
# Epoch 00001: val_loss improved from inf to 9.46455, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 2/20
# 6680/6680 [==============================] - ETA: 3s - loss: 11.0687 - acc: 0.15 - ETA: 2s - loss: 9.6014 - acc: 0.2563 - ETA: 2s - loss: 9.0358 - acc: 0.284 - ETA: 2s - loss: 9.1299 - acc: 0.287 - ETA: 2s - loss: 8.7612 - acc: 0.306 - ETA: 2s - loss: 8.8224 - acc: 0.301 - ETA: 2s - loss: 8.5780 - acc: 0.313 - ETA: 1s - loss: 8.7662 - acc: 0.309 - ETA: 1s - loss: 8.8930 - acc: 0.304 - ETA: 1s - loss: 8.8629 - acc: 0.304 - ETA: 1s - loss: 8.7768 - acc: 0.308 - ETA: 1s - loss: 8.8084 - acc: 0.306 - ETA: 1s - loss: 8.7274 - acc: 0.308 - ETA: 1s - loss: 8.6323 - acc: 0.317 - ETA: 1s - loss: 8.6454 - acc: 0.317 - ETA: 1s - loss: 8.5783 - acc: 0.319 - ETA: 1s - loss: 8.6243 - acc: 0.316 - ETA: 1s - loss: 8.6298 - acc: 0.318 - ETA: 1s - loss: 8.6110 - acc: 0.320 - ETA: 1s - loss: 8.5680 - acc: 0.325 - ETA: 1s - loss: 8.6086 - acc: 0.324 - ETA: 1s - loss: 8.6160 - acc: 0.323 - ETA: 1s - loss: 8.5713 - acc: 0.327 - ETA: 1s - loss: 8.5563 - acc: 0.329 - ETA: 0s - loss: 8.5439 - acc: 0.331 - ETA: 0s - loss: 8.5073 - acc: 0.333 - ETA: 0s - loss: 8.4992 - acc: 0.334 - ETA: 0s - loss: 8.4653 - acc: 0.337 - ETA: 0s - loss: 8.4549 - acc: 0.338 - ETA: 0s - loss: 8.4316 - acc: 0.341 - ETA: 0s - loss: 8.4469 - acc: 0.340 - ETA: 0s - loss: 8.4321 - acc: 0.341 - ETA: 0s - loss: 8.4017 - acc: 0.343 - ETA: 0s - loss: 8.4325 - acc: 0.342 - ETA: 0s - loss: 8.4514 - acc: 0.342 - ETA: 0s - loss: 8.4067 - acc: 0.346 - ETA: 0s - loss: 8.4033 - acc: 0.346 - ETA: 0s - loss: 8.4111 - acc: 0.347 - ETA: 0s - loss: 8.3794 - acc: 0.349 - ETA: 0s - loss: 8.3839 - acc: 0.348 - ETA: 0s - loss: 8.3905 - acc: 0.349 - ETA: 0s - loss: 8.3932 - acc: 0.350 - ETA: 0s - loss: 8.4101 - acc: 0.349 - 2s 372us/step - loss: 8.4018 - acc: 0.3503 - val_loss: 8.5216 - val_acc: 0.3533
#
# Epoch 00002: val_loss improved from 9.46455 to 8.52164, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 3/20
# 6680/6680 [==============================] - ETA: 3s - loss: 6.1170 - acc: 0.450 - ETA: 2s - loss: 7.5065 - acc: 0.405 - ETA: 2s - loss: 7.3989 - acc: 0.425 - ETA: 1s - loss: 7.4337 - acc: 0.440 - ETA: 1s - loss: 7.5974 - acc: 0.441 - ETA: 1s - loss: 7.5646 - acc: 0.444 - ETA: 1s - loss: 7.6654 - acc: 0.440 - ETA: 1s - loss: 7.6106 - acc: 0.446 - ETA: 1s - loss: 7.5784 - acc: 0.448 - ETA: 1s - loss: 7.6350 - acc: 0.447 - ETA: 1s - loss: 7.5696 - acc: 0.447 - ETA: 1s - loss: 7.6014 - acc: 0.444 - ETA: 1s - loss: 7.6720 - acc: 0.444 - ETA: 1s - loss: 7.6247 - acc: 0.447 - ETA: 1s - loss: 7.6596 - acc: 0.443 - ETA: 1s - loss: 7.6376 - acc: 0.442 - ETA: 1s - loss: 7.6452 - acc: 0.440 - ETA: 1s - loss: 7.6747 - acc: 0.438 - ETA: 1s - loss: 7.6891 - acc: 0.437 - ETA: 1s - loss: 7.6706 - acc: 0.439 - ETA: 1s - loss: 7.6721 - acc: 0.439 - ETA: 1s - loss: 7.6497 - acc: 0.439 - ETA: 0s - loss: 7.6146 - acc: 0.441 - ETA: 0s - loss: 7.6090 - acc: 0.441 - ETA: 0s - loss: 7.6079 - acc: 0.441 - ETA: 0s - loss: 7.6422 - acc: 0.438 - ETA: 0s - loss: 7.6695 - acc: 0.437 - ETA: 0s - loss: 7.6710 - acc: 0.437 - ETA: 0s - loss: 7.6373 - acc: 0.440 - ETA: 0s - loss: 7.6151 - acc: 0.441 - ETA: 0s - loss: 7.6318 - acc: 0.440 - ETA: 0s - loss: 7.6285 - acc: 0.439 - ETA: 0s - loss: 7.6194 - acc: 0.440 - ETA: 0s - loss: 7.6028 - acc: 0.440 - ETA: 0s - loss: 7.6102 - acc: 0.439 - ETA: 0s - loss: 7.6342 - acc: 0.438 - ETA: 0s - loss: 7.6301 - acc: 0.439 - ETA: 0s - loss: 7.6179 - acc: 0.440 - ETA: 0s - loss: 7.6166 - acc: 0.440 - ETA: 0s - loss: 7.6514 - acc: 0.438 - 2s 349us/step - loss: 7.6685 - acc: 0.4379 - val_loss: 8.1110 - val_acc: 0.3689
#
# Epoch 00003: val_loss improved from 8.52164 to 8.11104, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 4/20
# 6680/6680 [==============================] - ETA: 3s - loss: 7.4593 - acc: 0.400 - ETA: 2s - loss: 7.1973 - acc: 0.475 - ETA: 1s - loss: 7.2397 - acc: 0.490 - ETA: 1s - loss: 7.1591 - acc: 0.487 - ETA: 1s - loss: 7.1184 - acc: 0.490 - ETA: 1s - loss: 7.2677 - acc: 0.480 - ETA: 1s - loss: 7.4201 - acc: 0.471 - ETA: 1s - loss: 7.4640 - acc: 0.471 - ETA: 1s - loss: 7.5428 - acc: 0.468 - ETA: 1s - loss: 7.4906 - acc: 0.469 - ETA: 1s - loss: 7.4856 - acc: 0.471 - ETA: 1s - loss: 7.4523 - acc: 0.468 - ETA: 1s - loss: 7.4338 - acc: 0.469 - ETA: 1s - loss: 7.3774 - acc: 0.472 - ETA: 1s - loss: 7.3964 - acc: 0.472 - ETA: 1s - loss: 7.3949 - acc: 0.472 - ETA: 1s - loss: 7.3726 - acc: 0.475 - ETA: 1s - loss: 7.3443 - acc: 0.475 - ETA: 1s - loss: 7.3451 - acc: 0.476 - ETA: 1s - loss: 7.3343 - acc: 0.477 - ETA: 0s - loss: 7.3245 - acc: 0.476 - ETA: 0s - loss: 7.2947 - acc: 0.477 - ETA: 0s - loss: 7.2757 - acc: 0.477 - ETA: 0s - loss: 7.2575 - acc: 0.477 - ETA: 0s - loss: 7.2515 - acc: 0.478 - ETA: 0s - loss: 7.2844 - acc: 0.477 - ETA: 0s - loss: 7.2787 - acc: 0.478 - ETA: 0s - loss: 7.3111 - acc: 0.477 - ETA: 0s - loss: 7.3290 - acc: 0.474 - ETA: 0s - loss: 7.3110 - acc: 0.474 - ETA: 0s - loss: 7.2901 - acc: 0.474 - ETA: 0s - loss: 7.2668 - acc: 0.476 - ETA: 0s - loss: 7.2661 - acc: 0.476 - ETA: 0s - loss: 7.3047 - acc: 0.474 - ETA: 0s - loss: 7.2738 - acc: 0.476 - ETA: 0s - loss: 7.2768 - acc: 0.474 - ETA: 0s - loss: 7.2831 - acc: 0.474 - ETA: 0s - loss: 7.2944 - acc: 0.474 - ETA: 0s - loss: 7.3028 - acc: 0.474 - 2s 337us/step - loss: 7.3067 - acc: 0.4743 - val_loss: 7.8395 - val_acc: 0.3964
#
# Epoch 00004: val_loss improved from 8.11104 to 7.83953, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 5/20
# 6680/6680 [==============================] - ETA: 1s - loss: 10.0611 - acc: 0.35 - ETA: 2s - loss: 6.9519 - acc: 0.5050 - ETA: 1s - loss: 7.0527 - acc: 0.502 - ETA: 1s - loss: 7.0910 - acc: 0.500 - ETA: 1s - loss: 7.0518 - acc: 0.504 - ETA: 1s - loss: 7.2116 - acc: 0.496 - ETA: 1s - loss: 7.1050 - acc: 0.501 - ETA: 1s - loss: 7.2048 - acc: 0.495 - ETA: 1s - loss: 7.1189 - acc: 0.499 - ETA: 1s - loss: 7.0124 - acc: 0.505 - ETA: 1s - loss: 7.0534 - acc: 0.502 - ETA: 1s - loss: 7.0588 - acc: 0.502 - ETA: 1s - loss: 7.0239 - acc: 0.503 - ETA: 1s - loss: 7.0405 - acc: 0.502 - ETA: 1s - loss: 7.0731 - acc: 0.499 - ETA: 1s - loss: 7.0072 - acc: 0.505 - ETA: 1s - loss: 6.9745 - acc: 0.507 - ETA: 1s - loss: 6.9496 - acc: 0.507 - ETA: 1s - loss: 6.9307 - acc: 0.508 - ETA: 1s - loss: 6.9517 - acc: 0.506 - ETA: 1s - loss: 7.0232 - acc: 0.502 - ETA: 1s - loss: 7.0099 - acc: 0.504 - ETA: 0s - loss: 6.9891 - acc: 0.504 - ETA: 0s - loss: 7.0273 - acc: 0.501 - ETA: 0s - loss: 6.9708 - acc: 0.505 - ETA: 0s - loss: 6.9291 - acc: 0.507 - ETA: 0s - loss: 6.8933 - acc: 0.509 - ETA: 0s - loss: 6.8585 - acc: 0.511 - ETA: 0s - loss: 6.8237 - acc: 0.514 - ETA: 0s - loss: 6.8542 - acc: 0.512 - ETA: 0s - loss: 6.8678 - acc: 0.511 - ETA: 0s - loss: 6.8598 - acc: 0.512 - ETA: 0s - loss: 6.8596 - acc: 0.512 - ETA: 0s - loss: 6.8669 - acc: 0.512 - ETA: 0s - loss: 6.8635 - acc: 0.511 - ETA: 0s - loss: 6.8648 - acc: 0.510 - ETA: 0s - loss: 6.8640 - acc: 0.510 - ETA: 0s - loss: 6.8550 - acc: 0.510 - ETA: 0s - loss: 6.8772 - acc: 0.509 - ETA: 0s - loss: 6.9155 - acc: 0.505 - 2s 343us/step - loss: 6.9242 - acc: 0.5051 - val_loss: 7.3175 - val_acc: 0.4120
#
# Epoch 00005: val_loss improved from 7.83953 to 7.31752, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 6/20
# 6680/6680 [==============================] - ETA: 3s - loss: 6.7485 - acc: 0.500 - ETA: 2s - loss: 5.8793 - acc: 0.555 - ETA: 1s - loss: 6.7448 - acc: 0.518 - ETA: 1s - loss: 6.4919 - acc: 0.532 - ETA: 1s - loss: 6.5010 - acc: 0.534 - ETA: 1s - loss: 6.4699 - acc: 0.534 - ETA: 1s - loss: 6.4629 - acc: 0.539 - ETA: 1s - loss: 6.5790 - acc: 0.532 - ETA: 1s - loss: 6.7053 - acc: 0.526 - ETA: 1s - loss: 6.7745 - acc: 0.519 - ETA: 1s - loss: 6.7185 - acc: 0.521 - ETA: 1s - loss: 6.5679 - acc: 0.533 - ETA: 1s - loss: 6.5932 - acc: 0.533 - ETA: 1s - loss: 6.5271 - acc: 0.538 - ETA: 1s - loss: 6.5598 - acc: 0.537 - ETA: 1s - loss: 6.5497 - acc: 0.538 - ETA: 1s - loss: 6.6465 - acc: 0.531 - ETA: 1s - loss: 6.5902 - acc: 0.534 - ETA: 1s - loss: 6.5578 - acc: 0.538 - ETA: 1s - loss: 6.5487 - acc: 0.539 - ETA: 0s - loss: 6.4926 - acc: 0.543 - ETA: 0s - loss: 6.4814 - acc: 0.544 - ETA: 0s - loss: 6.4898 - acc: 0.543 - ETA: 0s - loss: 6.4920 - acc: 0.543 - ETA: 0s - loss: 6.4932 - acc: 0.543 - ETA: 0s - loss: 6.4861 - acc: 0.542 - ETA: 0s - loss: 6.4692 - acc: 0.543 - ETA: 0s - loss: 6.4623 - acc: 0.543 - ETA: 0s - loss: 6.4431 - acc: 0.544 - ETA: 0s - loss: 6.4433 - acc: 0.544 - ETA: 0s - loss: 6.4376 - acc: 0.545 - ETA: 0s - loss: 6.4490 - acc: 0.545 - ETA: 0s - loss: 6.4550 - acc: 0.545 - ETA: 0s - loss: 6.4476 - acc: 0.545 - ETA: 0s - loss: 6.4346 - acc: 0.546 - ETA: 0s - loss: 6.4409 - acc: 0.546 - ETA: 0s - loss: 6.4100 - acc: 0.547 - ETA: 0s - loss: 6.4262 - acc: 0.546 - 2s 335us/step - loss: 6.4202 - acc: 0.5467 - val_loss: 6.9940 - val_acc: 0.4599
#
# Epoch 00006: val_loss improved from 7.31752 to 6.99404, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 7/20
# 6680/6680 [==============================] - ETA: 1s - loss: 7.3455 - acc: 0.500 - ETA: 2s - loss: 6.5040 - acc: 0.565 - ETA: 1s - loss: 5.7055 - acc: 0.607 - ETA: 1s - loss: 5.9116 - acc: 0.600 - ETA: 1s - loss: 6.0060 - acc: 0.595 - ETA: 1s - loss: 6.0243 - acc: 0.597 - ETA: 1s - loss: 6.1871 - acc: 0.589 - ETA: 1s - loss: 6.1921 - acc: 0.585 - ETA: 1s - loss: 6.2235 - acc: 0.582 - ETA: 1s - loss: 6.2515 - acc: 0.582 - ETA: 1s - loss: 6.3133 - acc: 0.574 - ETA: 1s - loss: 6.3993 - acc: 0.568 - ETA: 1s - loss: 6.4158 - acc: 0.567 - ETA: 1s - loss: 6.3881 - acc: 0.568 - ETA: 1s - loss: 6.3792 - acc: 0.568 - ETA: 1s - loss: 6.3511 - acc: 0.572 - ETA: 1s - loss: 6.3817 - acc: 0.569 - ETA: 1s - loss: 6.3487 - acc: 0.570 - ETA: 1s - loss: 6.3404 - acc: 0.570 - ETA: 1s - loss: 6.3618 - acc: 0.568 - ETA: 1s - loss: 6.3108 - acc: 0.571 - ETA: 0s - loss: 6.2787 - acc: 0.572 - ETA: 0s - loss: 6.2677 - acc: 0.573 - ETA: 0s - loss: 6.2861 - acc: 0.572 - ETA: 0s - loss: 6.3010 - acc: 0.572 - ETA: 0s - loss: 6.2653 - acc: 0.574 - ETA: 0s - loss: 6.2603 - acc: 0.574 - ETA: 0s - loss: 6.2567 - acc: 0.574 - ETA: 0s - loss: 6.2566 - acc: 0.573 - ETA: 0s - loss: 6.2730 - acc: 0.572 - ETA: 0s - loss: 6.2786 - acc: 0.571 - ETA: 0s - loss: 6.2683 - acc: 0.572 - ETA: 0s - loss: 6.2787 - acc: 0.571 - ETA: 0s - loss: 6.2668 - acc: 0.572 - ETA: 0s - loss: 6.2728 - acc: 0.571 - ETA: 0s - loss: 6.2764 - acc: 0.571 - ETA: 0s - loss: 6.2563 - acc: 0.572 - ETA: 0s - loss: 6.2531 - acc: 0.572 - ETA: 0s - loss: 6.2459 - acc: 0.573 - 2s 337us/step - loss: 6.2433 - acc: 0.5732 - val_loss: 6.9547 - val_acc: 0.4647
#
# Epoch 00007: val_loss improved from 6.99404 to 6.95473, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 8/20
# 6680/6680 [==============================] - ETA: 1s - loss: 5.0289 - acc: 0.600 - ETA: 1s - loss: 6.2169 - acc: 0.585 - ETA: 1s - loss: 6.1160 - acc: 0.591 - ETA: 1s - loss: 5.8447 - acc: 0.603 - ETA: 1s - loss: 5.8476 - acc: 0.604 - ETA: 1s - loss: 5.6484 - acc: 0.611 - ETA: 1s - loss: 5.8197 - acc: 0.599 - ETA: 1s - loss: 5.8614 - acc: 0.596 - ETA: 1s - loss: 5.8595 - acc: 0.595 - ETA: 1s - loss: 5.9015 - acc: 0.594 - ETA: 1s - loss: 5.9051 - acc: 0.596 - ETA: 1s - loss: 5.8600 - acc: 0.600 - ETA: 1s - loss: 5.8871 - acc: 0.599 - ETA: 1s - loss: 5.9511 - acc: 0.596 - ETA: 1s - loss: 6.0143 - acc: 0.591 - ETA: 1s - loss: 6.0947 - acc: 0.587 - ETA: 1s - loss: 6.0963 - acc: 0.587 - ETA: 1s - loss: 6.0697 - acc: 0.589 - ETA: 1s - loss: 6.0674 - acc: 0.590 - ETA: 1s - loss: 6.0961 - acc: 0.588 - ETA: 0s - loss: 6.1233 - acc: 0.587 - ETA: 0s - loss: 6.1007 - acc: 0.589 - ETA: 0s - loss: 6.0684 - acc: 0.592 - ETA: 0s - loss: 6.1538 - acc: 0.586 - ETA: 0s - loss: 6.1844 - acc: 0.584 - ETA: 0s - loss: 6.2136 - acc: 0.583 - ETA: 0s - loss: 6.1844 - acc: 0.584 - ETA: 0s - loss: 6.1642 - acc: 0.585 - ETA: 0s - loss: 6.1469 - acc: 0.587 - ETA: 0s - loss: 6.1186 - acc: 0.589 - ETA: 0s - loss: 6.1001 - acc: 0.590 - ETA: 0s - loss: 6.1649 - acc: 0.586 - ETA: 0s - loss: 6.1754 - acc: 0.585 - ETA: 0s - loss: 6.1744 - acc: 0.586 - ETA: 0s - loss: 6.1695 - acc: 0.586 - ETA: 0s - loss: 6.1526 - acc: 0.587 - ETA: 0s - loss: 6.1546 - acc: 0.587 - ETA: 0s - loss: 6.1795 - acc: 0.585 - ETA: 0s - loss: 6.1863 - acc: 0.584 - 2s 336us/step - loss: 6.1841 - acc: 0.5843 - val_loss: 6.9771 - val_acc: 0.4707
#
# Epoch 00008: val_loss did not improve from 6.95473
# Epoch 9/20
# 6680/6680 [==============================] - ETA: 1s - loss: 4.4670 - acc: 0.650 - ETA: 1s - loss: 6.1902 - acc: 0.580 - ETA: 1s - loss: 6.3363 - acc: 0.577 - ETA: 1s - loss: 6.0734 - acc: 0.596 - ETA: 1s - loss: 5.9408 - acc: 0.608 - ETA: 1s - loss: 5.8455 - acc: 0.609 - ETA: 1s - loss: 6.0002 - acc: 0.603 - ETA: 1s - loss: 5.9338 - acc: 0.608 - ETA: 1s - loss: 5.9898 - acc: 0.602 - ETA: 1s - loss: 5.9282 - acc: 0.606 - ETA: 1s - loss: 5.9443 - acc: 0.605 - ETA: 1s - loss: 5.9999 - acc: 0.601 - ETA: 1s - loss: 6.0192 - acc: 0.599 - ETA: 1s - loss: 6.1024 - acc: 0.593 - ETA: 1s - loss: 6.1050 - acc: 0.593 - ETA: 1s - loss: 6.0936 - acc: 0.595 - ETA: 1s - loss: 6.0340 - acc: 0.600 - ETA: 1s - loss: 6.0108 - acc: 0.598 - ETA: 1s - loss: 5.9929 - acc: 0.598 - ETA: 1s - loss: 5.9574 - acc: 0.600 - ETA: 1s - loss: 5.9833 - acc: 0.598 - ETA: 0s - loss: 5.9638 - acc: 0.600 - ETA: 0s - loss: 5.9629 - acc: 0.601 - ETA: 0s - loss: 5.9522 - acc: 0.601 - ETA: 0s - loss: 5.9628 - acc: 0.601 - ETA: 0s - loss: 5.9650 - acc: 0.601 - ETA: 0s - loss: 6.0008 - acc: 0.599 - ETA: 0s - loss: 6.0057 - acc: 0.598 - ETA: 0s - loss: 5.9928 - acc: 0.599 - ETA: 0s - loss: 6.0046 - acc: 0.598 - ETA: 0s - loss: 5.9946 - acc: 0.599 - ETA: 0s - loss: 6.0063 - acc: 0.597 - ETA: 0s - loss: 6.0158 - acc: 0.597 - ETA: 0s - loss: 6.0381 - acc: 0.595 - ETA: 0s - loss: 6.0343 - acc: 0.596 - ETA: 0s - loss: 6.0044 - acc: 0.598 - ETA: 0s - loss: 6.0229 - acc: 0.596 - ETA: 0s - loss: 6.0328 - acc: 0.595 - ETA: 0s - loss: 6.0324 - acc: 0.595 - ETA: 0s - loss: 6.0346 - acc: 0.594 - 2s 345us/step - loss: 6.0365 - acc: 0.5945 - val_loss: 6.8154 - val_acc: 0.4743
#
# Epoch 00009: val_loss improved from 6.95473 to 6.81542, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 10/20
# 6680/6680 [==============================] - ETA: 3s - loss: 5.6519 - acc: 0.650 - ETA: 2s - loss: 7.1638 - acc: 0.540 - ETA: 2s - loss: 6.5333 - acc: 0.576 - ETA: 1s - loss: 6.2765 - acc: 0.591 - ETA: 1s - loss: 6.0169 - acc: 0.605 - ETA: 1s - loss: 5.9516 - acc: 0.613 - ETA: 1s - loss: 6.0046 - acc: 0.607 - ETA: 1s - loss: 5.9223 - acc: 0.613 - ETA: 1s - loss: 5.7859 - acc: 0.617 - ETA: 1s - loss: 5.8665 - acc: 0.614 - ETA: 1s - loss: 5.8975 - acc: 0.612 - ETA: 1s - loss: 5.8404 - acc: 0.615 - ETA: 1s - loss: 5.8780 - acc: 0.611 - ETA: 1s - loss: 5.8478 - acc: 0.614 - ETA: 1s - loss: 5.8545 - acc: 0.614 - ETA: 1s - loss: 5.8422 - acc: 0.614 - ETA: 1s - loss: 5.8114 - acc: 0.616 - ETA: 1s - loss: 5.7708 - acc: 0.618 - ETA: 1s - loss: 5.8461 - acc: 0.613 - ETA: 1s - loss: 5.8215 - acc: 0.616 - ETA: 0s - loss: 5.8354 - acc: 0.615 - ETA: 0s - loss: 5.8178 - acc: 0.616 - ETA: 0s - loss: 5.8187 - acc: 0.616 - ETA: 0s - loss: 5.8627 - acc: 0.613 - ETA: 0s - loss: 5.8465 - acc: 0.615 - ETA: 0s - loss: 5.8364 - acc: 0.616 - ETA: 0s - loss: 5.7968 - acc: 0.619 - ETA: 0s - loss: 5.7805 - acc: 0.619 - ETA: 0s - loss: 5.7957 - acc: 0.618 - ETA: 0s - loss: 5.7962 - acc: 0.618 - ETA: 0s - loss: 5.8198 - acc: 0.617 - ETA: 0s - loss: 5.8197 - acc: 0.617 - ETA: 0s - loss: 5.8106 - acc: 0.617 - ETA: 0s - loss: 5.8275 - acc: 0.616 - ETA: 0s - loss: 5.8423 - acc: 0.615 - ETA: 0s - loss: 5.8404 - acc: 0.615 - ETA: 0s - loss: 5.8697 - acc: 0.613 - ETA: 0s - loss: 5.8873 - acc: 0.612 - 2s 335us/step - loss: 5.8903 - acc: 0.6123 - val_loss: 6.7061 - val_acc: 0.4958
#
# Epoch 00010: val_loss improved from 6.81542 to 6.70609, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 11/20
# 6680/6680 [==============================] - ETA: 3s - loss: 5.7462 - acc: 0.600 - ETA: 1s - loss: 6.2092 - acc: 0.595 - ETA: 1s - loss: 5.8352 - acc: 0.621 - ETA: 1s - loss: 6.0131 - acc: 0.612 - ETA: 1s - loss: 5.9603 - acc: 0.613 - ETA: 1s - loss: 5.9711 - acc: 0.615 - ETA: 1s - loss: 5.8847 - acc: 0.621 - ETA: 1s - loss: 5.8150 - acc: 0.627 - ETA: 1s - loss: 5.7195 - acc: 0.633 - ETA: 1s - loss: 5.7908 - acc: 0.628 - ETA: 1s - loss: 5.7903 - acc: 0.627 - ETA: 1s - loss: 5.7899 - acc: 0.625 - ETA: 1s - loss: 5.8348 - acc: 0.623 - ETA: 1s - loss: 5.8138 - acc: 0.625 - ETA: 1s - loss: 5.8046 - acc: 0.625 - ETA: 1s - loss: 5.8228 - acc: 0.624 - ETA: 1s - loss: 5.8134 - acc: 0.625 - ETA: 1s - loss: 5.8599 - acc: 0.621 - ETA: 1s - loss: 5.8969 - acc: 0.619 - ETA: 1s - loss: 5.9074 - acc: 0.618 - ETA: 1s - loss: 5.9323 - acc: 0.617 - ETA: 0s - loss: 5.9197 - acc: 0.617 - ETA: 0s - loss: 5.9131 - acc: 0.618 - ETA: 0s - loss: 5.8980 - acc: 0.618 - ETA: 0s - loss: 5.8991 - acc: 0.618 - ETA: 0s - loss: 5.9051 - acc: 0.617 - ETA: 0s - loss: 5.9009 - acc: 0.617 - ETA: 0s - loss: 5.8618 - acc: 0.619 - ETA: 0s - loss: 5.8769 - acc: 0.618 - ETA: 0s - loss: 5.8565 - acc: 0.620 - ETA: 0s - loss: 5.8665 - acc: 0.619 - ETA: 0s - loss: 5.8735 - acc: 0.618 - ETA: 0s - loss: 5.8672 - acc: 0.619 - ETA: 0s - loss: 5.8582 - acc: 0.619 - ETA: 0s - loss: 5.8487 - acc: 0.620 - ETA: 0s - loss: 5.8216 - acc: 0.621 - ETA: 0s - loss: 5.8393 - acc: 0.620 - ETA: 0s - loss: 5.8231 - acc: 0.621 - ETA: 0s - loss: 5.8225 - acc: 0.620 - 2s 338us/step - loss: 5.8255 - acc: 0.6207 - val_loss: 6.6539 - val_acc: 0.4838
#
# Epoch 00011: val_loss improved from 6.70609 to 6.65385, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 12/20
# 6680/6680 [==============================] - ETA: 1s - loss: 4.0521 - acc: 0.750 - ETA: 1s - loss: 5.4876 - acc: 0.640 - ETA: 1s - loss: 5.5955 - acc: 0.642 - ETA: 1s - loss: 5.2480 - acc: 0.662 - ETA: 1s - loss: 5.2904 - acc: 0.659 - ETA: 1s - loss: 5.3741 - acc: 0.651 - ETA: 1s - loss: 5.3982 - acc: 0.648 - ETA: 1s - loss: 5.3426 - acc: 0.650 - ETA: 1s - loss: 5.2840 - acc: 0.653 - ETA: 1s - loss: 5.3636 - acc: 0.648 - ETA: 1s - loss: 5.3773 - acc: 0.646 - ETA: 1s - loss: 5.4853 - acc: 0.640 - ETA: 1s - loss: 5.5385 - acc: 0.637 - ETA: 1s - loss: 5.6025 - acc: 0.631 - ETA: 1s - loss: 5.6608 - acc: 0.626 - ETA: 1s - loss: 5.6959 - acc: 0.624 - ETA: 1s - loss: 5.7009 - acc: 0.623 - ETA: 1s - loss: 5.7089 - acc: 0.622 - ETA: 1s - loss: 5.7798 - acc: 0.619 - ETA: 1s - loss: 5.7601 - acc: 0.620 - ETA: 0s - loss: 5.7739 - acc: 0.620 - ETA: 0s - loss: 5.7767 - acc: 0.620 - ETA: 0s - loss: 5.8053 - acc: 0.618 - ETA: 0s - loss: 5.7922 - acc: 0.619 - ETA: 0s - loss: 5.8345 - acc: 0.615 - ETA: 0s - loss: 5.8266 - acc: 0.616 - ETA: 0s - loss: 5.8053 - acc: 0.617 - ETA: 0s - loss: 5.8038 - acc: 0.618 - ETA: 0s - loss: 5.8037 - acc: 0.618 - ETA: 0s - loss: 5.7841 - acc: 0.619 - ETA: 0s - loss: 5.7877 - acc: 0.619 - ETA: 0s - loss: 5.7491 - acc: 0.622 - ETA: 0s - loss: 5.7857 - acc: 0.619 - ETA: 0s - loss: 5.7578 - acc: 0.621 - ETA: 0s - loss: 5.7520 - acc: 0.622 - ETA: 0s - loss: 5.6919 - acc: 0.625 - ETA: 0s - loss: 5.6923 - acc: 0.626 - ETA: 0s - loss: 5.6879 - acc: 0.626 - ETA: 0s - loss: 5.6795 - acc: 0.625 - 2s 339us/step - loss: 5.6776 - acc: 0.6257 - val_loss: 6.5773 - val_acc: 0.4994
#
# Epoch 00012: val_loss improved from 6.65385 to 6.57726, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 13/20
# 6680/6680 [==============================] - ETA: 3s - loss: 2.4328 - acc: 0.850 - ETA: 2s - loss: 4.8747 - acc: 0.688 - ETA: 2s - loss: 5.6522 - acc: 0.641 - ETA: 2s - loss: 5.5415 - acc: 0.648 - ETA: 1s - loss: 5.3841 - acc: 0.655 - ETA: 1s - loss: 5.5369 - acc: 0.646 - ETA: 1s - loss: 5.5119 - acc: 0.648 - ETA: 1s - loss: 5.5839 - acc: 0.645 - ETA: 1s - loss: 5.5515 - acc: 0.647 - ETA: 1s - loss: 5.5178 - acc: 0.648 - ETA: 1s - loss: 5.5440 - acc: 0.646 - ETA: 1s - loss: 5.5811 - acc: 0.643 - ETA: 1s - loss: 5.5792 - acc: 0.644 - ETA: 1s - loss: 5.5826 - acc: 0.643 - ETA: 1s - loss: 5.5335 - acc: 0.644 - ETA: 1s - loss: 5.5226 - acc: 0.644 - ETA: 1s - loss: 5.4561 - acc: 0.647 - ETA: 1s - loss: 5.5161 - acc: 0.644 - ETA: 1s - loss: 5.5134 - acc: 0.645 - ETA: 1s - loss: 5.4857 - acc: 0.647 - ETA: 1s - loss: 5.4831 - acc: 0.647 - ETA: 0s - loss: 5.4879 - acc: 0.647 - ETA: 0s - loss: 5.4831 - acc: 0.647 - ETA: 0s - loss: 5.4826 - acc: 0.647 - ETA: 0s - loss: 5.4852 - acc: 0.646 - ETA: 0s - loss: 5.5053 - acc: 0.645 - ETA: 0s - loss: 5.5456 - acc: 0.643 - ETA: 0s - loss: 5.5145 - acc: 0.645 - ETA: 0s - loss: 5.5470 - acc: 0.642 - ETA: 0s - loss: 5.5431 - acc: 0.642 - ETA: 0s - loss: 5.5404 - acc: 0.642 - ETA: 0s - loss: 5.5990 - acc: 0.638 - ETA: 0s - loss: 5.6150 - acc: 0.637 - ETA: 0s - loss: 5.6193 - acc: 0.636 - ETA: 0s - loss: 5.6106 - acc: 0.636 - ETA: 0s - loss: 5.6271 - acc: 0.635 - ETA: 0s - loss: 5.6257 - acc: 0.635 - ETA: 0s - loss: 5.6232 - acc: 0.635 - ETA: 0s - loss: 5.5972 - acc: 0.636 - 2s 338us/step - loss: 5.6063 - acc: 0.6361 - val_loss: 6.6448 - val_acc: 0.4874
#
# Epoch 00013: val_loss did not improve from 6.57726
# Epoch 14/20
# 6680/6680 [==============================] - ETA: 1s - loss: 4.3267 - acc: 0.650 - ETA: 1s - loss: 5.8098 - acc: 0.615 - ETA: 1s - loss: 5.6514 - acc: 0.636 - ETA: 1s - loss: 5.6489 - acc: 0.635 - ETA: 1s - loss: 5.4819 - acc: 0.645 - ETA: 1s - loss: 5.2870 - acc: 0.659 - ETA: 1s - loss: 5.3714 - acc: 0.652 - ETA: 1s - loss: 5.4675 - acc: 0.648 - ETA: 1s - loss: 5.3521 - acc: 0.654 - ETA: 1s - loss: 5.3392 - acc: 0.654 - ETA: 1s - loss: 5.4435 - acc: 0.647 - ETA: 1s - loss: 5.4107 - acc: 0.650 - ETA: 1s - loss: 5.4764 - acc: 0.646 - ETA: 1s - loss: 5.4317 - acc: 0.650 - ETA: 1s - loss: 5.4672 - acc: 0.648 - ETA: 1s - loss: 5.4567 - acc: 0.648 - ETA: 1s - loss: 5.4598 - acc: 0.648 - ETA: 1s - loss: 5.4287 - acc: 0.649 - ETA: 1s - loss: 5.4395 - acc: 0.648 - ETA: 1s - loss: 5.4233 - acc: 0.649 - ETA: 1s - loss: 5.4470 - acc: 0.648 - ETA: 0s - loss: 5.3946 - acc: 0.650 - ETA: 0s - loss: 5.3743 - acc: 0.652 - ETA: 0s - loss: 5.3732 - acc: 0.653 - ETA: 0s - loss: 5.3841 - acc: 0.652 - ETA: 0s - loss: 5.4263 - acc: 0.649 - ETA: 0s - loss: 5.4552 - acc: 0.648 - ETA: 0s - loss: 5.4425 - acc: 0.649 - ETA: 0s - loss: 5.4563 - acc: 0.647 - ETA: 0s - loss: 5.4391 - acc: 0.647 - ETA: 0s - loss: 5.4423 - acc: 0.647 - ETA: 0s - loss: 5.4219 - acc: 0.648 - ETA: 0s - loss: 5.4532 - acc: 0.646 - ETA: 0s - loss: 5.4526 - acc: 0.646 - ETA: 0s - loss: 5.4396 - acc: 0.647 - ETA: 0s - loss: 5.4521 - acc: 0.646 - ETA: 0s - loss: 5.4690 - acc: 0.644 - ETA: 0s - loss: 5.4855 - acc: 0.643 - ETA: 0s - loss: 5.4718 - acc: 0.644 - 2s 339us/step - loss: 5.4839 - acc: 0.6439 - val_loss: 6.5944 - val_acc: 0.4838
#
# Epoch 00014: val_loss did not improve from 6.57726
# Epoch 15/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0012 - acc: 1.000 - ETA: 1s - loss: 5.3947 - acc: 0.660 - ETA: 1s - loss: 5.1154 - acc: 0.673 - ETA: 1s - loss: 5.1843 - acc: 0.670 - ETA: 1s - loss: 5.3013 - acc: 0.660 - ETA: 1s - loss: 5.3731 - acc: 0.653 - ETA: 1s - loss: 5.3934 - acc: 0.651 - ETA: 1s - loss: 5.3458 - acc: 0.654 - ETA: 1s - loss: 5.3654 - acc: 0.652 - ETA: 1s - loss: 5.2864 - acc: 0.658 - ETA: 1s - loss: 5.2178 - acc: 0.662 - ETA: 1s - loss: 5.3018 - acc: 0.657 - ETA: 1s - loss: 5.3266 - acc: 0.655 - ETA: 1s - loss: 5.3329 - acc: 0.655 - ETA: 1s - loss: 5.3638 - acc: 0.653 - ETA: 1s - loss: 5.3553 - acc: 0.654 - ETA: 1s - loss: 5.3669 - acc: 0.653 - ETA: 1s - loss: 5.3218 - acc: 0.655 - ETA: 1s - loss: 5.3303 - acc: 0.655 - ETA: 1s - loss: 5.3074 - acc: 0.656 - ETA: 0s - loss: 5.3275 - acc: 0.655 - ETA: 0s - loss: 5.3014 - acc: 0.656 - ETA: 0s - loss: 5.2994 - acc: 0.656 - ETA: 0s - loss: 5.3240 - acc: 0.655 - ETA: 0s - loss: 5.3001 - acc: 0.656 - ETA: 0s - loss: 5.2968 - acc: 0.656 - ETA: 0s - loss: 5.2927 - acc: 0.656 - ETA: 0s - loss: 5.2917 - acc: 0.657 - ETA: 0s - loss: 5.2872 - acc: 0.657 - ETA: 0s - loss: 5.3065 - acc: 0.656 - ETA: 0s - loss: 5.3361 - acc: 0.654 - ETA: 0s - loss: 5.3293 - acc: 0.653 - ETA: 0s - loss: 5.3286 - acc: 0.653 - ETA: 0s - loss: 5.3243 - acc: 0.653 - ETA: 0s - loss: 5.3416 - acc: 0.652 - ETA: 0s - loss: 5.3614 - acc: 0.650 - ETA: 0s - loss: 5.3534 - acc: 0.650 - ETA: 0s - loss: 5.3324 - acc: 0.651 - ETA: 0s - loss: 5.3101 - acc: 0.652 - 2s 336us/step - loss: 5.3192 - acc: 0.6518 - val_loss: 6.2365 - val_acc: 0.5138
#
# Epoch 00015: val_loss improved from 6.57726 to 6.23652, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 16/20
# 6680/6680 [==============================] - ETA: 2s - loss: 4.0315 - acc: 0.750 - ETA: 2s - loss: 5.5133 - acc: 0.645 - ETA: 1s - loss: 5.4941 - acc: 0.647 - ETA: 1s - loss: 5.2830 - acc: 0.661 - ETA: 1s - loss: 5.1371 - acc: 0.667 - ETA: 1s - loss: 5.1619 - acc: 0.667 - ETA: 1s - loss: 5.2197 - acc: 0.664 - ETA: 1s - loss: 5.2344 - acc: 0.664 - ETA: 1s - loss: 5.2202 - acc: 0.666 - ETA: 1s - loss: 5.1664 - acc: 0.669 - ETA: 1s - loss: 5.0329 - acc: 0.676 - ETA: 1s - loss: 5.0226 - acc: 0.676 - ETA: 1s - loss: 5.0229 - acc: 0.675 - ETA: 1s - loss: 5.0902 - acc: 0.671 - ETA: 1s - loss: 5.0790 - acc: 0.671 - ETA: 1s - loss: 5.1303 - acc: 0.667 - ETA: 1s - loss: 5.1317 - acc: 0.667 - ETA: 1s - loss: 5.1450 - acc: 0.666 - ETA: 1s - loss: 5.1651 - acc: 0.664 - ETA: 1s - loss: 5.1159 - acc: 0.667 - ETA: 0s - loss: 5.1500 - acc: 0.664 - ETA: 0s - loss: 5.1569 - acc: 0.663 - ETA: 0s - loss: 5.1106 - acc: 0.667 - ETA: 0s - loss: 5.1005 - acc: 0.668 - ETA: 0s - loss: 5.0885 - acc: 0.668 - ETA: 0s - loss: 5.0936 - acc: 0.668 - ETA: 0s - loss: 5.1031 - acc: 0.668 - ETA: 0s - loss: 5.0905 - acc: 0.668 - ETA: 0s - loss: 5.0985 - acc: 0.668 - ETA: 0s - loss: 5.0918 - acc: 0.668 - ETA: 0s - loss: 5.1144 - acc: 0.667 - ETA: 0s - loss: 5.0965 - acc: 0.667 - ETA: 0s - loss: 5.0659 - acc: 0.669 - ETA: 0s - loss: 5.0461 - acc: 0.670 - ETA: 0s - loss: 5.0312 - acc: 0.671 - ETA: 0s - loss: 5.0228 - acc: 0.671 - ETA: 0s - loss: 5.0308 - acc: 0.671 - ETA: 0s - loss: 5.0363 - acc: 0.671 - ETA: 0s - loss: 5.0319 - acc: 0.671 - 2s 341us/step - loss: 5.0666 - acc: 0.6690 - val_loss: 6.1528 - val_acc: 0.5162
#
# Epoch 00016: val_loss improved from 6.23652 to 6.15285, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 17/20
# 6680/6680 [==============================] - ETA: 1s - loss: 3.3280 - acc: 0.750 - ETA: 1s - loss: 4.5449 - acc: 0.685 - ETA: 1s - loss: 4.7229 - acc: 0.686 - ETA: 1s - loss: 4.7916 - acc: 0.684 - ETA: 1s - loss: 4.9357 - acc: 0.673 - ETA: 1s - loss: 4.9146 - acc: 0.674 - ETA: 1s - loss: 4.7687 - acc: 0.683 - ETA: 1s - loss: 4.8939 - acc: 0.675 - ETA: 1s - loss: 4.9558 - acc: 0.673 - ETA: 1s - loss: 4.9824 - acc: 0.672 - ETA: 1s - loss: 4.9198 - acc: 0.677 - ETA: 1s - loss: 4.9183 - acc: 0.678 - ETA: 1s - loss: 4.8994 - acc: 0.680 - ETA: 1s - loss: 4.9125 - acc: 0.678 - ETA: 1s - loss: 4.9819 - acc: 0.673 - ETA: 1s - loss: 4.9082 - acc: 0.679 - ETA: 1s - loss: 4.9074 - acc: 0.679 - ETA: 1s - loss: 4.8886 - acc: 0.681 - ETA: 1s - loss: 4.8616 - acc: 0.681 - ETA: 1s - loss: 4.8434 - acc: 0.682 - ETA: 1s - loss: 4.8375 - acc: 0.683 - ETA: 0s - loss: 4.8698 - acc: 0.680 - ETA: 0s - loss: 4.9172 - acc: 0.677 - ETA: 0s - loss: 4.8832 - acc: 0.679 - ETA: 0s - loss: 4.8801 - acc: 0.680 - ETA: 0s - loss: 4.8910 - acc: 0.680 - ETA: 0s - loss: 4.8999 - acc: 0.679 - ETA: 0s - loss: 4.8878 - acc: 0.680 - ETA: 0s - loss: 4.8888 - acc: 0.679 - ETA: 0s - loss: 4.8941 - acc: 0.679 - ETA: 0s - loss: 4.9246 - acc: 0.678 - ETA: 0s - loss: 4.9025 - acc: 0.679 - ETA: 0s - loss: 4.8874 - acc: 0.680 - ETA: 0s - loss: 4.8760 - acc: 0.681 - ETA: 0s - loss: 4.8819 - acc: 0.681 - ETA: 0s - loss: 4.8824 - acc: 0.680 - ETA: 0s - loss: 4.8953 - acc: 0.680 - ETA: 0s - loss: 4.9168 - acc: 0.678 - ETA: 0s - loss: 4.9227 - acc: 0.678 - 2s 334us/step - loss: 4.9187 - acc: 0.6786 - val_loss: 6.0319 - val_acc: 0.5437
#
# Epoch 00017: val_loss improved from 6.15285 to 6.03191, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 18/20
# 6680/6680 [==============================] - ETA: 1s - loss: 4.8358 - acc: 0.700 - ETA: 1s - loss: 4.1201 - acc: 0.735 - ETA: 1s - loss: 4.7574 - acc: 0.697 - ETA: 1s - loss: 4.8238 - acc: 0.690 - ETA: 1s - loss: 5.0705 - acc: 0.676 - ETA: 1s - loss: 5.0789 - acc: 0.675 - ETA: 1s - loss: 5.0857 - acc: 0.672 - ETA: 1s - loss: 4.9873 - acc: 0.679 - ETA: 1s - loss: 5.0469 - acc: 0.676 - ETA: 1s - loss: 5.0543 - acc: 0.677 - ETA: 1s - loss: 5.0923 - acc: 0.673 - ETA: 1s - loss: 5.0774 - acc: 0.675 - ETA: 1s - loss: 4.9875 - acc: 0.681 - ETA: 1s - loss: 4.9915 - acc: 0.681 - ETA: 1s - loss: 4.9693 - acc: 0.682 - ETA: 1s - loss: 4.9266 - acc: 0.685 - ETA: 1s - loss: 4.9194 - acc: 0.685 - ETA: 1s - loss: 4.8984 - acc: 0.686 - ETA: 1s - loss: 4.8948 - acc: 0.686 - ETA: 1s - loss: 4.8649 - acc: 0.688 - ETA: 0s - loss: 4.8340 - acc: 0.689 - ETA: 0s - loss: 4.8271 - acc: 0.690 - ETA: 0s - loss: 4.8218 - acc: 0.690 - ETA: 0s - loss: 4.8319 - acc: 0.689 - ETA: 0s - loss: 4.8242 - acc: 0.690 - ETA: 0s - loss: 4.7968 - acc: 0.692 - ETA: 0s - loss: 4.7930 - acc: 0.692 - ETA: 0s - loss: 4.7588 - acc: 0.694 - ETA: 0s - loss: 4.7624 - acc: 0.693 - ETA: 0s - loss: 4.7771 - acc: 0.691 - ETA: 0s - loss: 4.8268 - acc: 0.688 - ETA: 0s - loss: 4.8213 - acc: 0.689 - ETA: 0s - loss: 4.8109 - acc: 0.689 - ETA: 0s - loss: 4.8255 - acc: 0.688 - ETA: 0s - loss: 4.8225 - acc: 0.688 - ETA: 0s - loss: 4.8317 - acc: 0.687 - ETA: 0s - loss: 4.8370 - acc: 0.687 - ETA: 0s - loss: 4.8296 - acc: 0.687 - ETA: 0s - loss: 4.8527 - acc: 0.686 - 2s 335us/step - loss: 4.8434 - acc: 0.6862 - val_loss: 5.9307 - val_acc: 0.5425
#
# Epoch 00018: val_loss improved from 6.03191 to 5.93072, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 19/20
# 6680/6680 [==============================] - ETA: 1s - loss: 7.2532 - acc: 0.550 - ETA: 1s - loss: 5.4579 - acc: 0.655 - ETA: 1s - loss: 5.0018 - acc: 0.681 - ETA: 1s - loss: 4.6877 - acc: 0.701 - ETA: 1s - loss: 4.7724 - acc: 0.697 - ETA: 1s - loss: 4.6297 - acc: 0.705 - ETA: 1s - loss: 4.4901 - acc: 0.713 - ETA: 1s - loss: 4.4353 - acc: 0.715 - ETA: 1s - loss: 4.5752 - acc: 0.703 - ETA: 1s - loss: 4.5873 - acc: 0.702 - ETA: 1s - loss: 4.5608 - acc: 0.703 - ETA: 1s - loss: 4.6135 - acc: 0.700 - ETA: 1s - loss: 4.6515 - acc: 0.696 - ETA: 1s - loss: 4.6369 - acc: 0.698 - ETA: 1s - loss: 4.6821 - acc: 0.695 - ETA: 1s - loss: 4.6284 - acc: 0.698 - ETA: 1s - loss: 4.6205 - acc: 0.698 - ETA: 1s - loss: 4.6330 - acc: 0.698 - ETA: 1s - loss: 4.6261 - acc: 0.698 - ETA: 1s - loss: 4.6450 - acc: 0.695 - ETA: 1s - loss: 4.6618 - acc: 0.693 - ETA: 0s - loss: 4.6744 - acc: 0.693 - ETA: 0s - loss: 4.6932 - acc: 0.692 - ETA: 0s - loss: 4.6829 - acc: 0.693 - ETA: 0s - loss: 4.6992 - acc: 0.692 - ETA: 0s - loss: 4.7134 - acc: 0.691 - ETA: 0s - loss: 4.7345 - acc: 0.690 - ETA: 0s - loss: 4.7696 - acc: 0.688 - ETA: 0s - loss: 4.7686 - acc: 0.689 - ETA: 0s - loss: 4.7647 - acc: 0.689 - ETA: 0s - loss: 4.7190 - acc: 0.691 - ETA: 0s - loss: 4.7084 - acc: 0.692 - ETA: 0s - loss: 4.7401 - acc: 0.690 - ETA: 0s - loss: 4.7297 - acc: 0.691 - ETA: 0s - loss: 4.7133 - acc: 0.692 - ETA: 0s - loss: 4.7398 - acc: 0.690 - ETA: 0s - loss: 4.7528 - acc: 0.689 - ETA: 0s - loss: 4.7709 - acc: 0.689 - ETA: 0s - loss: 4.7901 - acc: 0.688 - 2s 335us/step - loss: 4.7840 - acc: 0.6888 - val_loss: 5.8878 - val_acc: 0.5617
#
# Epoch 00019: val_loss improved from 5.93072 to 5.88783, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 20/20
# 6680/6680 [==============================] - ETA: 1s - loss: 2.4179 - acc: 0.850 - ETA: 2s - loss: 3.8992 - acc: 0.750 - ETA: 1s - loss: 4.2051 - acc: 0.730 - ETA: 1s - loss: 4.1929 - acc: 0.730 - ETA: 1s - loss: 4.2491 - acc: 0.727 - ETA: 1s - loss: 4.5725 - acc: 0.707 - ETA: 1s - loss: 4.5097 - acc: 0.712 - ETA: 1s - loss: 4.5125 - acc: 0.712 - ETA: 1s - loss: 4.6380 - acc: 0.704 - ETA: 1s - loss: 4.6200 - acc: 0.703 - ETA: 1s - loss: 4.6467 - acc: 0.702 - ETA: 1s - loss: 4.6546 - acc: 0.702 - ETA: 1s - loss: 4.6381 - acc: 0.703 - ETA: 1s - loss: 4.6956 - acc: 0.699 - ETA: 1s - loss: 4.7343 - acc: 0.697 - ETA: 1s - loss: 4.7587 - acc: 0.696 - ETA: 1s - loss: 4.7755 - acc: 0.695 - ETA: 1s - loss: 4.8018 - acc: 0.693 - ETA: 1s - loss: 4.8213 - acc: 0.692 - ETA: 1s - loss: 4.8321 - acc: 0.692 - ETA: 0s - loss: 4.8045 - acc: 0.694 - ETA: 0s - loss: 4.8143 - acc: 0.693 - ETA: 0s - loss: 4.7800 - acc: 0.695 - ETA: 0s - loss: 4.7581 - acc: 0.696 - ETA: 0s - loss: 4.7570 - acc: 0.696 - ETA: 0s - loss: 4.7532 - acc: 0.697 - ETA: 0s - loss: 4.7483 - acc: 0.697 - ETA: 0s - loss: 4.7816 - acc: 0.694 - ETA: 0s - loss: 4.7550 - acc: 0.696 - ETA: 0s - loss: 4.7537 - acc: 0.696 - ETA: 0s - loss: 4.7547 - acc: 0.696 - ETA: 0s - loss: 4.7532 - acc: 0.696 - ETA: 0s - loss: 4.7768 - acc: 0.694 - ETA: 0s - loss: 4.7746 - acc: 0.694 - ETA: 0s - loss: 4.7680 - acc: 0.695 - ETA: 0s - loss: 4.7658 - acc: 0.694 - ETA: 0s - loss: 4.7696 - acc: 0.694 - ETA: 0s - loss: 4.7346 - acc: 0.696 - ETA: 0s - loss: 4.7420 - acc: 0.696 - 2s 333us/step - loss: 4.7457 - acc: 0.6958 - val_loss: 5.9440 - val_acc: 0.5425
#
# Epoch 00020: val_loss did not improve from 5.88783

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 54.3062%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras.  These are already in the workspace, at /data/bottleneck_features.  If you wish to download them on a different machine, they can be found at:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.
#
# The above architectures are downloaded and stored for you in the `/data/bottleneck_features/` folder.
#
# This means the following will be in the `/data/bottleneck_features/` folder:
#
# `DogVGG19Data.npz`
# `DogResnet50Data.npz`
# `DogInceptionV3Data.npz`
# `DogXceptionData.npz`
#
#
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('/data/bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
useVGG19 = 1
useResnet50 = 1
useDataGenResnet50 = 0

if useVGG19:
    bottleneck_features = np.load('data/bottleneck_features/DogVGG19Data.npz')
    train_VGG19 = bottleneck_features['train']
    valid_VGG19 = bottleneck_features['valid']
    test_VGG19 = bottleneck_features['test']
    
if useResnet50:
    bottleneck_features = np.load('data/bottleneck_features/DogResnet50Data.npz')
    train_Resnet50 = bottleneck_features['train']
    valid_Resnet50 = bottleneck_features['valid']
    test_Resnet50 = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__
#
# This is a great case for transfer learning of another network trained in image classification, such as VGG19 and RESNET50, since most of the main features learned for image classification are low level 3D convolutional (pixel xy plus color) features common to many kinds of images.
#
# This transfer learned network does much better than the scratch network since it has had the ability to learn from way more images, i.e. it is pre-trained to be good at image classification before I asked it to do anything special.
#
# I noticed about a 5% improvement in accuracy by using Resnet50 instead of VGG19.
#
# ** Regarding the transfer learning additonal HEAD of the network
# * I initially started with a layer of 133 like in the cifar10 mini-project on transfer learning. This matches the number of output classes.
# * I switched from ReLU to tanh, since ReLU while computationaly efficient, has issues like dying ReLU, and speed of tanh is enough for this application. Sigmoid was outperformed by tanh by about 1%.
# * After experimenting I had better results with tanh
# * Extra 512 layer to add more dimensionality, and dropout layers to help manage the risk of overfitting from the added dimensionality. I tried two 512 dense layers, but it performed worse in validation and seemed to overfit. A 256 layer with 0.3 dropout also did similarly well to a layer of 512 with 0.5 dropout.
# * Data augmentation was very time consuming and did not seem to increase the accuracy on the test set
# * Smaller batch sizes seemed to help. 32 was good at ~82-84%, while using the batch since equal to the training size reduced accuracy to around 70%.
#
# Refences:
# https://medium.com/the-theory-of-everything/understanding-activation-functions-in-neural-networks-9491262884e0

# %%
### TODO: Define your architecture.

from keras.layers import Dense, Flatten, MaxPooling1D
from keras.models import Sequential

dropout = 0.5
acti = 'tanh' # tried sigmoid, tanh (best), relu, elu

if useVGG19:
    print('VGG + Head Arch')
    VGG19_CustomHead = Sequential()
    VGG19_CustomHead.add(GlobalAveragePooling2D(input_shape=train_VGG19.shape[1:]))
    VGG19_CustomHead.add(Dense(512, activation=acti)) 
    VGG19_CustomHead.add(Dropout(dropout))
    VGG19_CustomHead.add(Dense(133, activation='softmax'))
    VGG19_CustomHead.summary()
    
if useResnet50:
    print('Resnet50 + Head Arch')
    Resnet50_CustomHead = Sequential()
    Resnet50_CustomHead.add(GlobalAveragePooling2D(input_shape=train_Resnet50.shape[1:]))
    Resnet50_CustomHead.add(Dense(512, activation=acti)) # sigmoid, tanh, relu
    Resnet50_CustomHead.add(Dropout(dropout))
    Resnet50_CustomHead.add(Dense(133, activation='softmax'))
    Resnet50_CustomHead.summary()
# Out:
# VGG + Head Arch
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 330,885
# Trainable params: 330,885
# Non-trainable params: 0
# _________________________________________________________________
# Resnet50 + Head Arch
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 1,117,317
# Trainable params: 1,117,317
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
if useVGG19:
    VGG19_CustomHead.compile(loss='categorical_crossentropy', 
                             optimizer='rmsprop', 
                             metrics=['accuracy'])
    
if useResnet50:
    Resnet50_CustomHead.compile(loss='categorical_crossentropy', 
                             optimizer='rmsprop', 
                             metrics=['accuracy'])  
    
    
from keras.preprocessing.image import ImageDataGenerator

if useDataGenResnet50: 
    ### Data Augmentation

    # create and configure augmented image generator
    datagen_train = ImageDataGenerator(
        width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
        height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
        horizontal_flip=True) # randomly flip images horizontally

    # print shape of training set
    print('train_tensors shape:', train_tensors.shape)

    # fit augmented image generator on data
    datagen_train.fit(train_tensors)

    # create and configure augmented image generator
    datagen_valid = ImageDataGenerator(
        width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
        height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
        horizontal_flip=True) # randomly flip images horizontally

    # print shape of training set
    print('valid_tensors shape:', valid_tensors.shape)

    # fit augmented image generator on data
    datagen_train.fit(valid_tensors)

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
from keras.callbacks import ModelCheckpoint, EarlyStopping

# train the model
batch_size = 32 # 8, 16, 32, train_Resnet50.shape[0], seem to have enough memory to handle this
epochs = 20

if useVGG19:
    checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG19.hdf5', 
                               verbose=1, save_best_only=True)
    VGG19_CustomHead.fit(train_VGG19, train_targets, 
                     epochs=20, batch_size=batch_size, 
                     validation_data=(valid_VGG19, valid_targets), 
                     callbacks=[checkpointer], verbose=1, shuffle=True)

if useResnet50:
    checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Resnet50.hdf5', 
                               verbose=1, save_best_only=True)
    #EarlyStopping(monitor='val_loss', 
    #              min_delta=0, patience=3, 
    #              verbose=0, mode='auto', 
    #              baseline=None, restore_best_weights=False)
    
    if useDataGenResnet50:               
        Resnet50_CustomHead.fit_generator(datagen_train.flow(train_Resnet50, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_Resnet50.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer],
                    validation_data=datagen_valid.flow(valid_Resnet50, valid_targets, batch_size=batch_size),
                    validation_steps=valid_Resnet50.shape[0] // batch_size)
    else:
        Resnet50_CustomHead.fit(train_Resnet50, train_targets, 
                                epochs=epochs, batch_size=batch_size,
                                validation_data=(valid_Resnet50, valid_targets), 
                                callbacks=[checkpointer], 
                                verbose=1, shuffle=True)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6680/6680 [==============================] - ETA: 3:44 - loss: 6.0508 - acc: 0.0000e+0 - ETA: 32s - loss: 6.0243 - acc: 0.0134    - ETA: 18s - loss: 5.8771 - acc: 0.01 - ETA: 11s - loss: 5.6636 - acc: 0.02 - ETA: 9s - loss: 5.5343 - acc: 0.0250 - ETA: 8s - loss: 5.4377 - acc: 0.029 - ETA: 6s - loss: 5.2943 - acc: 0.039 - ETA: 5s - loss: 5.1962 - acc: 0.048 - ETA: 5s - loss: 5.0857 - acc: 0.056 - ETA: 4s - loss: 4.9800 - acc: 0.068 - ETA: 3s - loss: 4.9000 - acc: 0.072 - ETA: 3s - loss: 4.8276 - acc: 0.078 - ETA: 3s - loss: 4.7480 - acc: 0.082 - ETA: 2s - loss: 4.6855 - acc: 0.091 - ETA: 2s - loss: 4.6239 - acc: 0.098 - ETA: 2s - loss: 4.5508 - acc: 0.106 - ETA: 2s - loss: 4.4710 - acc: 0.117 - ETA: 1s - loss: 4.4008 - acc: 0.124 - ETA: 1s - loss: 4.3316 - acc: 0.134 - ETA: 1s - loss: 4.2652 - acc: 0.143 - ETA: 1s - loss: 4.2075 - acc: 0.149 - ETA: 1s - loss: 4.1570 - acc: 0.154 - ETA: 1s - loss: 4.1095 - acc: 0.160 - ETA: 1s - loss: 4.0435 - acc: 0.168 - ETA: 0s - loss: 4.0064 - acc: 0.172 - ETA: 0s - loss: 3.9622 - acc: 0.176 - ETA: 0s - loss: 3.9150 - acc: 0.184 - ETA: 0s - loss: 3.8619 - acc: 0.191 - ETA: 0s - loss: 3.8275 - acc: 0.195 - ETA: 0s - loss: 3.7942 - acc: 0.200 - ETA: 0s - loss: 3.7573 - acc: 0.204 - ETA: 0s - loss: 3.7240 - acc: 0.208 - ETA: 0s - loss: 3.6827 - acc: 0.213 - ETA: 0s - loss: 3.6421 - acc: 0.218 - 3s 484us/step - loss: 3.6242 - acc: 0.2207 - val_loss: 1.8706 - val_acc: 0.5593
#
# Epoch 00001: val_loss improved from inf to 1.87055, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 2/20
# 6680/6680 [==============================] - ETA: 1s - loss: 2.0036 - acc: 0.437 - ETA: 1s - loss: 2.1559 - acc: 0.491 - ETA: 1s - loss: 2.1929 - acc: 0.459 - ETA: 1s - loss: 2.0425 - acc: 0.488 - ETA: 1s - loss: 2.0288 - acc: 0.489 - ETA: 1s - loss: 2.0256 - acc: 0.479 - ETA: 1s - loss: 2.0343 - acc: 0.470 - ETA: 1s - loss: 2.0182 - acc: 0.474 - ETA: 1s - loss: 1.9984 - acc: 0.480 - ETA: 1s - loss: 2.0109 - acc: 0.476 - ETA: 1s - loss: 2.0032 - acc: 0.478 - ETA: 1s - loss: 1.9986 - acc: 0.480 - ETA: 1s - loss: 1.9888 - acc: 0.484 - ETA: 1s - loss: 1.9903 - acc: 0.488 - ETA: 1s - loss: 1.9768 - acc: 0.490 - ETA: 0s - loss: 1.9743 - acc: 0.490 - ETA: 0s - loss: 1.9694 - acc: 0.491 - ETA: 0s - loss: 1.9583 - acc: 0.494 - ETA: 0s - loss: 1.9504 - acc: 0.495 - ETA: 0s - loss: 1.9384 - acc: 0.498 - ETA: 0s - loss: 1.9352 - acc: 0.499 - ETA: 0s - loss: 1.9319 - acc: 0.500 - ETA: 0s - loss: 1.9141 - acc: 0.503 - ETA: 0s - loss: 1.9077 - acc: 0.504 - ETA: 0s - loss: 1.9014 - acc: 0.505 - ETA: 0s - loss: 1.8866 - acc: 0.509 - ETA: 0s - loss: 1.8780 - acc: 0.512 - ETA: 0s - loss: 1.8715 - acc: 0.513 - ETA: 0s - loss: 1.8582 - acc: 0.515 - ETA: 0s - loss: 1.8501 - acc: 0.516 - ETA: 0s - loss: 1.8485 - acc: 0.517 - ETA: 0s - loss: 1.8375 - acc: 0.520 - ETA: 0s - loss: 1.8257 - acc: 0.522 - 2s 297us/step - loss: 1.8191 - acc: 0.5241 - val_loss: 1.2551 - val_acc: 0.6695
#
# Epoch 00002: val_loss improved from 1.87055 to 1.25509, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 3/20
# 6680/6680 [==============================] - ETA: 2s - loss: 1.6049 - acc: 0.562 - ETA: 1s - loss: 1.3881 - acc: 0.609 - ETA: 1s - loss: 1.3583 - acc: 0.625 - ETA: 1s - loss: 1.3296 - acc: 0.635 - ETA: 1s - loss: 1.3440 - acc: 0.633 - ETA: 1s - loss: 1.3648 - acc: 0.626 - ETA: 1s - loss: 1.3565 - acc: 0.628 - ETA: 1s - loss: 1.3490 - acc: 0.627 - ETA: 1s - loss: 1.3494 - acc: 0.628 - ETA: 1s - loss: 1.3476 - acc: 0.629 - ETA: 1s - loss: 1.3301 - acc: 0.635 - ETA: 1s - loss: 1.3217 - acc: 0.638 - ETA: 1s - loss: 1.3166 - acc: 0.637 - ETA: 1s - loss: 1.3169 - acc: 0.636 - ETA: 1s - loss: 1.3074 - acc: 0.639 - ETA: 1s - loss: 1.3045 - acc: 0.636 - ETA: 0s - loss: 1.3097 - acc: 0.634 - ETA: 0s - loss: 1.3044 - acc: 0.637 - ETA: 0s - loss: 1.2922 - acc: 0.641 - ETA: 0s - loss: 1.2916 - acc: 0.641 - ETA: 0s - loss: 1.2934 - acc: 0.640 - ETA: 0s - loss: 1.2839 - acc: 0.642 - ETA: 0s - loss: 1.2797 - acc: 0.643 - ETA: 0s - loss: 1.2778 - acc: 0.644 - ETA: 0s - loss: 1.2720 - acc: 0.646 - ETA: 0s - loss: 1.2695 - acc: 0.646 - ETA: 0s - loss: 1.2714 - acc: 0.644 - ETA: 0s - loss: 1.2700 - acc: 0.645 - ETA: 0s - loss: 1.2679 - acc: 0.646 - ETA: 0s - loss: 1.2688 - acc: 0.646 - ETA: 0s - loss: 1.2669 - acc: 0.647 - ETA: 0s - loss: 1.2630 - acc: 0.648 - ETA: 0s - loss: 1.2580 - acc: 0.649 - ETA: 0s - loss: 1.2534 - acc: 0.650 - 2s 299us/step - loss: 1.2536 - acc: 0.6510 - val_loss: 1.0144 - val_acc: 0.7329
#
# Epoch 00003: val_loss improved from 1.25509 to 1.01445, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 4/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.7725 - acc: 0.750 - ETA: 1s - loss: 1.0255 - acc: 0.678 - ETA: 1s - loss: 1.0097 - acc: 0.701 - ETA: 1s - loss: 1.0081 - acc: 0.701 - ETA: 1s - loss: 1.0169 - acc: 0.700 - ETA: 1s - loss: 1.0115 - acc: 0.704 - ETA: 1s - loss: 1.0261 - acc: 0.703 - ETA: 1s - loss: 1.0309 - acc: 0.701 - ETA: 1s - loss: 1.0280 - acc: 0.706 - ETA: 1s - loss: 1.0196 - acc: 0.710 - ETA: 1s - loss: 1.0097 - acc: 0.710 - ETA: 1s - loss: 1.0226 - acc: 0.709 - ETA: 1s - loss: 1.0212 - acc: 0.710 - ETA: 1s - loss: 1.0120 - acc: 0.714 - ETA: 1s - loss: 1.0069 - acc: 0.712 - ETA: 1s - loss: 1.0111 - acc: 0.709 - ETA: 0s - loss: 1.0177 - acc: 0.707 - ETA: 0s - loss: 1.0282 - acc: 0.705 - ETA: 0s - loss: 1.0251 - acc: 0.705 - ETA: 0s - loss: 1.0202 - acc: 0.707 - ETA: 0s - loss: 1.0138 - acc: 0.708 - ETA: 0s - loss: 1.0084 - acc: 0.710 - ETA: 0s - loss: 1.0094 - acc: 0.710 - ETA: 0s - loss: 1.0060 - acc: 0.712 - ETA: 0s - loss: 1.0042 - acc: 0.713 - ETA: 0s - loss: 1.0017 - acc: 0.713 - ETA: 0s - loss: 1.0052 - acc: 0.713 - ETA: 0s - loss: 1.0071 - acc: 0.713 - ETA: 0s - loss: 1.0100 - acc: 0.712 - ETA: 0s - loss: 1.0129 - acc: 0.711 - ETA: 0s - loss: 1.0087 - acc: 0.712 - ETA: 0s - loss: 1.0122 - acc: 0.711 - ETA: 0s - loss: 1.0091 - acc: 0.712 - ETA: 0s - loss: 1.0122 - acc: 0.711 - 2s 302us/step - loss: 1.0090 - acc: 0.7126 - val_loss: 0.9835 - val_acc: 0.7174
#
# Epoch 00004: val_loss improved from 1.01445 to 0.98349, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 5/20
# 6680/6680 [==============================] - ETA: 2s - loss: 1.1432 - acc: 0.656 - ETA: 1s - loss: 0.8382 - acc: 0.767 - ETA: 1s - loss: 0.8700 - acc: 0.747 - ETA: 1s - loss: 0.8665 - acc: 0.759 - ETA: 1s - loss: 0.8528 - acc: 0.766 - ETA: 1s - loss: 0.8567 - acc: 0.767 - ETA: 1s - loss: 0.8540 - acc: 0.766 - ETA: 1s - loss: 0.8635 - acc: 0.766 - ETA: 1s - loss: 0.8617 - acc: 0.765 - ETA: 1s - loss: 0.8690 - acc: 0.763 - ETA: 1s - loss: 0.8618 - acc: 0.765 - ETA: 1s - loss: 0.8522 - acc: 0.770 - ETA: 1s - loss: 0.8485 - acc: 0.771 - ETA: 1s - loss: 0.8668 - acc: 0.765 - ETA: 1s - loss: 0.8665 - acc: 0.767 - ETA: 1s - loss: 0.8747 - acc: 0.764 - ETA: 1s - loss: 0.8824 - acc: 0.762 - ETA: 1s - loss: 0.8847 - acc: 0.761 - ETA: 1s - loss: 0.8828 - acc: 0.761 - ETA: 0s - loss: 0.8797 - acc: 0.762 - ETA: 0s - loss: 0.8838 - acc: 0.760 - ETA: 0s - loss: 0.8789 - acc: 0.761 - ETA: 0s - loss: 0.8791 - acc: 0.761 - ETA: 0s - loss: 0.8801 - acc: 0.762 - ETA: 0s - loss: 0.8837 - acc: 0.761 - ETA: 0s - loss: 0.8819 - acc: 0.761 - ETA: 0s - loss: 0.8795 - acc: 0.761 - ETA: 0s - loss: 0.8718 - acc: 0.763 - ETA: 0s - loss: 0.8703 - acc: 0.762 - ETA: 0s - loss: 0.8694 - acc: 0.762 - ETA: 0s - loss: 0.8744 - acc: 0.760 - ETA: 0s - loss: 0.8719 - acc: 0.760 - ETA: 0s - loss: 0.8749 - acc: 0.758 - ETA: 0s - loss: 0.8776 - acc: 0.757 - ETA: 0s - loss: 0.8757 - acc: 0.757 - ETA: 0s - loss: 0.8804 - acc: 0.755 - ETA: 0s - loss: 0.8763 - acc: 0.756 - 2s 322us/step - loss: 0.8766 - acc: 0.7558 - val_loss: 0.8974 - val_acc: 0.7341
#
# Epoch 00005: val_loss improved from 0.98349 to 0.89743, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 6/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.6975 - acc: 0.812 - ETA: 1s - loss: 0.8111 - acc: 0.745 - ETA: 1s - loss: 0.7470 - acc: 0.776 - ETA: 1s - loss: 0.7055 - acc: 0.786 - ETA: 1s - loss: 0.7244 - acc: 0.797 - ETA: 1s - loss: 0.7579 - acc: 0.792 - ETA: 1s - loss: 0.7433 - acc: 0.793 - ETA: 1s - loss: 0.7407 - acc: 0.795 - ETA: 1s - loss: 0.7445 - acc: 0.792 - ETA: 1s - loss: 0.7372 - acc: 0.793 - ETA: 1s - loss: 0.7407 - acc: 0.794 - ETA: 1s - loss: 0.7370 - acc: 0.796 - ETA: 1s - loss: 0.7309 - acc: 0.796 - ETA: 1s - loss: 0.7269 - acc: 0.798 - ETA: 1s - loss: 0.7267 - acc: 0.797 - ETA: 1s - loss: 0.7273 - acc: 0.796 - ETA: 0s - loss: 0.7360 - acc: 0.795 - ETA: 0s - loss: 0.7402 - acc: 0.793 - ETA: 0s - loss: 0.7406 - acc: 0.794 - ETA: 0s - loss: 0.7420 - acc: 0.791 - ETA: 0s - loss: 0.7384 - acc: 0.793 - ETA: 0s - loss: 0.7354 - acc: 0.793 - ETA: 0s - loss: 0.7372 - acc: 0.792 - ETA: 0s - loss: 0.7464 - acc: 0.789 - ETA: 0s - loss: 0.7481 - acc: 0.788 - ETA: 0s - loss: 0.7489 - acc: 0.787 - ETA: 0s - loss: 0.7460 - acc: 0.787 - ETA: 0s - loss: 0.7443 - acc: 0.787 - ETA: 0s - loss: 0.7451 - acc: 0.787 - ETA: 0s - loss: 0.7484 - acc: 0.785 - ETA: 0s - loss: 0.7510 - acc: 0.784 - ETA: 0s - loss: 0.7482 - acc: 0.784 - ETA: 0s - loss: 0.7493 - acc: 0.783 - ETA: 0s - loss: 0.7532 - acc: 0.782 - ETA: 0s - loss: 0.7549 - acc: 0.781 - 2s 297us/step - loss: 0.7552 - acc: 0.7814 - val_loss: 0.8752 - val_acc: 0.7557
#
# Epoch 00006: val_loss improved from 0.89743 to 0.87524, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 7/20
# 6680/6680 [==============================] - ETA: 2s - loss: 0.5499 - acc: 0.781 - ETA: 2s - loss: 0.6091 - acc: 0.838 - ETA: 1s - loss: 0.5996 - acc: 0.830 - ETA: 1s - loss: 0.6031 - acc: 0.835 - ETA: 1s - loss: 0.6217 - acc: 0.830 - ETA: 1s - loss: 0.6425 - acc: 0.821 - ETA: 1s - loss: 0.6393 - acc: 0.822 - ETA: 1s - loss: 0.6392 - acc: 0.826 - ETA: 1s - loss: 0.6407 - acc: 0.824 - ETA: 1s - loss: 0.6419 - acc: 0.825 - ETA: 1s - loss: 0.6504 - acc: 0.819 - ETA: 1s - loss: 0.6477 - acc: 0.820 - ETA: 1s - loss: 0.6467 - acc: 0.821 - ETA: 1s - loss: 0.6450 - acc: 0.821 - ETA: 1s - loss: 0.6476 - acc: 0.819 - ETA: 1s - loss: 0.6484 - acc: 0.820 - ETA: 1s - loss: 0.6472 - acc: 0.823 - ETA: 0s - loss: 0.6550 - acc: 0.823 - ETA: 0s - loss: 0.6569 - acc: 0.823 - ETA: 0s - loss: 0.6566 - acc: 0.821 - ETA: 0s - loss: 0.6566 - acc: 0.822 - ETA: 0s - loss: 0.6624 - acc: 0.820 - ETA: 0s - loss: 0.6652 - acc: 0.819 - ETA: 0s - loss: 0.6689 - acc: 0.818 - ETA: 0s - loss: 0.6714 - acc: 0.816 - ETA: 0s - loss: 0.6752 - acc: 0.813 - ETA: 0s - loss: 0.6765 - acc: 0.813 - ETA: 0s - loss: 0.6820 - acc: 0.810 - ETA: 0s - loss: 0.6845 - acc: 0.809 - ETA: 0s - loss: 0.6867 - acc: 0.808 - ETA: 0s - loss: 0.6856 - acc: 0.808 - ETA: 0s - loss: 0.6845 - acc: 0.809 - ETA: 0s - loss: 0.6868 - acc: 0.808 - ETA: 0s - loss: 0.6825 - acc: 0.810 - ETA: 0s - loss: 0.6775 - acc: 0.812 - 2s 301us/step - loss: 0.6757 - acc: 0.8129 - val_loss: 0.8061 - val_acc: 0.7617
#
# Epoch 00007: val_loss improved from 0.87524 to 0.80614, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 8/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.9471 - acc: 0.718 - ETA: 1s - loss: 0.6021 - acc: 0.843 - ETA: 1s - loss: 0.5908 - acc: 0.838 - ETA: 1s - loss: 0.6202 - acc: 0.815 - ETA: 1s - loss: 0.6173 - acc: 0.820 - ETA: 1s - loss: 0.6195 - acc: 0.815 - ETA: 1s - loss: 0.6080 - acc: 0.822 - ETA: 1s - loss: 0.5923 - acc: 0.829 - ETA: 1s - loss: 0.6137 - acc: 0.826 - ETA: 1s - loss: 0.6104 - acc: 0.825 - ETA: 1s - loss: 0.6056 - acc: 0.827 - ETA: 1s - loss: 0.6020 - acc: 0.826 - ETA: 1s - loss: 0.5956 - acc: 0.829 - ETA: 1s - loss: 0.5909 - acc: 0.832 - ETA: 1s - loss: 0.5880 - acc: 0.831 - ETA: 1s - loss: 0.5969 - acc: 0.827 - ETA: 1s - loss: 0.5982 - acc: 0.828 - ETA: 0s - loss: 0.6034 - acc: 0.826 - ETA: 0s - loss: 0.6024 - acc: 0.828 - ETA: 0s - loss: 0.6092 - acc: 0.826 - ETA: 0s - loss: 0.6038 - acc: 0.827 - ETA: 0s - loss: 0.6069 - acc: 0.825 - ETA: 0s - loss: 0.6063 - acc: 0.825 - ETA: 0s - loss: 0.6077 - acc: 0.824 - ETA: 0s - loss: 0.6062 - acc: 0.824 - ETA: 0s - loss: 0.6124 - acc: 0.823 - ETA: 0s - loss: 0.6105 - acc: 0.824 - ETA: 0s - loss: 0.6110 - acc: 0.824 - ETA: 0s - loss: 0.6083 - acc: 0.825 - ETA: 0s - loss: 0.6070 - acc: 0.824 - ETA: 0s - loss: 0.6067 - acc: 0.824 - ETA: 0s - loss: 0.6064 - acc: 0.824 - ETA: 0s - loss: 0.6090 - acc: 0.824 - ETA: 0s - loss: 0.6131 - acc: 0.824 - 2s 299us/step - loss: 0.6144 - acc: 0.8240 - val_loss: 0.8338 - val_acc: 0.7437
#
# Epoch 00008: val_loss did not improve from 0.80614
# Epoch 9/20
# 6680/6680 [==============================] - ETA: 2s - loss: 0.6055 - acc: 0.843 - ETA: 1s - loss: 0.6061 - acc: 0.839 - ETA: 1s - loss: 0.5548 - acc: 0.853 - ETA: 1s - loss: 0.5846 - acc: 0.835 - ETA: 1s - loss: 0.5660 - acc: 0.840 - ETA: 1s - loss: 0.5539 - acc: 0.844 - ETA: 1s - loss: 0.5590 - acc: 0.843 - ETA: 1s - loss: 0.5546 - acc: 0.845 - ETA: 1s - loss: 0.5535 - acc: 0.848 - ETA: 1s - loss: 0.5604 - acc: 0.845 - ETA: 1s - loss: 0.5640 - acc: 0.846 - ETA: 1s - loss: 0.5553 - acc: 0.846 - ETA: 1s - loss: 0.5622 - acc: 0.843 - ETA: 1s - loss: 0.5586 - acc: 0.843 - ETA: 1s - loss: 0.5637 - acc: 0.842 - ETA: 0s - loss: 0.5621 - acc: 0.844 - ETA: 0s - loss: 0.5651 - acc: 0.843 - ETA: 0s - loss: 0.5611 - acc: 0.844 - ETA: 0s - loss: 0.5613 - acc: 0.845 - ETA: 0s - loss: 0.5596 - acc: 0.845 - ETA: 0s - loss: 0.5617 - acc: 0.844 - ETA: 0s - loss: 0.5619 - acc: 0.845 - ETA: 0s - loss: 0.5586 - acc: 0.846 - ETA: 0s - loss: 0.5594 - acc: 0.845 - ETA: 0s - loss: 0.5656 - acc: 0.843 - ETA: 0s - loss: 0.5667 - acc: 0.842 - ETA: 0s - loss: 0.5679 - acc: 0.842 - ETA: 0s - loss: 0.5683 - acc: 0.841 - ETA: 0s - loss: 0.5657 - acc: 0.842 - ETA: 0s - loss: 0.5644 - acc: 0.842 - ETA: 0s - loss: 0.5645 - acc: 0.841 - ETA: 0s - loss: 0.5690 - acc: 0.840 - ETA: 0s - loss: 0.5711 - acc: 0.839 - ETA: 0s - loss: 0.5692 - acc: 0.839 - 2s 293us/step - loss: 0.5698 - acc: 0.8395 - val_loss: 0.7444 - val_acc: 0.7784
#
# Epoch 00009: val_loss improved from 0.80614 to 0.74438, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 10/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.2838 - acc: 0.937 - ETA: 1s - loss: 0.4235 - acc: 0.875 - ETA: 1s - loss: 0.4838 - acc: 0.853 - ETA: 1s - loss: 0.4876 - acc: 0.861 - ETA: 1s - loss: 0.4774 - acc: 0.861 - ETA: 1s - loss: 0.4756 - acc: 0.868 - ETA: 1s - loss: 0.4813 - acc: 0.866 - ETA: 1s - loss: 0.4874 - acc: 0.867 - ETA: 1s - loss: 0.4835 - acc: 0.869 - ETA: 1s - loss: 0.4854 - acc: 0.868 - ETA: 1s - loss: 0.4861 - acc: 0.868 - ETA: 1s - loss: 0.4877 - acc: 0.866 - ETA: 1s - loss: 0.4913 - acc: 0.864 - ETA: 1s - loss: 0.5024 - acc: 0.861 - ETA: 1s - loss: 0.4934 - acc: 0.865 - ETA: 0s - loss: 0.4964 - acc: 0.864 - ETA: 0s - loss: 0.5026 - acc: 0.862 - ETA: 0s - loss: 0.5040 - acc: 0.861 - ETA: 0s - loss: 0.5030 - acc: 0.861 - ETA: 0s - loss: 0.5007 - acc: 0.862 - ETA: 0s - loss: 0.5024 - acc: 0.862 - ETA: 0s - loss: 0.5037 - acc: 0.862 - ETA: 0s - loss: 0.5038 - acc: 0.861 - ETA: 0s - loss: 0.5043 - acc: 0.862 - ETA: 0s - loss: 0.5078 - acc: 0.861 - ETA: 0s - loss: 0.5035 - acc: 0.862 - ETA: 0s - loss: 0.5066 - acc: 0.861 - ETA: 0s - loss: 0.5079 - acc: 0.861 - ETA: 0s - loss: 0.5081 - acc: 0.861 - ETA: 0s - loss: 0.5090 - acc: 0.860 - ETA: 0s - loss: 0.5085 - acc: 0.860 - ETA: 0s - loss: 0.5083 - acc: 0.860 - ETA: 0s - loss: 0.5102 - acc: 0.860 - ETA: 0s - loss: 0.5092 - acc: 0.860 - 2s 287us/step - loss: 0.5086 - acc: 0.8609 - val_loss: 0.7388 - val_acc: 0.7760
#
# Epoch 00010: val_loss improved from 0.74438 to 0.73877, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 11/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.3880 - acc: 0.875 - ETA: 1s - loss: 0.4242 - acc: 0.883 - ETA: 1s - loss: 0.4418 - acc: 0.877 - ETA: 1s - loss: 0.4500 - acc: 0.876 - ETA: 1s - loss: 0.4567 - acc: 0.878 - ETA: 1s - loss: 0.4538 - acc: 0.881 - ETA: 1s - loss: 0.4334 - acc: 0.886 - ETA: 1s - loss: 0.4297 - acc: 0.886 - ETA: 1s - loss: 0.4297 - acc: 0.887 - ETA: 1s - loss: 0.4255 - acc: 0.888 - ETA: 1s - loss: 0.4407 - acc: 0.883 - ETA: 1s - loss: 0.4422 - acc: 0.883 - ETA: 1s - loss: 0.4458 - acc: 0.883 - ETA: 1s - loss: 0.4481 - acc: 0.880 - ETA: 1s - loss: 0.4557 - acc: 0.876 - ETA: 0s - loss: 0.4559 - acc: 0.877 - ETA: 0s - loss: 0.4580 - acc: 0.877 - ETA: 0s - loss: 0.4600 - acc: 0.877 - ETA: 0s - loss: 0.4589 - acc: 0.877 - ETA: 0s - loss: 0.4560 - acc: 0.876 - ETA: 0s - loss: 0.4570 - acc: 0.875 - ETA: 0s - loss: 0.4627 - acc: 0.872 - ETA: 0s - loss: 0.4618 - acc: 0.871 - ETA: 0s - loss: 0.4617 - acc: 0.871 - ETA: 0s - loss: 0.4649 - acc: 0.870 - ETA: 0s - loss: 0.4656 - acc: 0.870 - ETA: 0s - loss: 0.4660 - acc: 0.870 - ETA: 0s - loss: 0.4656 - acc: 0.869 - ETA: 0s - loss: 0.4665 - acc: 0.869 - ETA: 0s - loss: 0.4657 - acc: 0.871 - ETA: 0s - loss: 0.4699 - acc: 0.869 - ETA: 0s - loss: 0.4696 - acc: 0.870 - ETA: 0s - loss: 0.4698 - acc: 0.869 - ETA: 0s - loss: 0.4715 - acc: 0.868 - 2s 287us/step - loss: 0.4718 - acc: 0.8684 - val_loss: 0.7614 - val_acc: 0.7808
#
# Epoch 00011: val_loss did not improve from 0.73877
# Epoch 12/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.5564 - acc: 0.750 - ETA: 1s - loss: 0.4164 - acc: 0.870 - ETA: 1s - loss: 0.4264 - acc: 0.863 - ETA: 1s - loss: 0.4268 - acc: 0.871 - ETA: 1s - loss: 0.4293 - acc: 0.871 - ETA: 1s - loss: 0.4330 - acc: 0.871 - ETA: 1s - loss: 0.4288 - acc: 0.873 - ETA: 1s - loss: 0.4340 - acc: 0.874 - ETA: 1s - loss: 0.4184 - acc: 0.882 - ETA: 1s - loss: 0.4259 - acc: 0.877 - ETA: 1s - loss: 0.4284 - acc: 0.877 - ETA: 1s - loss: 0.4308 - acc: 0.875 - ETA: 1s - loss: 0.4348 - acc: 0.875 - ETA: 1s - loss: 0.4456 - acc: 0.873 - ETA: 1s - loss: 0.4472 - acc: 0.873 - ETA: 1s - loss: 0.4490 - acc: 0.872 - ETA: 0s - loss: 0.4491 - acc: 0.872 - ETA: 0s - loss: 0.4482 - acc: 0.875 - ETA: 0s - loss: 0.4484 - acc: 0.875 - ETA: 0s - loss: 0.4473 - acc: 0.876 - ETA: 0s - loss: 0.4444 - acc: 0.877 - ETA: 0s - loss: 0.4454 - acc: 0.877 - ETA: 0s - loss: 0.4476 - acc: 0.875 - ETA: 0s - loss: 0.4448 - acc: 0.876 - ETA: 0s - loss: 0.4455 - acc: 0.876 - ETA: 0s - loss: 0.4471 - acc: 0.876 - ETA: 0s - loss: 0.4452 - acc: 0.876 - ETA: 0s - loss: 0.4454 - acc: 0.876 - ETA: 0s - loss: 0.4513 - acc: 0.874 - ETA: 0s - loss: 0.4508 - acc: 0.874 - ETA: 0s - loss: 0.4521 - acc: 0.874 - ETA: 0s - loss: 0.4529 - acc: 0.873 - ETA: 0s - loss: 0.4516 - acc: 0.873 - ETA: 0s - loss: 0.4521 - acc: 0.873 - 2s 293us/step - loss: 0.4499 - acc: 0.8750 - val_loss: 0.7197 - val_acc: 0.7928
#
# Epoch 00012: val_loss improved from 0.73877 to 0.71968, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 13/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.2321 - acc: 0.906 - ETA: 1s - loss: 0.3720 - acc: 0.894 - ETA: 1s - loss: 0.3465 - acc: 0.901 - ETA: 1s - loss: 0.3585 - acc: 0.904 - ETA: 1s - loss: 0.3642 - acc: 0.902 - ETA: 1s - loss: 0.3549 - acc: 0.904 - ETA: 1s - loss: 0.3730 - acc: 0.898 - ETA: 1s - loss: 0.3641 - acc: 0.902 - ETA: 1s - loss: 0.3666 - acc: 0.896 - ETA: 1s - loss: 0.3577 - acc: 0.902 - ETA: 1s - loss: 0.3635 - acc: 0.901 - ETA: 1s - loss: 0.3690 - acc: 0.900 - ETA: 1s - loss: 0.3719 - acc: 0.899 - ETA: 1s - loss: 0.3775 - acc: 0.896 - ETA: 1s - loss: 0.3884 - acc: 0.893 - ETA: 0s - loss: 0.4010 - acc: 0.889 - ETA: 0s - loss: 0.4066 - acc: 0.886 - ETA: 0s - loss: 0.4037 - acc: 0.887 - ETA: 0s - loss: 0.4086 - acc: 0.885 - ETA: 0s - loss: 0.4106 - acc: 0.883 - ETA: 0s - loss: 0.4109 - acc: 0.883 - ETA: 0s - loss: 0.4107 - acc: 0.884 - ETA: 0s - loss: 0.4114 - acc: 0.885 - ETA: 0s - loss: 0.4125 - acc: 0.885 - ETA: 0s - loss: 0.4125 - acc: 0.884 - ETA: 0s - loss: 0.4114 - acc: 0.885 - ETA: 0s - loss: 0.4116 - acc: 0.885 - ETA: 0s - loss: 0.4126 - acc: 0.885 - ETA: 0s - loss: 0.4100 - acc: 0.885 - ETA: 0s - loss: 0.4112 - acc: 0.885 - ETA: 0s - loss: 0.4144 - acc: 0.884 - ETA: 0s - loss: 0.4198 - acc: 0.883 - ETA: 0s - loss: 0.4205 - acc: 0.882 - 2s 284us/step - loss: 0.4194 - acc: 0.8835 - val_loss: 0.7775 - val_acc: 0.7808
#
# Epoch 00013: val_loss did not improve from 0.71968
# Epoch 14/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.5765 - acc: 0.875 - ETA: 1s - loss: 0.3589 - acc: 0.910 - ETA: 1s - loss: 0.3570 - acc: 0.896 - ETA: 1s - loss: 0.3578 - acc: 0.894 - ETA: 1s - loss: 0.3302 - acc: 0.910 - ETA: 1s - loss: 0.3255 - acc: 0.910 - ETA: 1s - loss: 0.3376 - acc: 0.905 - ETA: 1s - loss: 0.3440 - acc: 0.901 - ETA: 1s - loss: 0.3448 - acc: 0.900 - ETA: 1s - loss: 0.3374 - acc: 0.902 - ETA: 1s - loss: 0.3399 - acc: 0.900 - ETA: 1s - loss: 0.3552 - acc: 0.896 - ETA: 1s - loss: 0.3497 - acc: 0.900 - ETA: 1s - loss: 0.3528 - acc: 0.900 - ETA: 1s - loss: 0.3579 - acc: 0.898 - ETA: 0s - loss: 0.3564 - acc: 0.900 - ETA: 0s - loss: 0.3578 - acc: 0.899 - ETA: 0s - loss: 0.3584 - acc: 0.899 - ETA: 0s - loss: 0.3604 - acc: 0.899 - ETA: 0s - loss: 0.3619 - acc: 0.898 - ETA: 0s - loss: 0.3597 - acc: 0.899 - ETA: 0s - loss: 0.3614 - acc: 0.898 - ETA: 0s - loss: 0.3604 - acc: 0.899 - ETA: 0s - loss: 0.3595 - acc: 0.900 - ETA: 0s - loss: 0.3627 - acc: 0.900 - ETA: 0s - loss: 0.3637 - acc: 0.900 - ETA: 0s - loss: 0.3656 - acc: 0.900 - ETA: 0s - loss: 0.3675 - acc: 0.899 - ETA: 0s - loss: 0.3689 - acc: 0.899 - ETA: 0s - loss: 0.3686 - acc: 0.899 - ETA: 0s - loss: 0.3647 - acc: 0.900 - ETA: 0s - loss: 0.3642 - acc: 0.900 - ETA: 0s - loss: 0.3685 - acc: 0.899 - ETA: 0s - loss: 0.3717 - acc: 0.897 - 2s 288us/step - loss: 0.3740 - acc: 0.8972 - val_loss: 0.7440 - val_acc: 0.7868
#
# Epoch 00014: val_loss did not improve from 0.71968
# Epoch 15/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.6328 - acc: 0.843 - ETA: 1s - loss: 0.3152 - acc: 0.942 - ETA: 1s - loss: 0.3449 - acc: 0.920 - ETA: 1s - loss: 0.3215 - acc: 0.924 - ETA: 1s - loss: 0.3399 - acc: 0.912 - ETA: 1s - loss: 0.3428 - acc: 0.914 - ETA: 1s - loss: 0.3525 - acc: 0.909 - ETA: 1s - loss: 0.3534 - acc: 0.907 - ETA: 1s - loss: 0.3505 - acc: 0.909 - ETA: 1s - loss: 0.3489 - acc: 0.910 - ETA: 1s - loss: 0.3464 - acc: 0.910 - ETA: 1s - loss: 0.3420 - acc: 0.910 - ETA: 1s - loss: 0.3409 - acc: 0.909 - ETA: 1s - loss: 0.3477 - acc: 0.906 - ETA: 1s - loss: 0.3502 - acc: 0.903 - ETA: 0s - loss: 0.3433 - acc: 0.905 - ETA: 0s - loss: 0.3441 - acc: 0.905 - ETA: 0s - loss: 0.3421 - acc: 0.907 - ETA: 0s - loss: 0.3450 - acc: 0.907 - ETA: 0s - loss: 0.3432 - acc: 0.907 - ETA: 0s - loss: 0.3402 - acc: 0.908 - ETA: 0s - loss: 0.3381 - acc: 0.909 - ETA: 0s - loss: 0.3401 - acc: 0.909 - ETA: 0s - loss: 0.3396 - acc: 0.909 - ETA: 0s - loss: 0.3386 - acc: 0.910 - ETA: 0s - loss: 0.3404 - acc: 0.909 - ETA: 0s - loss: 0.3450 - acc: 0.908 - ETA: 0s - loss: 0.3435 - acc: 0.907 - ETA: 0s - loss: 0.3471 - acc: 0.905 - ETA: 0s - loss: 0.3477 - acc: 0.906 - ETA: 0s - loss: 0.3478 - acc: 0.906 - ETA: 0s - loss: 0.3469 - acc: 0.906 - ETA: 0s - loss: 0.3471 - acc: 0.906 - ETA: 0s - loss: 0.3472 - acc: 0.906 - 2s 286us/step - loss: 0.3476 - acc: 0.9064 - val_loss: 0.7300 - val_acc: 0.7760
#
# Epoch 00015: val_loss did not improve from 0.71968
# Epoch 16/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.3487 - acc: 0.906 - ETA: 1s - loss: 0.3228 - acc: 0.915 - ETA: 1s - loss: 0.2876 - acc: 0.935 - ETA: 1s - loss: 0.2825 - acc: 0.937 - ETA: 1s - loss: 0.2788 - acc: 0.931 - ETA: 1s - loss: 0.2849 - acc: 0.929 - ETA: 1s - loss: 0.2861 - acc: 0.930 - ETA: 1s - loss: 0.2900 - acc: 0.927 - ETA: 1s - loss: 0.2851 - acc: 0.929 - ETA: 1s - loss: 0.2870 - acc: 0.930 - ETA: 1s - loss: 0.2938 - acc: 0.925 - ETA: 1s - loss: 0.2951 - acc: 0.925 - ETA: 1s - loss: 0.3024 - acc: 0.924 - ETA: 1s - loss: 0.3029 - acc: 0.923 - ETA: 1s - loss: 0.3070 - acc: 0.922 - ETA: 0s - loss: 0.3115 - acc: 0.920 - ETA: 0s - loss: 0.3151 - acc: 0.918 - ETA: 0s - loss: 0.3179 - acc: 0.917 - ETA: 0s - loss: 0.3142 - acc: 0.919 - ETA: 0s - loss: 0.3139 - acc: 0.920 - ETA: 0s - loss: 0.3167 - acc: 0.918 - ETA: 0s - loss: 0.3167 - acc: 0.918 - ETA: 0s - loss: 0.3176 - acc: 0.917 - ETA: 0s - loss: 0.3172 - acc: 0.917 - ETA: 0s - loss: 0.3178 - acc: 0.916 - ETA: 0s - loss: 0.3187 - acc: 0.915 - ETA: 0s - loss: 0.3221 - acc: 0.915 - ETA: 0s - loss: 0.3182 - acc: 0.916 - ETA: 0s - loss: 0.3194 - acc: 0.915 - ETA: 0s - loss: 0.3226 - acc: 0.915 - ETA: 0s - loss: 0.3246 - acc: 0.914 - ETA: 0s - loss: 0.3272 - acc: 0.912 - ETA: 0s - loss: 0.3289 - acc: 0.911 - ETA: 0s - loss: 0.3330 - acc: 0.909 - 2s 295us/step - loss: 0.3367 - acc: 0.9085 - val_loss: 0.7523 - val_acc: 0.7868
#
# Epoch 00016: val_loss did not improve from 0.71968
# Epoch 17/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.4412 - acc: 0.875 - ETA: 1s - loss: 0.3275 - acc: 0.901 - ETA: 1s - loss: 0.3008 - acc: 0.913 - ETA: 1s - loss: 0.3152 - acc: 0.912 - ETA: 1s - loss: 0.3409 - acc: 0.907 - ETA: 1s - loss: 0.3289 - acc: 0.908 - ETA: 1s - loss: 0.3177 - acc: 0.910 - ETA: 1s - loss: 0.3138 - acc: 0.912 - ETA: 1s - loss: 0.3098 - acc: 0.914 - ETA: 1s - loss: 0.3051 - acc: 0.915 - ETA: 1s - loss: 0.2954 - acc: 0.920 - ETA: 1s - loss: 0.3007 - acc: 0.918 - ETA: 1s - loss: 0.3007 - acc: 0.919 - ETA: 1s - loss: 0.3025 - acc: 0.917 - ETA: 1s - loss: 0.2982 - acc: 0.918 - ETA: 1s - loss: 0.2966 - acc: 0.919 - ETA: 0s - loss: 0.2973 - acc: 0.919 - ETA: 0s - loss: 0.2961 - acc: 0.919 - ETA: 0s - loss: 0.3017 - acc: 0.918 - ETA: 0s - loss: 0.2979 - acc: 0.920 - ETA: 0s - loss: 0.2968 - acc: 0.919 - ETA: 0s - loss: 0.2959 - acc: 0.921 - ETA: 0s - loss: 0.2949 - acc: 0.920 - ETA: 0s - loss: 0.2945 - acc: 0.921 - ETA: 0s - loss: 0.2982 - acc: 0.919 - ETA: 0s - loss: 0.3005 - acc: 0.919 - ETA: 0s - loss: 0.3023 - acc: 0.918 - ETA: 0s - loss: 0.3006 - acc: 0.918 - ETA: 0s - loss: 0.3004 - acc: 0.919 - ETA: 0s - loss: 0.3013 - acc: 0.918 - ETA: 0s - loss: 0.3025 - acc: 0.918 - ETA: 0s - loss: 0.3041 - acc: 0.917 - ETA: 0s - loss: 0.3058 - acc: 0.917 - ETA: 0s - loss: 0.3067 - acc: 0.916 - ETA: 0s - loss: 0.3079 - acc: 0.916 - 2s 291us/step - loss: 0.3089 - acc: 0.9160 - val_loss: 0.7202 - val_acc: 0.7988
#
# Epoch 00017: val_loss did not improve from 0.71968
# Epoch 18/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.2950 - acc: 0.937 - ETA: 1s - loss: 0.3143 - acc: 0.915 - ETA: 1s - loss: 0.2949 - acc: 0.923 - ETA: 1s - loss: 0.2914 - acc: 0.922 - ETA: 1s - loss: 0.2878 - acc: 0.921 - ETA: 1s - loss: 0.2870 - acc: 0.924 - ETA: 1s - loss: 0.2798 - acc: 0.927 - ETA: 1s - loss: 0.2785 - acc: 0.928 - ETA: 1s - loss: 0.2717 - acc: 0.933 - ETA: 1s - loss: 0.2730 - acc: 0.931 - ETA: 1s - loss: 0.2758 - acc: 0.930 - ETA: 1s - loss: 0.2796 - acc: 0.930 - ETA: 1s - loss: 0.2747 - acc: 0.931 - ETA: 1s - loss: 0.2734 - acc: 0.930 - ETA: 1s - loss: 0.2721 - acc: 0.930 - ETA: 1s - loss: 0.2803 - acc: 0.928 - ETA: 0s - loss: 0.2821 - acc: 0.928 - ETA: 0s - loss: 0.2844 - acc: 0.928 - ETA: 0s - loss: 0.2865 - acc: 0.926 - ETA: 0s - loss: 0.2886 - acc: 0.925 - ETA: 0s - loss: 0.2873 - acc: 0.926 - ETA: 0s - loss: 0.2865 - acc: 0.926 - ETA: 0s - loss: 0.2878 - acc: 0.926 - ETA: 0s - loss: 0.2933 - acc: 0.924 - ETA: 0s - loss: 0.2939 - acc: 0.923 - ETA: 0s - loss: 0.2923 - acc: 0.924 - ETA: 0s - loss: 0.2942 - acc: 0.924 - ETA: 0s - loss: 0.2935 - acc: 0.923 - ETA: 0s - loss: 0.2970 - acc: 0.922 - ETA: 0s - loss: 0.2979 - acc: 0.921 - ETA: 0s - loss: 0.2988 - acc: 0.921 - ETA: 0s - loss: 0.3013 - acc: 0.921 - ETA: 0s - loss: 0.3003 - acc: 0.920 - ETA: 0s - loss: 0.3012 - acc: 0.920 - ETA: 0s - loss: 0.2996 - acc: 0.920 - 2s 293us/step - loss: 0.2993 - acc: 0.9210 - val_loss: 0.7003 - val_acc: 0.7952
#
# Epoch 00018: val_loss improved from 0.71968 to 0.70029, saving model to saved_models/weights.best.VGG19.hdf5
# Epoch 19/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.2411 - acc: 0.968 - ETA: 1s - loss: 0.2742 - acc: 0.933 - ETA: 1s - loss: 0.2700 - acc: 0.932 - ETA: 1s - loss: 0.2554 - acc: 0.930 - ETA: 1s - loss: 0.2529 - acc: 0.936 - ETA: 1s - loss: 0.2428 - acc: 0.942 - ETA: 1s - loss: 0.2416 - acc: 0.940 - ETA: 1s - loss: 0.2405 - acc: 0.940 - ETA: 1s - loss: 0.2475 - acc: 0.939 - ETA: 1s - loss: 0.2497 - acc: 0.938 - ETA: 1s - loss: 0.2513 - acc: 0.938 - ETA: 1s - loss: 0.2533 - acc: 0.937 - ETA: 1s - loss: 0.2587 - acc: 0.936 - ETA: 1s - loss: 0.2569 - acc: 0.936 - ETA: 1s - loss: 0.2614 - acc: 0.934 - ETA: 1s - loss: 0.2625 - acc: 0.935 - ETA: 0s - loss: 0.2603 - acc: 0.934 - ETA: 0s - loss: 0.2617 - acc: 0.933 - ETA: 0s - loss: 0.2607 - acc: 0.933 - ETA: 0s - loss: 0.2622 - acc: 0.933 - ETA: 0s - loss: 0.2650 - acc: 0.931 - ETA: 0s - loss: 0.2664 - acc: 0.930 - ETA: 0s - loss: 0.2652 - acc: 0.931 - ETA: 0s - loss: 0.2663 - acc: 0.929 - ETA: 0s - loss: 0.2660 - acc: 0.930 - ETA: 0s - loss: 0.2696 - acc: 0.928 - ETA: 0s - loss: 0.2694 - acc: 0.927 - ETA: 0s - loss: 0.2718 - acc: 0.926 - ETA: 0s - loss: 0.2771 - acc: 0.924 - ETA: 0s - loss: 0.2766 - acc: 0.925 - ETA: 0s - loss: 0.2754 - acc: 0.925 - ETA: 0s - loss: 0.2764 - acc: 0.925 - ETA: 0s - loss: 0.2762 - acc: 0.926 - ETA: 0s - loss: 0.2756 - acc: 0.926 - ETA: 0s - loss: 0.2770 - acc: 0.925 - 2s 295us/step - loss: 0.2770 - acc: 0.9254 - val_loss: 0.7405 - val_acc: 0.7713
#
# Epoch 00019: val_loss did not improve from 0.70029
# Epoch 20/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.1052 - acc: 0.968 - ETA: 1s - loss: 0.2303 - acc: 0.933 - ETA: 1s - loss: 0.2461 - acc: 0.927 - ETA: 1s - loss: 0.2371 - acc: 0.932 - ETA: 1s - loss: 0.2370 - acc: 0.936 - ETA: 1s - loss: 0.2354 - acc: 0.938 - ETA: 1s - loss: 0.2441 - acc: 0.935 - ETA: 1s - loss: 0.2518 - acc: 0.935 - ETA: 1s - loss: 0.2534 - acc: 0.933 - ETA: 1s - loss: 0.2594 - acc: 0.930 - ETA: 1s - loss: 0.2556 - acc: 0.933 - ETA: 1s - loss: 0.2562 - acc: 0.932 - ETA: 1s - loss: 0.2607 - acc: 0.932 - ETA: 1s - loss: 0.2651 - acc: 0.928 - ETA: 1s - loss: 0.2653 - acc: 0.929 - ETA: 1s - loss: 0.2670 - acc: 0.928 - ETA: 0s - loss: 0.2628 - acc: 0.929 - ETA: 0s - loss: 0.2598 - acc: 0.931 - ETA: 0s - loss: 0.2595 - acc: 0.932 - ETA: 0s - loss: 0.2626 - acc: 0.931 - ETA: 0s - loss: 0.2657 - acc: 0.931 - ETA: 0s - loss: 0.2666 - acc: 0.930 - ETA: 0s - loss: 0.2696 - acc: 0.930 - ETA: 0s - loss: 0.2733 - acc: 0.928 - ETA: 0s - loss: 0.2738 - acc: 0.927 - ETA: 0s - loss: 0.2743 - acc: 0.927 - ETA: 0s - loss: 0.2766 - acc: 0.925 - ETA: 0s - loss: 0.2772 - acc: 0.926 - ETA: 0s - loss: 0.2792 - acc: 0.925 - ETA: 0s - loss: 0.2808 - acc: 0.924 - ETA: 0s - loss: 0.2844 - acc: 0.923 - ETA: 0s - loss: 0.2864 - acc: 0.922 - ETA: 0s - loss: 0.2860 - acc: 0.923 - ETA: 0s - loss: 0.2847 - acc: 0.923 - ETA: 0s - loss: 0.2831 - acc: 0.924 - 2s 298us/step - loss: 0.2837 - acc: 0.9244 - val_loss: 0.7220 - val_acc: 0.7760
#
# Epoch 00020: val_loss did not improve from 0.70029
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6680/6680 [==============================] - ETA: 3:03 - loss: 5.3912 - acc: 0.031 - ETA: 15s - loss: 5.4309 - acc: 0.054 - ETA: 8s - loss: 4.9402 - acc: 0.0856 - ETA: 5s - loss: 4.5998 - acc: 0.119 - ETA: 3s - loss: 4.2721 - acc: 0.155 - ETA: 3s - loss: 4.0257 - acc: 0.187 - ETA: 2s - loss: 3.8234 - acc: 0.219 - ETA: 2s - loss: 3.6057 - acc: 0.252 - ETA: 1s - loss: 3.4230 - acc: 0.277 - ETA: 1s - loss: 3.2669 - acc: 0.302 - ETA: 1s - loss: 3.1237 - acc: 0.323 - ETA: 1s - loss: 3.0142 - acc: 0.340 - ETA: 0s - loss: 2.8973 - acc: 0.358 - ETA: 0s - loss: 2.8072 - acc: 0.373 - ETA: 0s - loss: 2.7299 - acc: 0.386 - ETA: 0s - loss: 2.6541 - acc: 0.400 - ETA: 0s - loss: 2.5756 - acc: 0.411 - ETA: 0s - loss: 2.5067 - acc: 0.422 - ETA: 0s - loss: 2.4419 - acc: 0.435 - ETA: 0s - loss: 2.3860 - acc: 0.446 - 2s 315us/step - loss: 2.3543 - acc: 0.4522 - val_loss: 1.1182 - val_acc: 0.7114
#
# Epoch 00001: val_loss improved from inf to 1.11822, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 2/20
# 6680/6680 [==============================] - ETA: 1s - loss: 1.0517 - acc: 0.625 - ETA: 0s - loss: 1.0074 - acc: 0.703 - ETA: 0s - loss: 0.9991 - acc: 0.724 - ETA: 0s - loss: 1.0195 - acc: 0.726 - ETA: 0s - loss: 0.9901 - acc: 0.734 - ETA: 0s - loss: 0.9971 - acc: 0.731 - ETA: 0s - loss: 0.9920 - acc: 0.729 - ETA: 0s - loss: 0.9962 - acc: 0.724 - ETA: 0s - loss: 0.9990 - acc: 0.724 - ETA: 0s - loss: 0.9950 - acc: 0.724 - ETA: 0s - loss: 0.9728 - acc: 0.729 - ETA: 0s - loss: 0.9642 - acc: 0.731 - ETA: 0s - loss: 0.9550 - acc: 0.735 - ETA: 0s - loss: 0.9535 - acc: 0.732 - ETA: 0s - loss: 0.9512 - acc: 0.732 - ETA: 0s - loss: 0.9548 - acc: 0.730 - ETA: 0s - loss: 0.9567 - acc: 0.729 - ETA: 0s - loss: 0.9447 - acc: 0.733 - ETA: 0s - loss: 0.9295 - acc: 0.739 - ETA: 0s - loss: 0.9260 - acc: 0.740 - 1s 162us/step - loss: 0.9289 - acc: 0.7398 - val_loss: 0.8885 - val_acc: 0.7461
#
# Epoch 00002: val_loss improved from 1.11822 to 0.88847, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 3/20
# 6680/6680 [==============================] - ETA: 1s - loss: 1.1090 - acc: 0.687 - ETA: 0s - loss: 0.5883 - acc: 0.841 - ETA: 0s - loss: 0.6037 - acc: 0.829 - ETA: 0s - loss: 0.6310 - acc: 0.811 - ETA: 0s - loss: 0.6202 - acc: 0.818 - ETA: 0s - loss: 0.6211 - acc: 0.822 - ETA: 0s - loss: 0.6309 - acc: 0.820 - ETA: 0s - loss: 0.6420 - acc: 0.817 - ETA: 0s - loss: 0.6525 - acc: 0.812 - ETA: 0s - loss: 0.6487 - acc: 0.816 - ETA: 0s - loss: 0.6420 - acc: 0.817 - ETA: 0s - loss: 0.6369 - acc: 0.818 - ETA: 0s - loss: 0.6309 - acc: 0.821 - ETA: 0s - loss: 0.6296 - acc: 0.820 - ETA: 0s - loss: 0.6315 - acc: 0.816 - ETA: 0s - loss: 0.6271 - acc: 0.819 - ETA: 0s - loss: 0.6307 - acc: 0.818 - ETA: 0s - loss: 0.6309 - acc: 0.819 - ETA: 0s - loss: 0.6303 - acc: 0.819 - ETA: 0s - loss: 0.6312 - acc: 0.819 - 1s 162us/step - loss: 0.6309 - acc: 0.8196 - val_loss: 0.7592 - val_acc: 0.7689
#
# Epoch 00003: val_loss improved from 0.88847 to 0.75924, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 4/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.5133 - acc: 0.843 - ETA: 0s - loss: 0.4327 - acc: 0.867 - ETA: 0s - loss: 0.4565 - acc: 0.866 - ETA: 0s - loss: 0.4297 - acc: 0.873 - ETA: 0s - loss: 0.4235 - acc: 0.873 - ETA: 0s - loss: 0.4267 - acc: 0.872 - ETA: 0s - loss: 0.4363 - acc: 0.868 - ETA: 0s - loss: 0.4427 - acc: 0.868 - ETA: 0s - loss: 0.4572 - acc: 0.865 - ETA: 0s - loss: 0.4529 - acc: 0.869 - ETA: 0s - loss: 0.4486 - acc: 0.871 - ETA: 0s - loss: 0.4541 - acc: 0.870 - ETA: 0s - loss: 0.4495 - acc: 0.872 - ETA: 0s - loss: 0.4525 - acc: 0.871 - ETA: 0s - loss: 0.4554 - acc: 0.869 - ETA: 0s - loss: 0.4550 - acc: 0.869 - ETA: 0s - loss: 0.4585 - acc: 0.867 - ETA: 0s - loss: 0.4606 - acc: 0.866 - ETA: 0s - loss: 0.4617 - acc: 0.866 - ETA: 0s - loss: 0.4672 - acc: 0.865 - 1s 159us/step - loss: 0.4676 - acc: 0.8650 - val_loss: 0.6805 - val_acc: 0.8132
#
# Epoch 00004: val_loss improved from 0.75924 to 0.68047, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 5/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.4771 - acc: 0.906 - ETA: 0s - loss: 0.2830 - acc: 0.934 - ETA: 0s - loss: 0.3300 - acc: 0.911 - ETA: 0s - loss: 0.3481 - acc: 0.906 - ETA: 0s - loss: 0.3779 - acc: 0.896 - ETA: 0s - loss: 0.3691 - acc: 0.900 - ETA: 0s - loss: 0.3531 - acc: 0.907 - ETA: 0s - loss: 0.3410 - acc: 0.911 - ETA: 0s - loss: 0.3416 - acc: 0.911 - ETA: 0s - loss: 0.3388 - acc: 0.913 - ETA: 0s - loss: 0.3406 - acc: 0.912 - ETA: 0s - loss: 0.3442 - acc: 0.911 - ETA: 0s - loss: 0.3507 - acc: 0.909 - ETA: 0s - loss: 0.3570 - acc: 0.905 - ETA: 0s - loss: 0.3581 - acc: 0.904 - ETA: 0s - loss: 0.3658 - acc: 0.900 - ETA: 0s - loss: 0.3664 - acc: 0.900 - ETA: 0s - loss: 0.3695 - acc: 0.900 - ETA: 0s - loss: 0.3680 - acc: 0.901 - ETA: 0s - loss: 0.3675 - acc: 0.900 - ETA: 0s - loss: 0.3684 - acc: 0.900 - 1s 170us/step - loss: 0.3694 - acc: 0.9006 - val_loss: 0.6502 - val_acc: 0.7988
#
# Epoch 00005: val_loss improved from 0.68047 to 0.65021, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 6/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.3855 - acc: 0.906 - ETA: 0s - loss: 0.3051 - acc: 0.903 - ETA: 0s - loss: 0.2871 - acc: 0.911 - ETA: 0s - loss: 0.2849 - acc: 0.919 - ETA: 0s - loss: 0.2781 - acc: 0.927 - ETA: 0s - loss: 0.2635 - acc: 0.932 - ETA: 0s - loss: 0.2692 - acc: 0.929 - ETA: 0s - loss: 0.2721 - acc: 0.928 - ETA: 0s - loss: 0.2858 - acc: 0.921 - ETA: 0s - loss: 0.2856 - acc: 0.923 - ETA: 0s - loss: 0.2945 - acc: 0.919 - ETA: 0s - loss: 0.2972 - acc: 0.918 - ETA: 0s - loss: 0.3000 - acc: 0.917 - ETA: 0s - loss: 0.2977 - acc: 0.918 - ETA: 0s - loss: 0.2956 - acc: 0.920 - ETA: 0s - loss: 0.2950 - acc: 0.920 - ETA: 0s - loss: 0.2989 - acc: 0.920 - ETA: 0s - loss: 0.2987 - acc: 0.919 - ETA: 0s - loss: 0.2963 - acc: 0.919 - ETA: 0s - loss: 0.2984 - acc: 0.918 - ETA: 0s - loss: 0.2982 - acc: 0.918 - 1s 168us/step - loss: 0.2981 - acc: 0.9184 - val_loss: 0.6501 - val_acc: 0.8120
#
# Epoch 00006: val_loss improved from 0.65021 to 0.65011, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 7/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.1306 - acc: 1.000 - ETA: 1s - loss: 0.1849 - acc: 0.960 - ETA: 0s - loss: 0.1946 - acc: 0.958 - ETA: 0s - loss: 0.1932 - acc: 0.954 - ETA: 0s - loss: 0.2012 - acc: 0.949 - ETA: 0s - loss: 0.2098 - acc: 0.948 - ETA: 0s - loss: 0.2209 - acc: 0.945 - ETA: 0s - loss: 0.2252 - acc: 0.944 - ETA: 0s - loss: 0.2242 - acc: 0.944 - ETA: 0s - loss: 0.2281 - acc: 0.943 - ETA: 0s - loss: 0.2342 - acc: 0.940 - ETA: 0s - loss: 0.2345 - acc: 0.941 - ETA: 0s - loss: 0.2372 - acc: 0.938 - ETA: 0s - loss: 0.2407 - acc: 0.937 - ETA: 0s - loss: 0.2410 - acc: 0.937 - ETA: 0s - loss: 0.2436 - acc: 0.936 - ETA: 0s - loss: 0.2444 - acc: 0.937 - ETA: 0s - loss: 0.2492 - acc: 0.935 - ETA: 0s - loss: 0.2508 - acc: 0.935 - ETA: 0s - loss: 0.2508 - acc: 0.935 - 1s 162us/step - loss: 0.2525 - acc: 0.9344 - val_loss: 0.6458 - val_acc: 0.7976
#
# Epoch 00007: val_loss improved from 0.65011 to 0.64578, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 8/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.1345 - acc: 0.906 - ETA: 0s - loss: 0.1493 - acc: 0.968 - ETA: 0s - loss: 0.1584 - acc: 0.968 - ETA: 0s - loss: 0.1600 - acc: 0.963 - ETA: 0s - loss: 0.1729 - acc: 0.959 - ETA: 0s - loss: 0.1769 - acc: 0.956 - ETA: 0s - loss: 0.1734 - acc: 0.956 - ETA: 0s - loss: 0.1822 - acc: 0.954 - ETA: 0s - loss: 0.1848 - acc: 0.952 - ETA: 0s - loss: 0.1869 - acc: 0.952 - ETA: 0s - loss: 0.1864 - acc: 0.953 - ETA: 0s - loss: 0.1852 - acc: 0.952 - ETA: 0s - loss: 0.1868 - acc: 0.952 - ETA: 0s - loss: 0.1889 - acc: 0.950 - ETA: 0s - loss: 0.1912 - acc: 0.949 - ETA: 0s - loss: 0.1952 - acc: 0.947 - ETA: 0s - loss: 0.1938 - acc: 0.949 - ETA: 0s - loss: 0.1978 - acc: 0.947 - ETA: 0s - loss: 0.1991 - acc: 0.947 - ETA: 0s - loss: 0.2055 - acc: 0.945 - 1s 159us/step - loss: 0.2061 - acc: 0.9451 - val_loss: 0.6409 - val_acc: 0.8287
#
# Epoch 00008: val_loss improved from 0.64578 to 0.64093, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 9/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.2171 - acc: 0.968 - ETA: 0s - loss: 0.1186 - acc: 0.981 - ETA: 0s - loss: 0.1368 - acc: 0.973 - ETA: 0s - loss: 0.1365 - acc: 0.972 - ETA: 0s - loss: 0.1357 - acc: 0.974 - ETA: 0s - loss: 0.1484 - acc: 0.968 - ETA: 0s - loss: 0.1523 - acc: 0.966 - ETA: 0s - loss: 0.1523 - acc: 0.966 - ETA: 0s - loss: 0.1513 - acc: 0.966 - ETA: 0s - loss: 0.1524 - acc: 0.966 - ETA: 0s - loss: 0.1557 - acc: 0.963 - ETA: 0s - loss: 0.1573 - acc: 0.961 - ETA: 0s - loss: 0.1591 - acc: 0.960 - ETA: 0s - loss: 0.1571 - acc: 0.961 - ETA: 0s - loss: 0.1582 - acc: 0.961 - ETA: 0s - loss: 0.1626 - acc: 0.959 - ETA: 0s - loss: 0.1633 - acc: 0.959 - ETA: 0s - loss: 0.1655 - acc: 0.959 - ETA: 0s - loss: 0.1667 - acc: 0.958 - ETA: 0s - loss: 0.1687 - acc: 0.957 - 1s 163us/step - loss: 0.1718 - acc: 0.9566 - val_loss: 0.6500 - val_acc: 0.8132
#
# Epoch 00009: val_loss did not improve from 0.64093
# Epoch 10/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0601 - acc: 1.000 - ETA: 0s - loss: 0.1283 - acc: 0.966 - ETA: 0s - loss: 0.1144 - acc: 0.976 - ETA: 0s - loss: 0.1216 - acc: 0.974 - ETA: 0s - loss: 0.1308 - acc: 0.972 - ETA: 0s - loss: 0.1366 - acc: 0.970 - ETA: 0s - loss: 0.1399 - acc: 0.969 - ETA: 0s - loss: 0.1416 - acc: 0.968 - ETA: 0s - loss: 0.1441 - acc: 0.968 - ETA: 0s - loss: 0.1417 - acc: 0.968 - ETA: 0s - loss: 0.1399 - acc: 0.968 - ETA: 0s - loss: 0.1385 - acc: 0.968 - ETA: 0s - loss: 0.1393 - acc: 0.967 - ETA: 0s - loss: 0.1400 - acc: 0.968 - ETA: 0s - loss: 0.1457 - acc: 0.966 - ETA: 0s - loss: 0.1447 - acc: 0.966 - ETA: 0s - loss: 0.1465 - acc: 0.966 - ETA: 0s - loss: 0.1448 - acc: 0.966 - ETA: 0s - loss: 0.1456 - acc: 0.965 - ETA: 0s - loss: 0.1460 - acc: 0.965 - 1s 159us/step - loss: 0.1462 - acc: 0.9651 - val_loss: 0.6358 - val_acc: 0.8168
#
# Epoch 00010: val_loss improved from 0.64093 to 0.63585, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 11/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.1236 - acc: 1.000 - ETA: 0s - loss: 0.1270 - acc: 0.971 - ETA: 0s - loss: 0.1266 - acc: 0.972 - ETA: 0s - loss: 0.1286 - acc: 0.971 - ETA: 0s - loss: 0.1241 - acc: 0.973 - ETA: 0s - loss: 0.1180 - acc: 0.976 - ETA: 0s - loss: 0.1133 - acc: 0.976 - ETA: 0s - loss: 0.1101 - acc: 0.977 - ETA: 0s - loss: 0.1103 - acc: 0.977 - ETA: 0s - loss: 0.1113 - acc: 0.978 - ETA: 0s - loss: 0.1117 - acc: 0.978 - ETA: 0s - loss: 0.1112 - acc: 0.978 - ETA: 0s - loss: 0.1088 - acc: 0.979 - ETA: 0s - loss: 0.1136 - acc: 0.977 - ETA: 0s - loss: 0.1167 - acc: 0.976 - ETA: 0s - loss: 0.1179 - acc: 0.976 - ETA: 0s - loss: 0.1183 - acc: 0.976 - ETA: 0s - loss: 0.1196 - acc: 0.975 - ETA: 0s - loss: 0.1202 - acc: 0.975 - ETA: 0s - loss: 0.1200 - acc: 0.974 - 1s 162us/step - loss: 0.1196 - acc: 0.9750 - val_loss: 0.5850 - val_acc: 0.8275
#
# Epoch 00011: val_loss improved from 0.63585 to 0.58497, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 12/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0647 - acc: 1.000 - ETA: 1s - loss: 0.0692 - acc: 0.991 - ETA: 0s - loss: 0.0789 - acc: 0.984 - ETA: 0s - loss: 0.0739 - acc: 0.984 - ETA: 0s - loss: 0.0765 - acc: 0.983 - ETA: 0s - loss: 0.0813 - acc: 0.982 - ETA: 0s - loss: 0.0810 - acc: 0.981 - ETA: 0s - loss: 0.0817 - acc: 0.982 - ETA: 0s - loss: 0.0861 - acc: 0.981 - ETA: 0s - loss: 0.0865 - acc: 0.982 - ETA: 0s - loss: 0.0886 - acc: 0.980 - ETA: 0s - loss: 0.0874 - acc: 0.980 - ETA: 0s - loss: 0.0882 - acc: 0.979 - ETA: 0s - loss: 0.0886 - acc: 0.980 - ETA: 0s - loss: 0.0906 - acc: 0.979 - ETA: 0s - loss: 0.0898 - acc: 0.979 - ETA: 0s - loss: 0.0949 - acc: 0.978 - ETA: 0s - loss: 0.0963 - acc: 0.978 - ETA: 0s - loss: 0.0972 - acc: 0.978 - ETA: 0s - loss: 0.0965 - acc: 0.978 - 1s 161us/step - loss: 0.0957 - acc: 0.9787 - val_loss: 0.6743 - val_acc: 0.8048
#
# Epoch 00012: val_loss did not improve from 0.58497
# Epoch 13/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.1359 - acc: 0.968 - ETA: 0s - loss: 0.0933 - acc: 0.979 - ETA: 0s - loss: 0.0801 - acc: 0.982 - ETA: 0s - loss: 0.0759 - acc: 0.981 - ETA: 0s - loss: 0.0775 - acc: 0.983 - ETA: 0s - loss: 0.0766 - acc: 0.984 - ETA: 0s - loss: 0.0829 - acc: 0.982 - ETA: 0s - loss: 0.0849 - acc: 0.982 - ETA: 0s - loss: 0.0832 - acc: 0.982 - ETA: 0s - loss: 0.0833 - acc: 0.983 - ETA: 0s - loss: 0.0804 - acc: 0.983 - ETA: 0s - loss: 0.0796 - acc: 0.983 - ETA: 0s - loss: 0.0814 - acc: 0.983 - ETA: 0s - loss: 0.0831 - acc: 0.982 - ETA: 0s - loss: 0.0860 - acc: 0.981 - ETA: 0s - loss: 0.0874 - acc: 0.980 - ETA: 0s - loss: 0.0878 - acc: 0.980 - ETA: 0s - loss: 0.0868 - acc: 0.981 - ETA: 0s - loss: 0.0876 - acc: 0.980 - ETA: 0s - loss: 0.0867 - acc: 0.981 - 1s 159us/step - loss: 0.0873 - acc: 0.9810 - val_loss: 0.6158 - val_acc: 0.8251
#
# Epoch 00013: val_loss did not improve from 0.58497
# Epoch 14/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0556 - acc: 1.000 - ETA: 0s - loss: 0.0589 - acc: 0.987 - ETA: 0s - loss: 0.0591 - acc: 0.989 - ETA: 0s - loss: 0.0807 - acc: 0.982 - ETA: 0s - loss: 0.0769 - acc: 0.983 - ETA: 0s - loss: 0.0765 - acc: 0.984 - ETA: 0s - loss: 0.0707 - acc: 0.986 - ETA: 0s - loss: 0.0746 - acc: 0.985 - ETA: 0s - loss: 0.0767 - acc: 0.984 - ETA: 0s - loss: 0.0754 - acc: 0.984 - ETA: 0s - loss: 0.0735 - acc: 0.985 - ETA: 0s - loss: 0.0738 - acc: 0.984 - ETA: 0s - loss: 0.0732 - acc: 0.983 - ETA: 0s - loss: 0.0727 - acc: 0.984 - ETA: 0s - loss: 0.0735 - acc: 0.983 - ETA: 0s - loss: 0.0746 - acc: 0.983 - ETA: 0s - loss: 0.0747 - acc: 0.982 - ETA: 0s - loss: 0.0743 - acc: 0.982 - ETA: 0s - loss: 0.0755 - acc: 0.982 - ETA: 0s - loss: 0.0764 - acc: 0.982 - 1s 161us/step - loss: 0.0760 - acc: 0.9826 - val_loss: 0.6027 - val_acc: 0.8204
#
# Epoch 00014: val_loss did not improve from 0.58497
# Epoch 15/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0609 - acc: 0.968 - ETA: 0s - loss: 0.0457 - acc: 0.992 - ETA: 0s - loss: 0.0485 - acc: 0.990 - ETA: 0s - loss: 0.0509 - acc: 0.991 - ETA: 0s - loss: 0.0532 - acc: 0.990 - ETA: 0s - loss: 0.0537 - acc: 0.988 - ETA: 0s - loss: 0.0537 - acc: 0.988 - ETA: 0s - loss: 0.0531 - acc: 0.989 - ETA: 0s - loss: 0.0538 - acc: 0.990 - ETA: 0s - loss: 0.0569 - acc: 0.988 - ETA: 0s - loss: 0.0581 - acc: 0.988 - ETA: 0s - loss: 0.0601 - acc: 0.987 - ETA: 0s - loss: 0.0603 - acc: 0.987 - ETA: 0s - loss: 0.0601 - acc: 0.987 - ETA: 0s - loss: 0.0597 - acc: 0.987 - ETA: 0s - loss: 0.0600 - acc: 0.987 - ETA: 0s - loss: 0.0613 - acc: 0.987 - ETA: 0s - loss: 0.0619 - acc: 0.987 - ETA: 0s - loss: 0.0646 - acc: 0.986 - ETA: 0s - loss: 0.0644 - acc: 0.986 - 1s 162us/step - loss: 0.0649 - acc: 0.9861 - val_loss: 0.6313 - val_acc: 0.8120
#
# Epoch 00015: val_loss did not improve from 0.58497
# Epoch 16/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.1116 - acc: 0.968 - ETA: 0s - loss: 0.0402 - acc: 0.992 - ETA: 0s - loss: 0.0362 - acc: 0.995 - ETA: 0s - loss: 0.0375 - acc: 0.996 - ETA: 0s - loss: 0.0381 - acc: 0.996 - ETA: 0s - loss: 0.0376 - acc: 0.996 - ETA: 0s - loss: 0.0387 - acc: 0.995 - ETA: 0s - loss: 0.0424 - acc: 0.993 - ETA: 0s - loss: 0.0447 - acc: 0.992 - ETA: 0s - loss: 0.0452 - acc: 0.992 - ETA: 0s - loss: 0.0451 - acc: 0.992 - ETA: 0s - loss: 0.0447 - acc: 0.992 - ETA: 0s - loss: 0.0458 - acc: 0.992 - ETA: 0s - loss: 0.0473 - acc: 0.991 - ETA: 0s - loss: 0.0497 - acc: 0.990 - ETA: 0s - loss: 0.0516 - acc: 0.990 - ETA: 0s - loss: 0.0530 - acc: 0.990 - ETA: 0s - loss: 0.0548 - acc: 0.989 - ETA: 0s - loss: 0.0555 - acc: 0.989 - ETA: 0s - loss: 0.0555 - acc: 0.989 - 1s 160us/step - loss: 0.0554 - acc: 0.9895 - val_loss: 0.6853 - val_acc: 0.8192
#
# Epoch 00016: val_loss did not improve from 0.58497
# Epoch 17/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0746 - acc: 0.968 - ETA: 0s - loss: 0.0460 - acc: 0.994 - ETA: 0s - loss: 0.0406 - acc: 0.994 - ETA: 0s - loss: 0.0372 - acc: 0.995 - ETA: 0s - loss: 0.0359 - acc: 0.995 - ETA: 0s - loss: 0.0393 - acc: 0.994 - ETA: 0s - loss: 0.0376 - acc: 0.995 - ETA: 0s - loss: 0.0414 - acc: 0.993 - ETA: 0s - loss: 0.0441 - acc: 0.993 - ETA: 0s - loss: 0.0469 - acc: 0.992 - ETA: 0s - loss: 0.0489 - acc: 0.991 - ETA: 0s - loss: 0.0472 - acc: 0.992 - ETA: 0s - loss: 0.0502 - acc: 0.991 - ETA: 0s - loss: 0.0515 - acc: 0.991 - ETA: 0s - loss: 0.0507 - acc: 0.991 - ETA: 0s - loss: 0.0498 - acc: 0.991 - ETA: 0s - loss: 0.0514 - acc: 0.990 - ETA: 0s - loss: 0.0522 - acc: 0.990 - ETA: 0s - loss: 0.0554 - acc: 0.989 - ETA: 0s - loss: 0.0561 - acc: 0.988 - 1s 161us/step - loss: 0.0568 - acc: 0.9886 - val_loss: 0.6142 - val_acc: 0.8216
#
# Epoch 00017: val_loss did not improve from 0.58497
# Epoch 18/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0431 - acc: 1.000 - ETA: 0s - loss: 0.0371 - acc: 0.994 - ETA: 0s - loss: 0.0426 - acc: 0.991 - ETA: 0s - loss: 0.0483 - acc: 0.992 - ETA: 0s - loss: 0.0472 - acc: 0.991 - ETA: 0s - loss: 0.0436 - acc: 0.992 - ETA: 0s - loss: 0.0421 - acc: 0.993 - ETA: 0s - loss: 0.0457 - acc: 0.992 - ETA: 0s - loss: 0.0476 - acc: 0.991 - ETA: 0s - loss: 0.0469 - acc: 0.991 - ETA: 0s - loss: 0.0465 - acc: 0.992 - ETA: 0s - loss: 0.0458 - acc: 0.992 - ETA: 0s - loss: 0.0452 - acc: 0.992 - ETA: 0s - loss: 0.0465 - acc: 0.991 - ETA: 0s - loss: 0.0474 - acc: 0.991 - ETA: 0s - loss: 0.0478 - acc: 0.991 - ETA: 0s - loss: 0.0484 - acc: 0.991 - ETA: 0s - loss: 0.0473 - acc: 0.991 - ETA: 0s - loss: 0.0481 - acc: 0.991 - 1s 158us/step - loss: 0.0514 - acc: 0.9901 - val_loss: 0.6230 - val_acc: 0.8204
#
# Epoch 00018: val_loss did not improve from 0.58497
# Epoch 19/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0488 - acc: 1.000 - ETA: 0s - loss: 0.0366 - acc: 0.997 - ETA: 0s - loss: 0.0364 - acc: 0.994 - ETA: 0s - loss: 0.0327 - acc: 0.995 - ETA: 0s - loss: 0.0352 - acc: 0.994 - ETA: 0s - loss: 0.0369 - acc: 0.994 - ETA: 0s - loss: 0.0381 - acc: 0.993 - ETA: 0s - loss: 0.0394 - acc: 0.993 - ETA: 0s - loss: 0.0417 - acc: 0.991 - ETA: 0s - loss: 0.0407 - acc: 0.992 - ETA: 0s - loss: 0.0406 - acc: 0.992 - ETA: 0s - loss: 0.0399 - acc: 0.992 - ETA: 0s - loss: 0.0404 - acc: 0.992 - ETA: 0s - loss: 0.0414 - acc: 0.991 - ETA: 0s - loss: 0.0442 - acc: 0.991 - ETA: 0s - loss: 0.0465 - acc: 0.990 - ETA: 0s - loss: 0.0455 - acc: 0.991 - ETA: 0s - loss: 0.0455 - acc: 0.990 - ETA: 0s - loss: 0.0450 - acc: 0.990 - ETA: 0s - loss: 0.0454 - acc: 0.990 - 1s 162us/step - loss: 0.0454 - acc: 0.9904 - val_loss: 0.6398 - val_acc: 0.8287
#
# Epoch 00019: val_loss did not improve from 0.58497
# Epoch 20/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0538 - acc: 0.968 - ETA: 1s - loss: 0.0235 - acc: 0.997 - ETA: 1s - loss: 0.0250 - acc: 0.997 - ETA: 0s - loss: 0.0335 - acc: 0.995 - ETA: 0s - loss: 0.0354 - acc: 0.992 - ETA: 0s - loss: 0.0396 - acc: 0.991 - ETA: 0s - loss: 0.0383 - acc: 0.992 - ETA: 0s - loss: 0.0373 - acc: 0.992 - ETA: 0s - loss: 0.0367 - acc: 0.992 - ETA: 0s - loss: 0.0388 - acc: 0.992 - ETA: 0s - loss: 0.0407 - acc: 0.990 - ETA: 0s - loss: 0.0411 - acc: 0.990 - ETA: 0s - loss: 0.0411 - acc: 0.990 - ETA: 0s - loss: 0.0427 - acc: 0.989 - ETA: 0s - loss: 0.0446 - acc: 0.989 - ETA: 0s - loss: 0.0444 - acc: 0.989 - ETA: 0s - loss: 0.0461 - acc: 0.989 - ETA: 0s - loss: 0.0448 - acc: 0.989 - ETA: 0s - loss: 0.0439 - acc: 0.990 - ETA: 0s - loss: 0.0443 - acc: 0.989 - 1s 164us/step - loss: 0.0437 - acc: 0.9903 - val_loss: 0.6466 - val_acc: 0.8228
#
# Epoch 00020: val_loss did not improve from 0.58497

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
if useVGG19:
    VGG19_CustomHead.load_weights('saved_models/weights.best.VGG19.hdf5')
    
if useResnet50:
    Resnet50_CustomHead.load_weights('saved_models/weights.best.Resnet50.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
if useVGG19:
    # get index of predicted dog breed for each image in test set
    VGG19_predictions = [np.argmax(VGG19_CustomHead.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG19]
    # report test accuracy
    test_accuracy = 100*np.sum(np.array(VGG19_predictions)==np.argmax(test_targets, axis=1))/len(VGG19_predictions)
    print('VGG19 Test Accuracy: %.4f%%' % test_accuracy)  
    # best to date 79.0-80.0%, 2x 500 layers, dropout, tanh activation
    
if useResnet50:
    # get index of predicted dog breed for each image in test set
    Resnet50_predictions = [np.argmax(Resnet50_CustomHead.predict(np.expand_dims(feature, axis=0))) for feature in test_Resnet50]
    # report test accuracy
    test_accuracy = 100*np.sum(np.array(Resnet50_predictions)==np.argmax(test_targets, axis=1))/len(Resnet50_predictions)
    print('Resnet50 Test Accuracy: %.4f%%' % test_accuracy)    
    # best to date  84.2105%, no data augmentation, 500 dense hidden layer, 0.5 dropout, tanh
    # best to date with elu  79.0670% (but trains fast), no data augmentation, 500 layer, 0.5 dropout
    # best to date with data augmentation and elu 77%
# Out:
# VGG19 Test Accuracy: 79.7847%
# Resnet50 Test Accuracy: 80.1435%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

from extract_bottleneck_features import *

if useVGG19:
    def VGG19_predict_breed(img_path):
        # extract bottleneck features
        bottleneck_feature = extract_VGG19(path_to_tensor(img_path))
        # obtain predicted vector
        predicted_vector = VGG19_CustomHead.predict(bottleneck_feature)
        # return dog breed that is predicted by the model
        predIdx = np.argmax(predicted_vector)
        print(predIdx)
        return dog_names[predIdx]

#result = VGG19_predict_breed(human_files[0])
#print(result)    
    
if useResnet50:
    def Resnet50_predict_breed(img_path):
        # extract bottleneck features
        bottleneck_feature = extract_Resnet50(path_to_tensor(img_path))
        # obtain predicted vector
        predicted_vector = Resnet50_CustomHead.predict(bottleneck_feature)
        # return dog breed that is predicted by the model
        predIdx = np.argmax(predicted_vector)
        return dog_names[predIdx]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

import cv2                
import matplotlib.pyplot as plt  
# %matplotlib inline  

## if a dog is detected in the image, return the predicted breed.
## if a human is detected in the image, return the resembling dog breed.
## if neither is detected in the image, provide output that indicates an error.
def dog_or_dogish_detector(img_path):
    if useVGG19:  
        predName = VGG19_predict_breed(img_path)
    elif useResnet50:     
        predName = Resnet50_predict_breed(img_path)
        
    # check for dogs, let CNN detector take priority    
    if (dog_detector(img_path)):
        return 'hello, dog! Your breed is ...' + predName    
    elif (face_detector(img_path)):
        return 'hello, human, you look like a ...' + predName    
    else:
        return 'error, neither dog nor human ...' + predName    
    
    
def showImg(img_path): 
    # load color (BGR) image
    img = cv2.imread(img_path)

    # convert BGR image to RGB for plotting
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # display the image, along with bounding box
    plt.imshow(cv_rgb)
    plt.show()

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__
#
# The output is pretty good. Better than I expected honestly.
#
# To impove
# * A larger training set (seemed to overfit, even with a lot of dropout)
# * Data augmentation (to make better use of the small data set we do have)
# * (done already, but could keep trying) Experiment with different layer depths, dropouts, activation functions, learning rates, momentum rates
# * Use a better pre-trained network

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

ione = np.array(glob("data/ione.jpg"))
print(ione[0])
showImg(ione[0])
result = dog_or_dogish_detector(ione[0])
print(result)


showImg(human_files[0])
result = dog_or_dogish_detector(human_files[0])
print(result)

showImg(human_files[1])
result = dog_or_dogish_detector(human_files[1])
print(result)

showImg(human_files[2])
result = dog_or_dogish_detector(human_files[2])
print(result)

showImg(human_files[3])
result = dog_or_dogish_detector(human_files[2])
print(result)


showImg(dog_files_short[0])
result = dog_or_dogish_detector(dog_files_short[0])
print(result)

showImg(dog_files_short[1])
result = dog_or_dogish_detector(dog_files_short[1])
print(result)

showImg(dog_files_short[2])
result = dog_or_dogish_detector(dog_files_short[2])
print(result)

showImg(dog_files_short[3])
result = dog_or_dogish_detector(dog_files_short[3])
print(result)
# Out:
# data/ione.jpg
# 48
# hello, human, you look like a ...n\049.Chinese_crested
# 111
# hello, human, you look like a ...n\112.Nova_scotia_duck_tolling_retriever
# 82
# hello, human, you look like a ...n\083.Ibizan_hound
# 92
# hello, human, you look like a ...n\093.Kerry_blue_terrier
# 92
# hello, human, you look like a ...n\093.Kerry_blue_terrier
# 94
# hello, dog! Your breed is ...n\095.Kuvasz
# 56
# hello, dog! Your breed is ...n\057.Dalmatian
# 87
# hello, dog! Your breed is ...n\088.Irish_water_spaniel
# 7
# hello, dog! Your breed is ...n\008.American_staffordshire_terrier

# %% [markdown]
# # Please download your notebook to submit
#
# In order to submit, please do the following:
# 1.  Download an HTML version of the notebook to your computer using 'File: Download as...'
# 2.  Click on the orange Jupyter circle on the top left of the workspace.
# 3.  Navigate into the dog-project folder to ensure that you are using the provided dog_images, lfw, and bottleneck_features folders; this means that those folders will *not* appear in the dog-project folder.  If they do appear because you downloaded them, delete them.
# 4.  While in the dog-project folder, upload the HTML version of this notebook you just downloaded.  The upload button is on the top right.
# 5.  Navigate back to the home folder by clicking on the two dots next to the folder icon, and then open up a terminal under the 'new' tab on the top right
# 6.  Zip the dog-project folder with the following command in the terminal:
#  `zip -r dog-project.zip dog-project`
# 7.  Download the zip file by clicking on the square next to it and selecting 'download'.  This will be the zip file you turn in on the next node after this workspace!
